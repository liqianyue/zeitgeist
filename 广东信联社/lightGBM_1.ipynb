# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score,auc,roc_curve
import matplotlib.pyplot as plt
import sklearn.metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc,f1_score,confusion_matrix
from sklearn.multiclass import OneVsRestClassifier
from sklearn import metrics
from imblearn.over_sampling import SMOTE,ADASYN
from imblearn.under_sampling import RandomUnderSampler
from sklearn.ensemble import RandomForestClassifier
RandomUnderSampler
from sklearn  import preprocessing
import  xgboost
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from tensorflow import keras as keras
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import StratifiedKFold
import lightgbm as lgb

# %% [markdown]
# # 加载数据集与预处理

# %%
#训练集
train=pd.read_csv("C:/Users/Lenovo/Desktop/train/train7.9_screening.csv")
#测试集
test=pd.read_csv("C:/Users/Lenovo/Desktop/train/test7.9_screening.csv")
data = pd.concat([train,test],axis=0,ignore_index=True)
#训练集标签
train_label=pd.read_csv("C:/Users/Lenovo/Desktop/train/y_train.csv")
train_label=train_label.iloc[:,1]

# %%
train_data=train.iloc[:,1:].values
train_label=train_label.values.ravel()
print(train_data.shape)
print(train_label.shape)
test_data=test.iloc[:,1:].values
print(test_data.shape)
# Out:
# (784000, 70)
# (784000,)
# (340043, 70)

# %%
model_smote=SMOTE(k_neighbors=20)
X,y=model_smote.fit_resample(train_data,train_label)
X.shape,y.shape
# Out:
# ((1400000, 70), (1400000,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

# %% [markdown]
# # lgb_1

# %%
parameters={
            'objective': 'binary',
            'metric': 'binary_error',
            'verbosity': -1,
            'boosting_type': 'gbdt',
            'lambda_l1': 1.20240655708393e-08, 
            'lambda_l2': 0.1148043434213944, 
            'num_leaves': 512, 
            'learning_rate': 0.020071584253295194, 
            'n_estimators': 3288, 
            'feature_fraction': 0.9512028862422643, 
            'bagging_fraction': 0.934931341887986, 
            'bagging_freq': 1, 
            'min_child_samples': 29,
            'max_depth':53
            }

# %%
gbm = lgb.LGBMClassifier(**parameters)

# %%
gbm.fit(X, y,eval_set=[(X,y),(X_test,y_test)],early_stopping_rounds=100)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9512028862422643, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9512028862422643
# [LightGBM] [Warning] lambda_l1 is set=1.20240655708393e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.20240655708393e-08
# [LightGBM] [Warning] bagging_fraction is set=0.934931341887986, subsample=1.0 will be ignored. Current value: bagging_fraction=0.934931341887986
# [LightGBM] [Warning] lambda_l2 is set=0.1148043434213944, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1148043434213944
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [1]	training's binary_error: 0.0250507	valid_1's binary_error: 0.0251821
# Training until validation scores don't improve for 100 rounds
# [2]	training's binary_error: 0.0238514	valid_1's binary_error: 0.0236679
# [3]	training's binary_error: 0.0235329	valid_1's binary_error: 0.0234179
# [4]	training's binary_error: 0.0233364	valid_1's binary_error: 0.0232429
# [5]	training's binary_error: 0.0231793	valid_1's binary_error: 0.0229893
# [6]	training's binary_error: 0.0229957	valid_1's binary_error: 0.022775
# [7]	training's binary_error: 0.0228771	valid_1's binary_error: 0.0226393
# [8]	training's binary_error: 0.0228143	valid_1's binary_error: 0.0225036
# [9]	training's binary_error: 0.0226321	valid_1's binary_error: 0.0223679
# [10]	training's binary_error: 0.0225714	valid_1's binary_error: 0.0224143
# [11]	training's binary_error: 0.0224886	valid_1's binary_error: 0.0222321
# [12]	training's binary_error: 0.0224	valid_1's binary_error: 0.0222607
# [13]	training's binary_error: 0.0222957	valid_1's binary_error: 0.0221607
# [14]	training's binary_error: 0.0222407	valid_1's binary_error: 0.0220964
# [15]	training's binary_error: 0.0221729	valid_1's binary_error: 0.0220036
# [16]	training's binary_error: 0.022105	valid_1's binary_error: 0.0219143
# [17]	training's binary_error: 0.0220293	valid_1's binary_error: 0.0218786
# [18]	training's binary_error: 0.0219621	valid_1's binary_error: 0.0218071
# [19]	training's binary_error: 0.0219257	valid_1's binary_error: 0.0217643
# [20]	training's binary_error: 0.02183	valid_1's binary_error: 0.0216893
# [21]	training's binary_error: 0.021805	valid_1's binary_error: 0.0216321
# [22]	training's binary_error: 0.0217179	valid_1's binary_error: 0.0215179
# [23]	training's binary_error: 0.021615	valid_1's binary_error: 0.0214429
# [24]	training's binary_error: 0.0216	valid_1's binary_error: 0.0214321
# [25]	training's binary_error: 0.0215457	valid_1's binary_error: 0.0213679
# [26]	training's binary_error: 0.0215236	valid_1's binary_error: 0.0213179
# [27]	training's binary_error: 0.0214743	valid_1's binary_error: 0.0212607
# [28]	training's binary_error: 0.0214314	valid_1's binary_error: 0.0212357
# [29]	training's binary_error: 0.0214021	valid_1's binary_error: 0.0212143
# [30]	training's binary_error: 0.02135	valid_1's binary_error: 0.0211679
# [31]	training's binary_error: 0.0213114	valid_1's binary_error: 0.0211143
# [32]	training's binary_error: 0.0212943	valid_1's binary_error: 0.0210714
# [33]	training's binary_error: 0.0212879	valid_1's binary_error: 0.0210429
# [34]	training's binary_error: 0.02124	valid_1's binary_error: 0.021025
# [35]	training's binary_error: 0.02121	valid_1's binary_error: 0.0210393
# [36]	training's binary_error: 0.0211629	valid_1's binary_error: 0.0209536
# [37]	training's binary_error: 0.0211043	valid_1's binary_error: 0.0209
# [38]	training's binary_error: 0.0210207	valid_1's binary_error: 0.0208179
# [39]	training's binary_error: 0.0209636	valid_1's binary_error: 0.0207607
# [40]	training's binary_error: 0.02093	valid_1's binary_error: 0.0207
# [41]	training's binary_error: 0.0208786	valid_1's binary_error: 0.0206107
# [42]	training's binary_error: 0.0208271	valid_1's binary_error: 0.0205857
# [43]	training's binary_error: 0.0207943	valid_1's binary_error: 0.0205321
# [44]	training's binary_error: 0.0207564	valid_1's binary_error: 0.0204893
# [45]	training's binary_error: 0.0207093	valid_1's binary_error: 0.0204714
# [46]	training's binary_error: 0.0206579	valid_1's binary_error: 0.0204214
# [47]	training's binary_error: 0.0206	valid_1's binary_error: 0.0203714
# [48]	training's binary_error: 0.0205657	valid_1's binary_error: 0.0203286
# [49]	training's binary_error: 0.0205393	valid_1's binary_error: 0.0203
# [50]	training's binary_error: 0.0204714	valid_1's binary_error: 0.020225
# [51]	training's binary_error: 0.0204157	valid_1's binary_error: 0.0201821
# [52]	training's binary_error: 0.0203307	valid_1's binary_error: 0.0201036
# [53]	training's binary_error: 0.0202686	valid_1's binary_error: 0.0200321
# [54]	training's binary_error: 0.0202379	valid_1's binary_error: 0.0200357
# [55]	training's binary_error: 0.0201607	valid_1's binary_error: 0.019975
# [56]	training's binary_error: 0.0201543	valid_1's binary_error: 0.0199821
# [57]	training's binary_error: 0.020105	valid_1's binary_error: 0.0199714
# [58]	training's binary_error: 0.0200757	valid_1's binary_error: 0.0199286
# [59]	training's binary_error: 0.0200279	valid_1's binary_error: 0.0198857
# [60]	training's binary_error: 0.0199936	valid_1's binary_error: 0.0198607
# [61]	training's binary_error: 0.0199429	valid_1's binary_error: 0.0198286
# [62]	training's binary_error: 0.0199007	valid_1's binary_error: 0.0197857
# [63]	training's binary_error: 0.0198686	valid_1's binary_error: 0.0197464
# [64]	training's binary_error: 0.01983	valid_1's binary_error: 0.0197321
# [65]	training's binary_error: 0.0197636	valid_1's binary_error: 0.0196321
# [66]	training's binary_error: 0.0197379	valid_1's binary_error: 0.0196393
# [67]	training's binary_error: 0.0196843	valid_1's binary_error: 0.0195786
# [68]	training's binary_error: 0.0196486	valid_1's binary_error: 0.019525
# [69]	training's binary_error: 0.0195843	valid_1's binary_error: 0.0194607
# [70]	training's binary_error: 0.019555	valid_1's binary_error: 0.0194786
# [71]	training's binary_error: 0.0195171	valid_1's binary_error: 0.019425
# [72]	training's binary_error: 0.0194729	valid_1's binary_error: 0.0193821
# [73]	training's binary_error: 0.0194371	valid_1's binary_error: 0.01935
# [74]	training's binary_error: 0.0193679	valid_1's binary_error: 0.0192786
# [75]	training's binary_error: 0.0193307	valid_1's binary_error: 0.0192429
# [76]	training's binary_error: 0.0192971	valid_1's binary_error: 0.0192
# [77]	training's binary_error: 0.0192621	valid_1's binary_error: 0.0191643
# [78]	training's binary_error: 0.0192129	valid_1's binary_error: 0.0191214
# [79]	training's binary_error: 0.01918	valid_1's binary_error: 0.0190679
# [80]	training's binary_error: 0.0191086	valid_1's binary_error: 0.0189714
# [81]	training's binary_error: 0.0190671	valid_1's binary_error: 0.018925
# [82]	training's binary_error: 0.0190507	valid_1's binary_error: 0.0189464
# [83]	training's binary_error: 0.0189993	valid_1's binary_error: 0.0188786
# [84]	training's binary_error: 0.0189621	valid_1's binary_error: 0.018825
# [85]	training's binary_error: 0.0188936	valid_1's binary_error: 0.0187536
# [86]	training's binary_error: 0.0188614	valid_1's binary_error: 0.0186929
# [87]	training's binary_error: 0.0188371	valid_1's binary_error: 0.0186464
# [88]	training's binary_error: 0.0187879	valid_1's binary_error: 0.0186179
# [89]	training's binary_error: 0.0187579	valid_1's binary_error: 0.0185607
# [90]	training's binary_error: 0.0187329	valid_1's binary_error: 0.0185607
# [91]	training's binary_error: 0.0186757	valid_1's binary_error: 0.0184714
# [92]	training's binary_error: 0.0186636	valid_1's binary_error: 0.0184429
# [93]	training's binary_error: 0.0186229	valid_1's binary_error: 0.0183929
# [94]	training's binary_error: 0.0185864	valid_1's binary_error: 0.0183571
# [95]	training's binary_error: 0.01855	valid_1's binary_error: 0.0183429
# [96]	training's binary_error: 0.0185064	valid_1's binary_error: 0.0182964
# [97]	training's binary_error: 0.0184479	valid_1's binary_error: 0.0182357
# [98]	training's binary_error: 0.0184329	valid_1's binary_error: 0.0182179
# [99]	training's binary_error: 0.0184057	valid_1's binary_error: 0.0182071
# [100]	training's binary_error: 0.0183493	valid_1's binary_error: 0.0181929
# [101]	training's binary_error: 0.0183257	valid_1's binary_error: 0.0181857
# [102]	training's binary_error: 0.0182936	valid_1's binary_error: 0.0181179
# [103]	training's binary_error: 0.0182521	valid_1's binary_error: 0.0180821
# [104]	training's binary_error: 0.0182064	valid_1's binary_error: 0.0180036
# [105]	training's binary_error: 0.0181621	valid_1's binary_error: 0.0179607
# [106]	training's binary_error: 0.0181357	valid_1's binary_error: 0.017925
# [107]	training's binary_error: 0.0180871	valid_1's binary_error: 0.0178714
# [108]	training's binary_error: 0.0180379	valid_1's binary_error: 0.0178607
# [109]	training's binary_error: 0.0179979	valid_1's binary_error: 0.017825
# [110]	training's binary_error: 0.0179621	valid_1's binary_error: 0.0177786
# [111]	training's binary_error: 0.0179329	valid_1's binary_error: 0.0177571
# [112]	training's binary_error: 0.0178921	valid_1's binary_error: 0.0177071
# [113]	training's binary_error: 0.0178429	valid_1's binary_error: 0.0176893
# [114]	training's binary_error: 0.017835	valid_1's binary_error: 0.0176679
# [115]	training's binary_error: 0.017815	valid_1's binary_error: 0.0176786
# [116]	training's binary_error: 0.0177679	valid_1's binary_error: 0.0176
# [117]	training's binary_error: 0.0177157	valid_1's binary_error: 0.0175321
# [118]	training's binary_error: 0.0176879	valid_1's binary_error: 0.0175
# [119]	training's binary_error: 0.0176493	valid_1's binary_error: 0.0174571
# [120]	training's binary_error: 0.017605	valid_1's binary_error: 0.0174036
# [121]	training's binary_error: 0.0175414	valid_1's binary_error: 0.0173643
# [122]	training's binary_error: 0.01751	valid_1's binary_error: 0.0173179
# [123]	training's binary_error: 0.0174764	valid_1's binary_error: 0.0173107
# [124]	training's binary_error: 0.01745	valid_1's binary_error: 0.0172893
# [125]	training's binary_error: 0.0174243	valid_1's binary_error: 0.0172857
# [126]	training's binary_error: 0.0173836	valid_1's binary_error: 0.0172357
# [127]	training's binary_error: 0.0173257	valid_1's binary_error: 0.0171607
# [128]	training's binary_error: 0.0172936	valid_1's binary_error: 0.0171357
# [129]	training's binary_error: 0.0172543	valid_1's binary_error: 0.017075
# [130]	training's binary_error: 0.0172236	valid_1's binary_error: 0.0170536
# [131]	training's binary_error: 0.0171929	valid_1's binary_error: 0.017025
# [132]	training's binary_error: 0.0171564	valid_1's binary_error: 0.0169857
# [133]	training's binary_error: 0.0171157	valid_1's binary_error: 0.0169357
# [134]	training's binary_error: 0.0170557	valid_1's binary_error: 0.0169071
# [135]	training's binary_error: 0.0170193	valid_1's binary_error: 0.0168464
# [136]	training's binary_error: 0.0169793	valid_1's binary_error: 0.0168107
# [137]	training's binary_error: 0.0169436	valid_1's binary_error: 0.0167571
# [138]	training's binary_error: 0.0169157	valid_1's binary_error: 0.0167714
# [139]	training's binary_error: 0.0168686	valid_1's binary_error: 0.0166857
# [140]	training's binary_error: 0.0168293	valid_1's binary_error: 0.0166571
# [141]	training's binary_error: 0.0168079	valid_1's binary_error: 0.0166357
# [142]	training's binary_error: 0.0167879	valid_1's binary_error: 0.0165964
# [143]	training's binary_error: 0.0167621	valid_1's binary_error: 0.0165429
# [144]	training's binary_error: 0.0167379	valid_1's binary_error: 0.0165321
# [145]	training's binary_error: 0.0166943	valid_1's binary_error: 0.0164857
# [146]	training's binary_error: 0.0166729	valid_1's binary_error: 0.0164464
# [147]	training's binary_error: 0.0166229	valid_1's binary_error: 0.0164179
# [148]	training's binary_error: 0.0165929	valid_1's binary_error: 0.0164036
# [149]	training's binary_error: 0.0165514	valid_1's binary_error: 0.0163464
# [150]	training's binary_error: 0.0165329	valid_1's binary_error: 0.0163214
# [151]	training's binary_error: 0.0165029	valid_1's binary_error: 0.0163036
# [152]	training's binary_error: 0.0164707	valid_1's binary_error: 0.0162929
# [153]	training's binary_error: 0.0164257	valid_1's binary_error: 0.0162214
# [154]	training's binary_error: 0.0163907	valid_1's binary_error: 0.0162071
# [155]	training's binary_error: 0.0163507	valid_1's binary_error: 0.0161464
# [156]	training's binary_error: 0.0163386	valid_1's binary_error: 0.0161179
# [157]	training's binary_error: 0.0163079	valid_1's binary_error: 0.0160893
# [158]	training's binary_error: 0.0162786	valid_1's binary_error: 0.0160714
# [159]	training's binary_error: 0.0162371	valid_1's binary_error: 0.0160321
# [160]	training's binary_error: 0.0162014	valid_1's binary_error: 0.0159643
# [161]	training's binary_error: 0.0161636	valid_1's binary_error: 0.0159357
# [162]	training's binary_error: 0.0161214	valid_1's binary_error: 0.0159071
# [163]	training's binary_error: 0.0160936	valid_1's binary_error: 0.015875
# [164]	training's binary_error: 0.0160557	valid_1's binary_error: 0.0158321
# [165]	training's binary_error: 0.0160157	valid_1's binary_error: 0.0158
# [166]	training's binary_error: 0.0159779	valid_1's binary_error: 0.0157714
# [167]	training's binary_error: 0.0159536	valid_1's binary_error: 0.0157393
# [168]	training's binary_error: 0.0159243	valid_1's binary_error: 0.0157071
# [169]	training's binary_error: 0.01589	valid_1's binary_error: 0.0156821
# [170]	training's binary_error: 0.0158507	valid_1's binary_error: 0.0156429
# [171]	training's binary_error: 0.0158157	valid_1's binary_error: 0.0156143
# [172]	training's binary_error: 0.01578	valid_1's binary_error: 0.0155821
# [173]	training's binary_error: 0.0157207	valid_1's binary_error: 0.0155393
# [174]	training's binary_error: 0.0156993	valid_1's binary_error: 0.0155143
# [175]	training's binary_error: 0.0156486	valid_1's binary_error: 0.0154607
# [176]	training's binary_error: 0.0156071	valid_1's binary_error: 0.0153893
# [177]	training's binary_error: 0.0155779	valid_1's binary_error: 0.0153464
# [178]	training's binary_error: 0.0155507	valid_1's binary_error: 0.0153393
# [179]	training's binary_error: 0.0155121	valid_1's binary_error: 0.0153
# [180]	training's binary_error: 0.01549	valid_1's binary_error: 0.0152857
# [181]	training's binary_error: 0.0154343	valid_1's binary_error: 0.0152286
# [182]	training's binary_error: 0.0153964	valid_1's binary_error: 0.0151679
# [183]	training's binary_error: 0.0153643	valid_1's binary_error: 0.0151321
# [184]	training's binary_error: 0.015335	valid_1's binary_error: 0.0151179
# [185]	training's binary_error: 0.0153043	valid_1's binary_error: 0.0150714
# [186]	training's binary_error: 0.0152664	valid_1's binary_error: 0.0150286
# [187]	training's binary_error: 0.0152479	valid_1's binary_error: 0.015025
# [188]	training's binary_error: 0.0152193	valid_1's binary_error: 0.0149821
# [189]	training's binary_error: 0.015185	valid_1's binary_error: 0.0149464
# [190]	training's binary_error: 0.0151557	valid_1's binary_error: 0.0149036
# [191]	training's binary_error: 0.0151393	valid_1's binary_error: 0.0148964
# [192]	training's binary_error: 0.0151207	valid_1's binary_error: 0.0148786
# [193]	training's binary_error: 0.01508	valid_1's binary_error: 0.0148429
# [194]	training's binary_error: 0.0150543	valid_1's binary_error: 0.0148071
# [195]	training's binary_error: 0.0150079	valid_1's binary_error: 0.0147679
# [196]	training's binary_error: 0.0149679	valid_1's binary_error: 0.0147393
# [197]	training's binary_error: 0.0149364	valid_1's binary_error: 0.0146964
# [198]	training's binary_error: 0.0149014	valid_1's binary_error: 0.0146571
# [199]	training's binary_error: 0.0148686	valid_1's binary_error: 0.0146607
# [200]	training's binary_error: 0.0148343	valid_1's binary_error: 0.0146179
# [201]	training's binary_error: 0.0147993	valid_1's binary_error: 0.0145857
# [202]	training's binary_error: 0.0147736	valid_1's binary_error: 0.0145607
# [203]	training's binary_error: 0.0147179	valid_1's binary_error: 0.0144786
# [204]	training's binary_error: 0.0146843	valid_1's binary_error: 0.0144571
# [205]	training's binary_error: 0.0146521	valid_1's binary_error: 0.0144321
# [206]	training's binary_error: 0.0146321	valid_1's binary_error: 0.014425
# [207]	training's binary_error: 0.0145971	valid_1's binary_error: 0.0144107
# [208]	training's binary_error: 0.0145507	valid_1's binary_error: 0.0143679
# [209]	training's binary_error: 0.0145257	valid_1's binary_error: 0.01435
# [210]	training's binary_error: 0.0144993	valid_1's binary_error: 0.0142964
# [211]	training's binary_error: 0.0144736	valid_1's binary_error: 0.0142964
# [212]	training's binary_error: 0.0144386	valid_1's binary_error: 0.0142429
# [213]	training's binary_error: 0.0143971	valid_1's binary_error: 0.0142071
# [214]	training's binary_error: 0.0143629	valid_1's binary_error: 0.0141679
# [215]	training's binary_error: 0.01433	valid_1's binary_error: 0.0141179
# [216]	training's binary_error: 0.0142864	valid_1's binary_error: 0.0141071
# [217]	training's binary_error: 0.0142564	valid_1's binary_error: 0.0140821
# [218]	training's binary_error: 0.014235	valid_1's binary_error: 0.0140357
# [219]	training's binary_error: 0.014215	valid_1's binary_error: 0.0140143
# [220]	training's binary_error: 0.0141707	valid_1's binary_error: 0.013975
# [221]	training's binary_error: 0.0141436	valid_1's binary_error: 0.0139464
# [222]	training's binary_error: 0.0141071	valid_1's binary_error: 0.0138893
# [223]	training's binary_error: 0.0140779	valid_1's binary_error: 0.0138821
# [224]	training's binary_error: 0.0140307	valid_1's binary_error: 0.0138679
# [225]	training's binary_error: 0.0140086	valid_1's binary_error: 0.0138357
# [226]	training's binary_error: 0.01397	valid_1's binary_error: 0.0137964
# [227]	training's binary_error: 0.0139407	valid_1's binary_error: 0.0137714
# [228]	training's binary_error: 0.0139214	valid_1's binary_error: 0.0137357
# [229]	training's binary_error: 0.0138929	valid_1's binary_error: 0.0136893
# [230]	training's binary_error: 0.0138607	valid_1's binary_error: 0.0136536
# [231]	training's binary_error: 0.0138264	valid_1's binary_error: 0.0135964
# [232]	training's binary_error: 0.0137907	valid_1's binary_error: 0.0135679
# [233]	training's binary_error: 0.0137664	valid_1's binary_error: 0.0135286
# [234]	training's binary_error: 0.0137286	valid_1's binary_error: 0.0135036
# [235]	training's binary_error: 0.0137	valid_1's binary_error: 0.0134714
# [236]	training's binary_error: 0.01366	valid_1's binary_error: 0.0134429
# [237]	training's binary_error: 0.0136171	valid_1's binary_error: 0.0134107
# [238]	training's binary_error: 0.0135829	valid_1's binary_error: 0.013375
# [239]	training's binary_error: 0.0135636	valid_1's binary_error: 0.0133464
# [240]	training's binary_error: 0.0135214	valid_1's binary_error: 0.0133071
# [241]	training's binary_error: 0.0135	valid_1's binary_error: 0.0132679
# [242]	training's binary_error: 0.0134636	valid_1's binary_error: 0.013225
# [243]	training's binary_error: 0.0134414	valid_1's binary_error: 0.0132036
# [244]	training's binary_error: 0.0133993	valid_1's binary_error: 0.0131536
# [245]	training's binary_error: 0.0133679	valid_1's binary_error: 0.0131071
# [246]	training's binary_error: 0.013345	valid_1's binary_error: 0.0131036
# [247]	training's binary_error: 0.0133179	valid_1's binary_error: 0.0131
# [248]	training's binary_error: 0.0132957	valid_1's binary_error: 0.0130893
# [249]	training's binary_error: 0.0132529	valid_1's binary_error: 0.0130357
# [250]	training's binary_error: 0.0132064	valid_1's binary_error: 0.013
# [251]	training's binary_error: 0.0131871	valid_1's binary_error: 0.0129464
# [252]	training's binary_error: 0.0131564	valid_1's binary_error: 0.0129143
# [253]	training's binary_error: 0.0131243	valid_1's binary_error: 0.0128893
# [254]	training's binary_error: 0.0130836	valid_1's binary_error: 0.0128393
# [255]	training's binary_error: 0.0130536	valid_1's binary_error: 0.0128357
# [256]	training's binary_error: 0.0130379	valid_1's binary_error: 0.0127929
# [257]	training's binary_error: 0.013005	valid_1's binary_error: 0.0127571
# [258]	training's binary_error: 0.0129693	valid_1's binary_error: 0.0127107
# [259]	training's binary_error: 0.012945	valid_1's binary_error: 0.0126964
# [260]	training's binary_error: 0.0129086	valid_1's binary_error: 0.01265
# [261]	training's binary_error: 0.0128771	valid_1's binary_error: 0.0126179
# [262]	training's binary_error: 0.0128521	valid_1's binary_error: 0.0125857
# [263]	training's binary_error: 0.0128229	valid_1's binary_error: 0.0125714
# [264]	training's binary_error: 0.0127879	valid_1's binary_error: 0.0125321
# [265]	training's binary_error: 0.0127707	valid_1's binary_error: 0.0125179
# [266]	training's binary_error: 0.0127443	valid_1's binary_error: 0.0124929
# [267]	training's binary_error: 0.0127257	valid_1's binary_error: 0.0124571
# [268]	training's binary_error: 0.0127043	valid_1's binary_error: 0.0124071
# [269]	training's binary_error: 0.0126864	valid_1's binary_error: 0.0123929
# [270]	training's binary_error: 0.0126507	valid_1's binary_error: 0.0123714
# [271]	training's binary_error: 0.0126329	valid_1's binary_error: 0.01235
# [272]	training's binary_error: 0.0126064	valid_1's binary_error: 0.0123107
# [273]	training's binary_error: 0.0125793	valid_1's binary_error: 0.0123
# [274]	training's binary_error: 0.0125521	valid_1's binary_error: 0.0122643
# [275]	training's binary_error: 0.0125371	valid_1's binary_error: 0.01225
# [276]	training's binary_error: 0.0125	valid_1's binary_error: 0.0122321
# [277]	training's binary_error: 0.0124764	valid_1's binary_error: 0.0122214
# [278]	training's binary_error: 0.012445	valid_1's binary_error: 0.0121679
# [279]	training's binary_error: 0.0124057	valid_1's binary_error: 0.01215
# [280]	training's binary_error: 0.0123871	valid_1's binary_error: 0.0121179
# [281]	training's binary_error: 0.0123564	valid_1's binary_error: 0.0120893
# [282]	training's binary_error: 0.0123321	valid_1's binary_error: 0.0120607
# [283]	training's binary_error: 0.0122807	valid_1's binary_error: 0.0120107
# [284]	training's binary_error: 0.0122536	valid_1's binary_error: 0.0119607
# [285]	training's binary_error: 0.0122243	valid_1's binary_error: 0.0119321
# [286]	training's binary_error: 0.0122064	valid_1's binary_error: 0.0119143
# [287]	training's binary_error: 0.0121829	valid_1's binary_error: 0.0118679
# [288]	training's binary_error: 0.0121393	valid_1's binary_error: 0.0118536
# [289]	training's binary_error: 0.0121136	valid_1's binary_error: 0.0118321
# [290]	training's binary_error: 0.0121021	valid_1's binary_error: 0.0118179
# [291]	training's binary_error: 0.0120593	valid_1's binary_error: 0.011775
# [292]	training's binary_error: 0.0120214	valid_1's binary_error: 0.0117429
# [293]	training's binary_error: 0.0120029	valid_1's binary_error: 0.0117143
# [294]	training's binary_error: 0.0119771	valid_1's binary_error: 0.011725
# [295]	training's binary_error: 0.0119529	valid_1's binary_error: 0.0116964
# [296]	training's binary_error: 0.011925	valid_1's binary_error: 0.0117
# [297]	training's binary_error: 0.0118879	valid_1's binary_error: 0.0116286
# [298]	training's binary_error: 0.0118507	valid_1's binary_error: 0.0115821
# [299]	training's binary_error: 0.01183	valid_1's binary_error: 0.0115571
# [300]	training's binary_error: 0.0118043	valid_1's binary_error: 0.0115143
# [301]	training's binary_error: 0.0117814	valid_1's binary_error: 0.0115071
# [302]	training's binary_error: 0.0117471	valid_1's binary_error: 0.0114571
# [303]	training's binary_error: 0.0117207	valid_1's binary_error: 0.0114464
# [304]	training's binary_error: 0.0117086	valid_1's binary_error: 0.0114393
# [305]	training's binary_error: 0.0116764	valid_1's binary_error: 0.0113964
# [306]	training's binary_error: 0.011645	valid_1's binary_error: 0.0113571
# [307]	training's binary_error: 0.0116321	valid_1's binary_error: 0.0113214
# [308]	training's binary_error: 0.0116029	valid_1's binary_error: 0.0112821
# [309]	training's binary_error: 0.0115686	valid_1's binary_error: 0.0112679
# [310]	training's binary_error: 0.0115514	valid_1's binary_error: 0.01125
# [311]	training's binary_error: 0.0115257	valid_1's binary_error: 0.0112286
# [312]	training's binary_error: 0.0114929	valid_1's binary_error: 0.0112107
# [313]	training's binary_error: 0.0114686	valid_1's binary_error: 0.0111893
# [314]	training's binary_error: 0.0114521	valid_1's binary_error: 0.0111964
# [315]	training's binary_error: 0.0114279	valid_1's binary_error: 0.01115
# [316]	training's binary_error: 0.01141	valid_1's binary_error: 0.01115
# [317]	training's binary_error: 0.0113764	valid_1's binary_error: 0.0111107
# [318]	training's binary_error: 0.0113443	valid_1's binary_error: 0.0110821
# [319]	training's binary_error: 0.0113264	valid_1's binary_error: 0.0110679
# [320]	training's binary_error: 0.0112964	valid_1's binary_error: 0.0110286
# [321]	training's binary_error: 0.0112793	valid_1's binary_error: 0.0110286
# [322]	training's binary_error: 0.0112414	valid_1's binary_error: 0.0109821
# [323]	training's binary_error: 0.0112121	valid_1's binary_error: 0.0109536
# [324]	training's binary_error: 0.01118	valid_1's binary_error: 0.0109179
# [325]	training's binary_error: 0.0111536	valid_1's binary_error: 0.0108857
# [326]	training's binary_error: 0.01114	valid_1's binary_error: 0.0108929
# [327]	training's binary_error: 0.0111071	valid_1's binary_error: 0.0108679
# [328]	training's binary_error: 0.0110757	valid_1's binary_error: 0.0108464
# [329]	training's binary_error: 0.0110407	valid_1's binary_error: 0.010825
# [330]	training's binary_error: 0.0110271	valid_1's binary_error: 0.0108179
# [331]	training's binary_error: 0.0109943	valid_1's binary_error: 0.0107964
# [332]	training's binary_error: 0.0109686	valid_1's binary_error: 0.0107679
# [333]	training's binary_error: 0.0109436	valid_1's binary_error: 0.0107214
# [334]	training's binary_error: 0.0109029	valid_1's binary_error: 0.010675
# [335]	training's binary_error: 0.0108857	valid_1's binary_error: 0.0106393
# [336]	training's binary_error: 0.0108593	valid_1's binary_error: 0.0106179
# [337]	training's binary_error: 0.0108329	valid_1's binary_error: 0.0105929
# [338]	training's binary_error: 0.0108136	valid_1's binary_error: 0.0105714
# [339]	training's binary_error: 0.0107864	valid_1's binary_error: 0.0105786
# [340]	training's binary_error: 0.0107607	valid_1's binary_error: 0.0105357
# [341]	training's binary_error: 0.0107336	valid_1's binary_error: 0.0105071
# [342]	training's binary_error: 0.0107107	valid_1's binary_error: 0.0104929
# [343]	training's binary_error: 0.0106993	valid_1's binary_error: 0.0104857
# [344]	training's binary_error: 0.010675	valid_1's binary_error: 0.0104786
# [345]	training's binary_error: 0.0106514	valid_1's binary_error: 0.0104393
# [346]	training's binary_error: 0.0106207	valid_1's binary_error: 0.0104214
# [347]	training's binary_error: 0.010595	valid_1's binary_error: 0.0104036
# [348]	training's binary_error: 0.0105593	valid_1's binary_error: 0.0103214
# [349]	training's binary_error: 0.0105357	valid_1's binary_error: 0.0103357
# [350]	training's binary_error: 0.0104964	valid_1's binary_error: 0.0103
# [351]	training's binary_error: 0.0104629	valid_1's binary_error: 0.0102714
# [352]	training's binary_error: 0.0104379	valid_1's binary_error: 0.0102393
# [353]	training's binary_error: 0.0104179	valid_1's binary_error: 0.0102107
# [354]	training's binary_error: 0.0103857	valid_1's binary_error: 0.0101786
# [355]	training's binary_error: 0.0103657	valid_1's binary_error: 0.01015
# [356]	training's binary_error: 0.0103364	valid_1's binary_error: 0.0101357
# [357]	training's binary_error: 0.01032	valid_1's binary_error: 0.0100964
# [358]	training's binary_error: 0.010295	valid_1's binary_error: 0.0100857
# [359]	training's binary_error: 0.0102857	valid_1's binary_error: 0.010075
# [360]	training's binary_error: 0.0102607	valid_1's binary_error: 0.010025
# [361]	training's binary_error: 0.0102221	valid_1's binary_error: 0.00998214
# [362]	training's binary_error: 0.0102007	valid_1's binary_error: 0.00996429
# [363]	training's binary_error: 0.0101757	valid_1's binary_error: 0.00992857
# [364]	training's binary_error: 0.0101571	valid_1's binary_error: 0.00991786
# [365]	training's binary_error: 0.0101229	valid_1's binary_error: 0.00988214
# [366]	training's binary_error: 0.0101136	valid_1's binary_error: 0.00987857
# [367]	training's binary_error: 0.0100686	valid_1's binary_error: 0.00982143
# [368]	training's binary_error: 0.0100443	valid_1's binary_error: 0.00979286
# [369]	training's binary_error: 0.01002	valid_1's binary_error: 0.00976071
# [370]	training's binary_error: 0.00999429	valid_1's binary_error: 0.009725
# [371]	training's binary_error: 0.00995143	valid_1's binary_error: 0.00968214
# [372]	training's binary_error: 0.00992929	valid_1's binary_error: 0.00968214
# [373]	training's binary_error: 0.00990357	valid_1's binary_error: 0.00965
# [374]	training's binary_error: 0.00987929	valid_1's binary_error: 0.00960714
# [375]	training's binary_error: 0.00986	valid_1's binary_error: 0.00958929
# [376]	training's binary_error: 0.00983	valid_1's binary_error: 0.00956429
# [377]	training's binary_error: 0.00981071	valid_1's binary_error: 0.00953214
# [378]	training's binary_error: 0.00978429	valid_1's binary_error: 0.00950714
# [379]	training's binary_error: 0.00976143	valid_1's binary_error: 0.00949643
# [380]	training's binary_error: 0.00973071	valid_1's binary_error: 0.00945357
# [381]	training's binary_error: 0.009705	valid_1's binary_error: 0.00942143
# [382]	training's binary_error: 0.00968429	valid_1's binary_error: 0.00942143
# [383]	training's binary_error: 0.00965929	valid_1's binary_error: 0.00941071
# [384]	training's binary_error: 0.00963857	valid_1's binary_error: 0.00936429
# [385]	training's binary_error: 0.0096	valid_1's binary_error: 0.00931786
# [386]	training's binary_error: 0.00957143	valid_1's binary_error: 0.00926786
# [387]	training's binary_error: 0.00955714	valid_1's binary_error: 0.00927857
# [388]	training's binary_error: 0.00952929	valid_1's binary_error: 0.00926071
# [389]	training's binary_error: 0.00950357	valid_1's binary_error: 0.00925
# [390]	training's binary_error: 0.00947571	valid_1's binary_error: 0.00921786
# [391]	training's binary_error: 0.009455	valid_1's binary_error: 0.00917857
# [392]	training's binary_error: 0.00942643	valid_1's binary_error: 0.00916429
# [393]	training's binary_error: 0.00940286	valid_1's binary_error: 0.00913571
# [394]	training's binary_error: 0.00938357	valid_1's binary_error: 0.00911429
# [395]	training's binary_error: 0.00936786	valid_1's binary_error: 0.00911429
# [396]	training's binary_error: 0.00933714	valid_1's binary_error: 0.00905714
# [397]	training's binary_error: 0.00931429	valid_1's binary_error: 0.00903571
# [398]	training's binary_error: 0.00929071	valid_1's binary_error: 0.00902143
# [399]	training's binary_error: 0.00928286	valid_1's binary_error: 0.00900357
# [400]	training's binary_error: 0.00924929	valid_1's binary_error: 0.008975
# [401]	training's binary_error: 0.00921929	valid_1's binary_error: 0.00895357
# [402]	training's binary_error: 0.00919571	valid_1's binary_error: 0.00893214
# [403]	training's binary_error: 0.00916929	valid_1's binary_error: 0.00891429
# [404]	training's binary_error: 0.00913929	valid_1's binary_error: 0.00888214
# [405]	training's binary_error: 0.00911786	valid_1's binary_error: 0.00887143
# [406]	training's binary_error: 0.00909714	valid_1's binary_error: 0.00881429
# [407]	training's binary_error: 0.00907786	valid_1's binary_error: 0.0088
# [408]	training's binary_error: 0.00906571	valid_1's binary_error: 0.00878214
# [409]	training's binary_error: 0.00903143	valid_1's binary_error: 0.00875714
# [410]	training's binary_error: 0.00899786	valid_1's binary_error: 0.00871786
# [411]	training's binary_error: 0.00897071	valid_1's binary_error: 0.00870357
# [412]	training's binary_error: 0.00895214	valid_1's binary_error: 0.00867143
# [413]	training's binary_error: 0.00893429	valid_1's binary_error: 0.00863929
# [414]	training's binary_error: 0.00890357	valid_1's binary_error: 0.00861786
# [415]	training's binary_error: 0.00887357	valid_1's binary_error: 0.00857857
# [416]	training's binary_error: 0.00885071	valid_1's binary_error: 0.00856429
# [417]	training's binary_error: 0.00882286	valid_1's binary_error: 0.00851786
# [418]	training's binary_error: 0.00878714	valid_1's binary_error: 0.008475
# [419]	training's binary_error: 0.00877143	valid_1's binary_error: 0.00847143
# [420]	training's binary_error: 0.008755	valid_1's binary_error: 0.00847857
# [421]	training's binary_error: 0.00872	valid_1's binary_error: 0.00844286
# [422]	training's binary_error: 0.00870429	valid_1's binary_error: 0.00842143
# [423]	training's binary_error: 0.00867857	valid_1's binary_error: 0.00840714
# [424]	training's binary_error: 0.008655	valid_1's binary_error: 0.00838571
# [425]	training's binary_error: 0.00863857	valid_1's binary_error: 0.00835714
# [426]	training's binary_error: 0.00861643	valid_1's binary_error: 0.00832857
# [427]	training's binary_error: 0.008595	valid_1's binary_error: 0.00831071
# [428]	training's binary_error: 0.00857143	valid_1's binary_error: 0.00827857
# [429]	training's binary_error: 0.00854357	valid_1's binary_error: 0.00825
# [430]	training's binary_error: 0.00850857	valid_1's binary_error: 0.00821429
# [431]	training's binary_error: 0.00849	valid_1's binary_error: 0.00818571
# [432]	training's binary_error: 0.00847429	valid_1's binary_error: 0.00816786
# [433]	training's binary_error: 0.00845357	valid_1's binary_error: 0.00815357
# [434]	training's binary_error: 0.00842286	valid_1's binary_error: 0.00813214
# [435]	training's binary_error: 0.00840429	valid_1's binary_error: 0.008125
# [436]	training's binary_error: 0.00837643	valid_1's binary_error: 0.0081
# [437]	training's binary_error: 0.00834643	valid_1's binary_error: 0.00808214
# [438]	training's binary_error: 0.00831857	valid_1's binary_error: 0.00805
# [439]	training's binary_error: 0.00829786	valid_1's binary_error: 0.00802143
# [440]	training's binary_error: 0.00827929	valid_1's binary_error: 0.00800357
# [441]	training's binary_error: 0.00826	valid_1's binary_error: 0.008
# [442]	training's binary_error: 0.00824286	valid_1's binary_error: 0.00799286
# [443]	training's binary_error: 0.00821786	valid_1's binary_error: 0.00795
# [444]	training's binary_error: 0.00818714	valid_1's binary_error: 0.00792857
# [445]	training's binary_error: 0.00815857	valid_1's binary_error: 0.00790357
# [446]	training's binary_error: 0.00813	valid_1's binary_error: 0.00789286
# [447]	training's binary_error: 0.00810929	valid_1's binary_error: 0.00786429
# [448]	training's binary_error: 0.00808286	valid_1's binary_error: 0.00782857
# [449]	training's binary_error: 0.00805643	valid_1's binary_error: 0.00782143
# [450]	training's binary_error: 0.00803429	valid_1's binary_error: 0.0078
# [451]	training's binary_error: 0.00802143	valid_1's binary_error: 0.00778214
# [452]	training's binary_error: 0.00800429	valid_1's binary_error: 0.00774643
# [453]	training's binary_error: 0.00797071	valid_1's binary_error: 0.00773571
# [454]	training's binary_error: 0.007955	valid_1's binary_error: 0.007725
# [455]	training's binary_error: 0.00794286	valid_1's binary_error: 0.00771786
# [456]	training's binary_error: 0.00791071	valid_1's binary_error: 0.00771071
# [457]	training's binary_error: 0.007895	valid_1's binary_error: 0.00768929
# [458]	training's binary_error: 0.00786786	valid_1's binary_error: 0.00766071
# [459]	training's binary_error: 0.00784143	valid_1's binary_error: 0.00762143
# [460]	training's binary_error: 0.00780857	valid_1's binary_error: 0.00758929
# [461]	training's binary_error: 0.00778929	valid_1's binary_error: 0.00754643
# [462]	training's binary_error: 0.00776571	valid_1's binary_error: 0.00753929
# [463]	training's binary_error: 0.00774143	valid_1's binary_error: 0.007525
# [464]	training's binary_error: 0.00771143	valid_1's binary_error: 0.00749286
# [465]	training's binary_error: 0.00768286	valid_1's binary_error: 0.00746071
# [466]	training's binary_error: 0.00765214	valid_1's binary_error: 0.00743571
# [467]	training's binary_error: 0.00763643	valid_1's binary_error: 0.007425
# [468]	training's binary_error: 0.00762286	valid_1's binary_error: 0.00741429
# [469]	training's binary_error: 0.00760286	valid_1's binary_error: 0.00739286
# [470]	training's binary_error: 0.00757429	valid_1's binary_error: 0.00737143
# [471]	training's binary_error: 0.00753929	valid_1's binary_error: 0.00734286
# [472]	training's binary_error: 0.007515	valid_1's binary_error: 0.00730714
# [473]	training's binary_error: 0.00749	valid_1's binary_error: 0.00726071
# [474]	training's binary_error: 0.00746714	valid_1's binary_error: 0.007225
# [475]	training's binary_error: 0.00744714	valid_1's binary_error: 0.00721786
# [476]	training's binary_error: 0.007425	valid_1's binary_error: 0.00721429
# [477]	training's binary_error: 0.00741429	valid_1's binary_error: 0.00720357
# [478]	training's binary_error: 0.00739643	valid_1's binary_error: 0.00718571
# [479]	training's binary_error: 0.00737857	valid_1's binary_error: 0.00714643
# [480]	training's binary_error: 0.00734857	valid_1's binary_error: 0.007125
# [481]	training's binary_error: 0.00732571	valid_1's binary_error: 0.00710714
# [482]	training's binary_error: 0.00729929	valid_1's binary_error: 0.00709643
# [483]	training's binary_error: 0.00728357	valid_1's binary_error: 0.00708571
# [484]	training's binary_error: 0.00725929	valid_1's binary_error: 0.00707857
# [485]	training's binary_error: 0.00724	valid_1's binary_error: 0.00705714
# [486]	training's binary_error: 0.00722143	valid_1's binary_error: 0.00704286
# [487]	training's binary_error: 0.00720357	valid_1's binary_error: 0.00702857
# [488]	training's binary_error: 0.00717357	valid_1's binary_error: 0.00700357
# [489]	training's binary_error: 0.00715571	valid_1's binary_error: 0.00698571
# [490]	training's binary_error: 0.00713	valid_1's binary_error: 0.00697857
# [491]	training's binary_error: 0.00711214	valid_1's binary_error: 0.00696429
# [492]	training's binary_error: 0.00709857	valid_1's binary_error: 0.00693929
# [493]	training's binary_error: 0.00708286	valid_1's binary_error: 0.006925
# [494]	training's binary_error: 0.00706214	valid_1's binary_error: 0.00691429
# [495]	training's binary_error: 0.00702929	valid_1's binary_error: 0.00688571
# [496]	training's binary_error: 0.00701071	valid_1's binary_error: 0.00687857
# [497]	training's binary_error: 0.00699357	valid_1's binary_error: 0.00686786
# [498]	training's binary_error: 0.00697357	valid_1's binary_error: 0.00685357
# [499]	training's binary_error: 0.00695214	valid_1's binary_error: 0.00683214
# [500]	training's binary_error: 0.00692214	valid_1's binary_error: 0.00681429
# [501]	training's binary_error: 0.00690286	valid_1's binary_error: 0.00680357
# [502]	training's binary_error: 0.00688	valid_1's binary_error: 0.00677143
# [503]	training's binary_error: 0.006865	valid_1's binary_error: 0.00676071
# [504]	training's binary_error: 0.00683714	valid_1's binary_error: 0.00673929
# [505]	training's binary_error: 0.00681214	valid_1's binary_error: 0.00672857
# [506]	training's binary_error: 0.00679286	valid_1's binary_error: 0.00670714
# [507]	training's binary_error: 0.00677071	valid_1's binary_error: 0.006675
# [508]	training's binary_error: 0.00675571	valid_1's binary_error: 0.00667143
# [509]	training's binary_error: 0.00672714	valid_1's binary_error: 0.00665
# [510]	training's binary_error: 0.00671714	valid_1's binary_error: 0.006625
# [511]	training's binary_error: 0.00669357	valid_1's binary_error: 0.00658571
# [512]	training's binary_error: 0.00667286	valid_1's binary_error: 0.00655357
# [513]	training's binary_error: 0.00665214	valid_1's binary_error: 0.00653571
# [514]	training's binary_error: 0.00663714	valid_1's binary_error: 0.00652857
# [515]	training's binary_error: 0.00661786	valid_1's binary_error: 0.00651071
# [516]	training's binary_error: 0.00659786	valid_1's binary_error: 0.00648571
# [517]	training's binary_error: 0.00657571	valid_1's binary_error: 0.00646786
# [518]	training's binary_error: 0.006555	valid_1's binary_error: 0.00643929
# [519]	training's binary_error: 0.00653643	valid_1's binary_error: 0.00641429
# [520]	training's binary_error: 0.00651286	valid_1's binary_error: 0.0064
# [521]	training's binary_error: 0.00649143	valid_1's binary_error: 0.00638571
# [522]	training's binary_error: 0.00646143	valid_1's binary_error: 0.00635714
# [523]	training's binary_error: 0.00643643	valid_1's binary_error: 0.00632857
# [524]	training's binary_error: 0.00640857	valid_1's binary_error: 0.0063
# [525]	training's binary_error: 0.00638643	valid_1's binary_error: 0.00626071
# [526]	training's binary_error: 0.00636214	valid_1's binary_error: 0.00625357
# [527]	training's binary_error: 0.00633357	valid_1's binary_error: 0.00623214
# [528]	training's binary_error: 0.00631357	valid_1's binary_error: 0.00622143
# [529]	training's binary_error: 0.00629714	valid_1's binary_error: 0.00620357
# [530]	training's binary_error: 0.00628643	valid_1's binary_error: 0.00620357
# [531]	training's binary_error: 0.00626214	valid_1's binary_error: 0.00619643
# [532]	training's binary_error: 0.00624	valid_1's binary_error: 0.00618214
# [533]	training's binary_error: 0.00621786	valid_1's binary_error: 0.00615357
# [534]	training's binary_error: 0.00621143	valid_1's binary_error: 0.00615357
# [535]	training's binary_error: 0.00619571	valid_1's binary_error: 0.00612857
# [536]	training's binary_error: 0.00617857	valid_1's binary_error: 0.00612143
# [537]	training's binary_error: 0.00616786	valid_1's binary_error: 0.00611786
# [538]	training's binary_error: 0.00614071	valid_1's binary_error: 0.00608929
# [539]	training's binary_error: 0.00611429	valid_1's binary_error: 0.006075
# [540]	training's binary_error: 0.00609786	valid_1's binary_error: 0.00605714
# [541]	training's binary_error: 0.00607786	valid_1's binary_error: 0.00602143
# [542]	training's binary_error: 0.00605357	valid_1's binary_error: 0.00599643
# [543]	training's binary_error: 0.00603571	valid_1's binary_error: 0.00597143
# [544]	training's binary_error: 0.00601214	valid_1's binary_error: 0.00594286
# [545]	training's binary_error: 0.00599071	valid_1's binary_error: 0.00591071
# [546]	training's binary_error: 0.00597214	valid_1's binary_error: 0.00588571
# [547]	training's binary_error: 0.00595857	valid_1's binary_error: 0.00588571
# [548]	training's binary_error: 0.00594643	valid_1's binary_error: 0.00586786
# [549]	training's binary_error: 0.00593071	valid_1's binary_error: 0.00585357
# [550]	training's binary_error: 0.00591857	valid_1's binary_error: 0.00581786
# [551]	training's binary_error: 0.00589571	valid_1's binary_error: 0.00579643
# [552]	training's binary_error: 0.00587571	valid_1's binary_error: 0.00579286
# [553]	training's binary_error: 0.00585357	valid_1's binary_error: 0.005775
# [554]	training's binary_error: 0.00583071	valid_1's binary_error: 0.00576786
# [555]	training's binary_error: 0.00581143	valid_1's binary_error: 0.00574643
# [556]	training's binary_error: 0.00580786	valid_1's binary_error: 0.00573571
# [557]	training's binary_error: 0.00579143	valid_1's binary_error: 0.00571071
# [558]	training's binary_error: 0.00577286	valid_1's binary_error: 0.00569286
# [559]	training's binary_error: 0.00575429	valid_1's binary_error: 0.00566786
# [560]	training's binary_error: 0.00573643	valid_1's binary_error: 0.00564286
# [561]	training's binary_error: 0.005715	valid_1's binary_error: 0.00560714
# [562]	training's binary_error: 0.00569	valid_1's binary_error: 0.00558571
# [563]	training's binary_error: 0.005675	valid_1's binary_error: 0.005575
# [564]	training's binary_error: 0.00565714	valid_1's binary_error: 0.00555357
# [565]	training's binary_error: 0.00563571	valid_1's binary_error: 0.00554643
# [566]	training's binary_error: 0.00562214	valid_1's binary_error: 0.00553214
# [567]	training's binary_error: 0.00560143	valid_1's binary_error: 0.00551429
# [568]	training's binary_error: 0.00557929	valid_1's binary_error: 0.00549286
# [569]	training's binary_error: 0.00556714	valid_1's binary_error: 0.005475
# [570]	training's binary_error: 0.00554571	valid_1's binary_error: 0.00545357
# [571]	training's binary_error: 0.00552071	valid_1's binary_error: 0.00542143
# [572]	training's binary_error: 0.0055	valid_1's binary_error: 0.00538571
# [573]	training's binary_error: 0.00548286	valid_1's binary_error: 0.00536786
# [574]	training's binary_error: 0.00546429	valid_1's binary_error: 0.00535
# [575]	training's binary_error: 0.00544357	valid_1's binary_error: 0.00532143
# [576]	training's binary_error: 0.00541929	valid_1's binary_error: 0.00529286
# [577]	training's binary_error: 0.00540857	valid_1's binary_error: 0.00527857
# [578]	training's binary_error: 0.005405	valid_1's binary_error: 0.00526786
# [579]	training's binary_error: 0.00539	valid_1's binary_error: 0.00525714
# [580]	training's binary_error: 0.00536714	valid_1's binary_error: 0.00524286
# [581]	training's binary_error: 0.00535786	valid_1's binary_error: 0.00524286
# [582]	training's binary_error: 0.00533714	valid_1's binary_error: 0.00523571
# [583]	training's binary_error: 0.00532214	valid_1's binary_error: 0.00521429
# [584]	training's binary_error: 0.00530571	valid_1's binary_error: 0.00519643
# [585]	training's binary_error: 0.00528714	valid_1's binary_error: 0.00517857
# [586]	training's binary_error: 0.00526857	valid_1's binary_error: 0.00515714
# [587]	training's binary_error: 0.00525143	valid_1's binary_error: 0.00512143
# [588]	training's binary_error: 0.00523429	valid_1's binary_error: 0.00511071
# [589]	training's binary_error: 0.00521857	valid_1's binary_error: 0.00510714
# [590]	training's binary_error: 0.00520071	valid_1's binary_error: 0.00510357
# [591]	training's binary_error: 0.00518429	valid_1's binary_error: 0.00508929
# [592]	training's binary_error: 0.00516929	valid_1's binary_error: 0.005075
# [593]	training's binary_error: 0.00515571	valid_1's binary_error: 0.00506786
# [594]	training's binary_error: 0.00514286	valid_1's binary_error: 0.00505714
# [595]	training's binary_error: 0.00512857	valid_1's binary_error: 0.00505357
# [596]	training's binary_error: 0.00510286	valid_1's binary_error: 0.00502143
# [597]	training's binary_error: 0.00509	valid_1's binary_error: 0.00500357
# [598]	training's binary_error: 0.00507357	valid_1's binary_error: 0.00499643
# [599]	training's binary_error: 0.00506071	valid_1's binary_error: 0.00498929
# [600]	training's binary_error: 0.00505143	valid_1's binary_error: 0.00497857
# [601]	training's binary_error: 0.00502286	valid_1's binary_error: 0.00494286
# [602]	training's binary_error: 0.00500571	valid_1's binary_error: 0.00492857
# [603]	training's binary_error: 0.004985	valid_1's binary_error: 0.0049
# [604]	training's binary_error: 0.00496857	valid_1's binary_error: 0.00488929
# [605]	training's binary_error: 0.00494786	valid_1's binary_error: 0.00487143
# [606]	training's binary_error: 0.00493643	valid_1's binary_error: 0.00485
# [607]	training's binary_error: 0.00492286	valid_1's binary_error: 0.00484286
# [608]	training's binary_error: 0.00490143	valid_1's binary_error: 0.00481786
# [609]	training's binary_error: 0.00488357	valid_1's binary_error: 0.00480357
# [610]	training's binary_error: 0.00486429	valid_1's binary_error: 0.00478929
# [611]	training's binary_error: 0.00484357	valid_1's binary_error: 0.00476071
# [612]	training's binary_error: 0.00482214	valid_1's binary_error: 0.00473929
# [613]	training's binary_error: 0.00480857	valid_1's binary_error: 0.00471429
# [614]	training's binary_error: 0.00478571	valid_1's binary_error: 0.00469286
# [615]	training's binary_error: 0.00476786	valid_1's binary_error: 0.004675
# [616]	training's binary_error: 0.00475071	valid_1's binary_error: 0.00466071
# [617]	training's binary_error: 0.00474071	valid_1's binary_error: 0.00465
# [618]	training's binary_error: 0.00472571	valid_1's binary_error: 0.00463571
# [619]	training's binary_error: 0.00471286	valid_1's binary_error: 0.00463571
# [620]	training's binary_error: 0.004695	valid_1's binary_error: 0.00462143
# [621]	training's binary_error: 0.00468214	valid_1's binary_error: 0.00459643
# [622]	training's binary_error: 0.00465929	valid_1's binary_error: 0.00457143
# [623]	training's binary_error: 0.00463643	valid_1's binary_error: 0.00454643
# [624]	training's binary_error: 0.00461857	valid_1's binary_error: 0.00452143
# [625]	training's binary_error: 0.00460857	valid_1's binary_error: 0.00451786
# [626]	training's binary_error: 0.00458714	valid_1's binary_error: 0.00447857
# [627]	training's binary_error: 0.00456643	valid_1's binary_error: 0.00445
# [628]	training's binary_error: 0.00454786	valid_1's binary_error: 0.00444643
# [629]	training's binary_error: 0.00453571	valid_1's binary_error: 0.00443929
# ...
# [2065]	training's binary_error: 8.42857e-05	valid_1's binary_error: 5.71429e-05
# [2066]	training's binary_error: 8.42857e-05	valid_1's binary_error: 5.71429e-05
# [2067]	training's binary_error: 8.42857e-05	valid_1's binary_error: 5.71429e-05
# [2068]	training's binary_error: 8.21429e-05	valid_1's binary_error: 5.35714e-05
# [2069]	training's binary_error: 8.21429e-05	valid_1's binary_error: 5.35714e-05
# [2070]	training's binary_error: 8.21429e-05	valid_1's binary_error: 5.35714e-05
# [2071]	training's binary_error: 8.21429e-05	valid_1's binary_error: 5.35714e-05
# [2072]	training's binary_error: 8.14286e-05	valid_1's binary_error: 5.35714e-05
# [2073]	training's binary_error: 8.14286e-05	valid_1's binary_error: 5.35714e-05
# [2074]	training's binary_error: 8.14286e-05	valid_1's binary_error: 5.35714e-05
# [2075]	training's binary_error: 8.14286e-05	valid_1's binary_error: 5.35714e-05
# [2076]	training's binary_error: 8.14286e-05	valid_1's binary_error: 5.35714e-05
# [2077]	training's binary_error: 8.14286e-05	valid_1's binary_error: 5.35714e-05
# [2078]	training's binary_error: 8.14286e-05	valid_1's binary_error: 5.35714e-05
# [2079]	training's binary_error: 8.14286e-05	valid_1's binary_error: 5.35714e-05
# [2080]	training's binary_error: 8.14286e-05	valid_1's binary_error: 5.35714e-05
# [2081]	training's binary_error: 8.07143e-05	valid_1's binary_error: 5.35714e-05
# [2082]	training's binary_error: 8.07143e-05	valid_1's binary_error: 5.35714e-05
# [2083]	training's binary_error: 8.07143e-05	valid_1's binary_error: 5.35714e-05
# [2084]	training's binary_error: 8.07143e-05	valid_1's binary_error: 5.35714e-05
# [2085]	training's binary_error: 8.07143e-05	valid_1's binary_error: 5.35714e-05
# [2086]	training's binary_error: 8.14286e-05	valid_1's binary_error: 5.35714e-05
# [2087]	training's binary_error: 8.14286e-05	valid_1's binary_error: 5.35714e-05
# [2088]	training's binary_error: 8.14286e-05	valid_1's binary_error: 5.35714e-05
# [2089]	training's binary_error: 8.07143e-05	valid_1's binary_error: 5.35714e-05
# [2090]	training's binary_error: 7.85714e-05	valid_1's binary_error: 5e-05
# [2091]	training's binary_error: 7.85714e-05	valid_1's binary_error: 5e-05
# [2092]	training's binary_error: 7.78571e-05	valid_1's binary_error: 5e-05
# [2093]	training's binary_error: 7.78571e-05	valid_1's binary_error: 5e-05
# [2094]	training's binary_error: 7.78571e-05	valid_1's binary_error: 5e-05
# [2095]	training's binary_error: 7.71429e-05	valid_1's binary_error: 5e-05
# [2096]	training's binary_error: 7.71429e-05	valid_1's binary_error: 5e-05
# [2097]	training's binary_error: 7.71429e-05	valid_1's binary_error: 5e-05
# [2098]	training's binary_error: 7.71429e-05	valid_1's binary_error: 5e-05
# [2099]	training's binary_error: 7.71429e-05	valid_1's binary_error: 5e-05
# [2100]	training's binary_error: 7.71429e-05	valid_1's binary_error: 5e-05
# [2101]	training's binary_error: 7.64286e-05	valid_1's binary_error: 4.64286e-05
# [2102]	training's binary_error: 7.71429e-05	valid_1's binary_error: 5e-05
# [2103]	training's binary_error: 7.64286e-05	valid_1's binary_error: 4.64286e-05
# [2104]	training's binary_error: 7.64286e-05	valid_1's binary_error: 4.64286e-05
# [2105]	training's binary_error: 7.71429e-05	valid_1's binary_error: 5e-05
# [2106]	training's binary_error: 7.57143e-05	valid_1's binary_error: 5e-05
# [2107]	training's binary_error: 7.57143e-05	valid_1's binary_error: 5e-05
# [2108]	training's binary_error: 7.57143e-05	valid_1's binary_error: 5e-05
# [2109]	training's binary_error: 7.57143e-05	valid_1's binary_error: 5e-05
# [2110]	training's binary_error: 7.57143e-05	valid_1's binary_error: 5e-05
# [2111]	training's binary_error: 7.57143e-05	valid_1's binary_error: 5e-05
# [2112]	training's binary_error: 7.57143e-05	valid_1's binary_error: 5e-05
# [2113]	training's binary_error: 7.57143e-05	valid_1's binary_error: 5e-05
# [2114]	training's binary_error: 7.57143e-05	valid_1's binary_error: 5e-05
# [2115]	training's binary_error: 7.57143e-05	valid_1's binary_error: 5e-05
# [2116]	training's binary_error: 7.42857e-05	valid_1's binary_error: 5e-05
# [2117]	training's binary_error: 7.42857e-05	valid_1's binary_error: 5e-05
# [2118]	training's binary_error: 7.5e-05	valid_1's binary_error: 5e-05
# [2119]	training's binary_error: 7.5e-05	valid_1's binary_error: 5e-05
# [2120]	training's binary_error: 7.35714e-05	valid_1's binary_error: 4.64286e-05
# [2121]	training's binary_error: 7.42857e-05	valid_1's binary_error: 4.64286e-05
# [2122]	training's binary_error: 7.42857e-05	valid_1's binary_error: 4.64286e-05
# [2123]	training's binary_error: 7.42857e-05	valid_1's binary_error: 4.64286e-05
# [2124]	training's binary_error: 7.42857e-05	valid_1's binary_error: 4.64286e-05
# [2125]	training's binary_error: 7.35714e-05	valid_1's binary_error: 4.64286e-05
# [2126]	training's binary_error: 7.35714e-05	valid_1's binary_error: 4.64286e-05
# [2127]	training's binary_error: 7.35714e-05	valid_1's binary_error: 4.64286e-05
# [2128]	training's binary_error: 7.35714e-05	valid_1's binary_error: 4.64286e-05
# [2129]	training's binary_error: 7.35714e-05	valid_1's binary_error: 4.64286e-05
# [2130]	training's binary_error: 7.35714e-05	valid_1's binary_error: 4.64286e-05
# [2131]	training's binary_error: 7.35714e-05	valid_1's binary_error: 4.64286e-05
# [2132]	training's binary_error: 7.28571e-05	valid_1's binary_error: 4.64286e-05
# [2133]	training's binary_error: 7.21429e-05	valid_1's binary_error: 4.64286e-05
# [2134]	training's binary_error: 7.21429e-05	valid_1's binary_error: 4.64286e-05
# [2135]	training's binary_error: 7.21429e-05	valid_1's binary_error: 4.64286e-05
# [2136]	training's binary_error: 7.14286e-05	valid_1's binary_error: 5e-05
# [2137]	training's binary_error: 7.14286e-05	valid_1's binary_error: 5e-05
# [2138]	training's binary_error: 7.14286e-05	valid_1's binary_error: 5e-05
# [2139]	training's binary_error: 7.14286e-05	valid_1's binary_error: 5e-05
# [2140]	training's binary_error: 7.14286e-05	valid_1's binary_error: 5e-05
# [2141]	training's binary_error: 7.14286e-05	valid_1's binary_error: 5e-05
# [2142]	training's binary_error: 7.14286e-05	valid_1's binary_error: 5e-05
# [2143]	training's binary_error: 6.85714e-05	valid_1's binary_error: 4.64286e-05
# [2144]	training's binary_error: 6.85714e-05	valid_1's binary_error: 4.64286e-05
# [2145]	training's binary_error: 6.85714e-05	valid_1's binary_error: 4.64286e-05
# [2146]	training's binary_error: 6.85714e-05	valid_1's binary_error: 4.64286e-05
# [2147]	training's binary_error: 6.85714e-05	valid_1's binary_error: 4.64286e-05
# [2148]	training's binary_error: 6.85714e-05	valid_1's binary_error: 4.64286e-05
# [2149]	training's binary_error: 6.85714e-05	valid_1's binary_error: 4.64286e-05
# [2150]	training's binary_error: 6.85714e-05	valid_1's binary_error: 4.64286e-05
# [2151]	training's binary_error: 6.78571e-05	valid_1's binary_error: 4.28571e-05
# [2152]	training's binary_error: 6.78571e-05	valid_1's binary_error: 4.28571e-05
# [2153]	training's binary_error: 6.78571e-05	valid_1's binary_error: 4.28571e-05
# [2154]	training's binary_error: 6.85714e-05	valid_1's binary_error: 4.28571e-05
# [2155]	training's binary_error: 6.85714e-05	valid_1's binary_error: 4.28571e-05
# [2156]	training's binary_error: 6.78571e-05	valid_1's binary_error: 4.28571e-05
# [2157]	training's binary_error: 6.78571e-05	valid_1's binary_error: 4.28571e-05
# [2158]	training's binary_error: 6.78571e-05	valid_1's binary_error: 4.28571e-05
# [2159]	training's binary_error: 6.78571e-05	valid_1's binary_error: 4.28571e-05
# [2160]	training's binary_error: 6.71429e-05	valid_1's binary_error: 3.92857e-05
# [2161]	training's binary_error: 6.71429e-05	valid_1's binary_error: 3.92857e-05
# [2162]	training's binary_error: 6.71429e-05	valid_1's binary_error: 3.92857e-05
# [2163]	training's binary_error: 6.71429e-05	valid_1's binary_error: 3.92857e-05
# [2164]	training's binary_error: 6.71429e-05	valid_1's binary_error: 3.92857e-05
# [2165]	training's binary_error: 6.64286e-05	valid_1's binary_error: 3.92857e-05
# [2166]	training's binary_error: 6.64286e-05	valid_1's binary_error: 3.92857e-05
# [2167]	training's binary_error: 6.57143e-05	valid_1's binary_error: 3.92857e-05
# [2168]	training's binary_error: 6.57143e-05	valid_1's binary_error: 3.92857e-05
# [2169]	training's binary_error: 6.57143e-05	valid_1's binary_error: 3.92857e-05
# [2170]	training's binary_error: 6.57143e-05	valid_1's binary_error: 3.92857e-05
# [2171]	training's binary_error: 6.5e-05	valid_1's binary_error: 3.92857e-05
# [2172]	training's binary_error: 6.5e-05	valid_1's binary_error: 3.92857e-05
# [2173]	training's binary_error: 6.5e-05	valid_1's binary_error: 3.92857e-05
# [2174]	training's binary_error: 6.5e-05	valid_1's binary_error: 3.92857e-05
# [2175]	training's binary_error: 6.5e-05	valid_1's binary_error: 3.92857e-05
# [2176]	training's binary_error: 6.5e-05	valid_1's binary_error: 3.92857e-05
# [2177]	training's binary_error: 6.57143e-05	valid_1's binary_error: 3.92857e-05
# [2178]	training's binary_error: 6.42857e-05	valid_1's binary_error: 3.92857e-05
# [2179]	training's binary_error: 6.42857e-05	valid_1's binary_error: 3.92857e-05
# [2180]	training's binary_error: 6.42857e-05	valid_1's binary_error: 3.92857e-05
# [2181]	training's binary_error: 6.5e-05	valid_1's binary_error: 3.92857e-05
# [2182]	training's binary_error: 6.5e-05	valid_1's binary_error: 3.92857e-05
# [2183]	training's binary_error: 6.5e-05	valid_1's binary_error: 3.92857e-05
# [2184]	training's binary_error: 6.5e-05	valid_1's binary_error: 3.92857e-05
# [2185]	training's binary_error: 6.5e-05	valid_1's binary_error: 3.92857e-05
# [2186]	training's binary_error: 6.5e-05	valid_1's binary_error: 3.92857e-05
# [2187]	training's binary_error: 6.42857e-05	valid_1's binary_error: 3.92857e-05
# [2188]	training's binary_error: 6.42857e-05	valid_1's binary_error: 3.92857e-05
# [2189]	training's binary_error: 6.42857e-05	valid_1's binary_error: 3.92857e-05
# [2190]	training's binary_error: 6.42857e-05	valid_1's binary_error: 3.92857e-05
# [2191]	training's binary_error: 6.42857e-05	valid_1's binary_error: 3.92857e-05
# [2192]	training's binary_error: 6.28571e-05	valid_1's binary_error: 3.92857e-05
# [2193]	training's binary_error: 6.28571e-05	valid_1's binary_error: 3.92857e-05
# [2194]	training's binary_error: 6.28571e-05	valid_1's binary_error: 3.92857e-05
# [2195]	training's binary_error: 6.28571e-05	valid_1's binary_error: 3.92857e-05
# [2196]	training's binary_error: 6.28571e-05	valid_1's binary_error: 3.92857e-05
# [2197]	training's binary_error: 6.28571e-05	valid_1's binary_error: 3.92857e-05
# [2198]	training's binary_error: 6.21429e-05	valid_1's binary_error: 3.92857e-05
# [2199]	training's binary_error: 6.28571e-05	valid_1's binary_error: 3.92857e-05
# [2200]	training's binary_error: 6.28571e-05	valid_1's binary_error: 3.92857e-05
# [2201]	training's binary_error: 6.28571e-05	valid_1's binary_error: 3.92857e-05
# [2202]	training's binary_error: 6.21429e-05	valid_1's binary_error: 3.92857e-05
# [2203]	training's binary_error: 6.14286e-05	valid_1's binary_error: 3.92857e-05
# [2204]	training's binary_error: 6.14286e-05	valid_1's binary_error: 3.92857e-05
# [2205]	training's binary_error: 6.14286e-05	valid_1's binary_error: 3.92857e-05
# [2206]	training's binary_error: 6.14286e-05	valid_1's binary_error: 3.92857e-05
# [2207]	training's binary_error: 6.14286e-05	valid_1's binary_error: 3.92857e-05
# [2208]	training's binary_error: 6.07143e-05	valid_1's binary_error: 3.92857e-05
# [2209]	training's binary_error: 6.07143e-05	valid_1's binary_error: 3.92857e-05
# [2210]	training's binary_error: 6.07143e-05	valid_1's binary_error: 3.92857e-05
# [2211]	training's binary_error: 6.07143e-05	valid_1's binary_error: 3.92857e-05
# [2212]	training's binary_error: 6.07143e-05	valid_1's binary_error: 3.92857e-05
# [2213]	training's binary_error: 6.07143e-05	valid_1's binary_error: 3.92857e-05
# [2214]	training's binary_error: 6e-05	valid_1's binary_error: 3.92857e-05
# [2215]	training's binary_error: 6e-05	valid_1's binary_error: 3.92857e-05
# [2216]	training's binary_error: 5.92857e-05	valid_1's binary_error: 3.92857e-05
# [2217]	training's binary_error: 5.92857e-05	valid_1's binary_error: 3.92857e-05
# [2218]	training's binary_error: 5.92857e-05	valid_1's binary_error: 3.92857e-05
# [2219]	training's binary_error: 5.92857e-05	valid_1's binary_error: 3.92857e-05
# [2220]	training's binary_error: 5.92857e-05	valid_1's binary_error: 3.92857e-05
# [2221]	training's binary_error: 5.92857e-05	valid_1's binary_error: 3.92857e-05
# [2222]	training's binary_error: 5.92857e-05	valid_1's binary_error: 3.92857e-05
# [2223]	training's binary_error: 5.85714e-05	valid_1's binary_error: 3.92857e-05
# [2224]	training's binary_error: 5.85714e-05	valid_1's binary_error: 3.92857e-05
# [2225]	training's binary_error: 5.85714e-05	valid_1's binary_error: 3.92857e-05
# [2226]	training's binary_error: 5.78571e-05	valid_1's binary_error: 3.92857e-05
# [2227]	training's binary_error: 5.71429e-05	valid_1's binary_error: 3.92857e-05
# [2228]	training's binary_error: 5.71429e-05	valid_1's binary_error: 3.92857e-05
# [2229]	training's binary_error: 5.71429e-05	valid_1's binary_error: 3.92857e-05
# [2230]	training's binary_error: 5.71429e-05	valid_1's binary_error: 3.92857e-05
# [2231]	training's binary_error: 5.71429e-05	valid_1's binary_error: 3.92857e-05
# [2232]	training's binary_error: 5.71429e-05	valid_1's binary_error: 3.92857e-05
# [2233]	training's binary_error: 5.71429e-05	valid_1's binary_error: 3.92857e-05
# [2234]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2235]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2236]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2237]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2238]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2239]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2240]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2241]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2242]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2243]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2244]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2245]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2246]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2247]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2248]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2249]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2250]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2251]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2252]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2253]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2254]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2255]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2256]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2257]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2258]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2259]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# [2260]	training's binary_error: 5.64286e-05	valid_1's binary_error: 3.92857e-05
# Early stopping, best iteration is:
# [2160]	training's binary_error: 6.71429e-05	valid_1's binary_error: 3.92857e-05
# LGBMClassifier(bagging_fraction=0.934931341887986, bagging_freq=1,
#                feature_fraction=0.9512028862422643,
#                lambda_l1=1.20240655708393e-08, lambda_l2=0.1148043434213944,
#                learning_rate=0.020071584253295194, max_depth=53,
#                metric='binary_error', min_child_samples=29, n_estimators=3288,
#                num_leaves=512, objective='binary', verbosity=-1)

# %%
train_pri1 = gbm.predict_proba(train_data)[:,-1]
train_pri1 = pd.DataFrame(train_pri1,columns=['flag'])
train_pri1.to_csv('C:/Users/Lenovo/Desktop/train/train_lgb_1.csv',index = False)

# %%
ind_pri1 = gbm.predict_proba(test_data)[:,-1]
ind_pri1 = pd.DataFrame(ind_pri1,columns=['flag'])
ind_pri1.to_csv('C:/Users/Lenovo/Desktop/train/prob_lgb_1.csv',index = False)

# %% [markdown]
# # lgb_2(+focal loss)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np
import lightgbm
import os
from datetime import timedelta
from datetime import datetime
from dateutil.relativedelta import relativedelta
from scipy.misc import derivative
import warnings
warnings.filterwarnings('ignore')

# %%
# focal loss 损失函数
def focal_loss_lgb_sk(y_true, y_pred, alpha, gamma):
   
    a,g = alpha, gamma
    def fl(x,t):
        p = 1/(1+np.exp(-x))
        return -( a*t + (1-a)*(1-t) ) * (( 1 - ( t*p + (1-t)*(1-p)) )**g) * ( t*np.log(p)+(1-t)*np.log(1-p) )
    partial_fl = lambda x: fl(x, y_true)
    grad = derivative(partial_fl, y_pred, n=1, dx=1e-6)
    hess = derivative(partial_fl, y_pred, n=2, dx=1e-6)
    return grad, hess

# focal loss 对应的评估函数metric
def focal_loss_lgb_eval_error_sk(y_true, y_pred, alpha, gamma):
    
    a,g = alpha, gamma
    p = 1/(1+np.exp(-y_pred))
    loss = -( a*y_true + (1-a)*(1-y_true) ) * (( 1 - ( y_true*p + (1-y_true)*(1-p)) )**g) * ( y_true*np.log(p)+(1-y_true)*np.log(1-p) )
    return 'focal_loss', np.mean(loss), False

def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
focal_loss = lambda x,y: focal_loss_lgb_sk(x, y, alpha = 0.4, gamma = 2)

# %%
focal_eval = lambda y_ture,y_pred: focal_loss_lgb_eval_error_sk(y_true, y_pred, alpha=0.4, gamma = 2)

# %%
parameters={
            'objective': focal_loss,
            'metric': None,
            'verbosity': -1,
            'boosting_type': 'gbdt',
            'lambda_l1': 1.20240655708393e-08, 
            'lambda_l2': 0.1148043434213944, 
            'num_leaves': 512, 
            'learning_rate': 0.020071584253295194, 
            'n_estimators': 7000, 
            'feature_fraction': 0.9512028862422643, 
            'bagging_fraction': 0.934931341887986, 
            'bagging_freq': 1, 
            'min_child_samples': 29,
            'max_depth':53
            }

# %%
gbm = lgb.LGBMClassifier(**parameters)

# %%
gbm.fit(X, y,eval_set=[(X,y),(X_test,y_test)],
        eval_metric=lambda y_true, y_pred: [focal_loss_lgb_eval_error_sk(y_true, y_pred, alpha=0.4, gamma = 2)],
        early_stopping_rounds=100)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9512028862422643, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9512028862422643
# [LightGBM] [Warning] lambda_l1 is set=1.20240655708393e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.20240655708393e-08
# [LightGBM] [Warning] bagging_fraction is set=0.934931341887986, subsample=1.0 will be ignored. Current value: bagging_fraction=0.934931341887986
# [LightGBM] [Warning] lambda_l2 is set=0.1148043434213944, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1148043434213944
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [1]	training's binary_logloss: 2.578	training's focal_loss: 0.0845976	valid_1's binary_logloss: 2.58388	valid_1's focal_loss: 0.0845984
# Training until validation scores don't improve for 100 rounds
# [2]	training's binary_logloss: 2.1995	training's focal_loss: 0.0826123	valid_1's binary_logloss: 2.19918	valid_1's focal_loss: 0.0826127
# [3]	training's binary_logloss: 1.97046	training's focal_loss: 0.0806819	valid_1's binary_logloss: 1.96899	valid_1's focal_loss: 0.0806815
# [4]	training's binary_logloss: 1.82643	training's focal_loss: 0.07881	valid_1's binary_logloss: 1.82052	valid_1's focal_loss: 0.0788093
# [5]	training's binary_logloss: 1.71087	training's focal_loss: 0.0769899	valid_1's binary_logloss: 1.708	valid_1's focal_loss: 0.0769891
# [6]	training's binary_logloss: 1.61766	training's focal_loss: 0.0752216	valid_1's binary_logloss: 1.61678	valid_1's focal_loss: 0.0752205
# [7]	training's binary_logloss: 1.53746	training's focal_loss: 0.073502	valid_1's binary_logloss: 1.53883	valid_1's focal_loss: 0.0735008
# [8]	training's binary_logloss: 1.46438	training's focal_loss: 0.0718317	valid_1's binary_logloss: 1.46167	valid_1's focal_loss: 0.0718306
# [9]	training's binary_logloss: 1.39927	training's focal_loss: 0.0702083	valid_1's binary_logloss: 1.39515	valid_1's focal_loss: 0.070207
# [10]	training's binary_logloss: 1.34064	training's focal_loss: 0.0686288	valid_1's binary_logloss: 1.33749	valid_1's focal_loss: 0.0686272
# [11]	training's binary_logloss: 1.28939	training's focal_loss: 0.0670914	valid_1's binary_logloss: 1.28812	valid_1's focal_loss: 0.06709
# [12]	training's binary_logloss: 1.23871	training's focal_loss: 0.0655993	valid_1's binary_logloss: 1.23631	valid_1's focal_loss: 0.0655982
# [13]	training's binary_logloss: 1.19428	training's focal_loss: 0.0641469	valid_1's binary_logloss: 1.19234	valid_1's focal_loss: 0.0641454
# [14]	training's binary_logloss: 1.1523	training's focal_loss: 0.0627325	valid_1's binary_logloss: 1.1525	valid_1's focal_loss: 0.0627319
# [15]	training's binary_logloss: 1.11248	training's focal_loss: 0.0613557	valid_1's binary_logloss: 1.11202	valid_1's focal_loss: 0.0613552
# [16]	training's binary_logloss: 1.07637	training's focal_loss: 0.0600183	valid_1's binary_logloss: 1.07651	valid_1's focal_loss: 0.0600179
# [17]	training's binary_logloss: 1.04164	training's focal_loss: 0.0587169	valid_1's binary_logloss: 1.04157	valid_1's focal_loss: 0.0587165
# [18]	training's binary_logloss: 1.00843	training's focal_loss: 0.057448	valid_1's binary_logloss: 1.00767	valid_1's focal_loss: 0.0574475
# [19]	training's binary_logloss: 0.977273	training's focal_loss: 0.0562153	valid_1's binary_logloss: 0.977253	valid_1's focal_loss: 0.0562146
# [20]	training's binary_logloss: 0.946099	training's focal_loss: 0.0550124	valid_1's binary_logloss: 0.946572	valid_1's focal_loss: 0.055012
# [21]	training's binary_logloss: 0.915876	training's focal_loss: 0.0538426	valid_1's binary_logloss: 0.916665	valid_1's focal_loss: 0.0538417
# [22]	training's binary_logloss: 0.886413	training's focal_loss: 0.0527033	valid_1's binary_logloss: 0.886321	valid_1's focal_loss: 0.0527027
# [23]	training's binary_logloss: 0.860607	training's focal_loss: 0.0515947	valid_1's binary_logloss: 0.860081	valid_1's focal_loss: 0.0515941
# [24]	training's binary_logloss: 0.836484	training's focal_loss: 0.0505143	valid_1's binary_logloss: 0.834732	valid_1's focal_loss: 0.0505135
# [25]	training's binary_logloss: 0.813347	training's focal_loss: 0.0494625	valid_1's binary_logloss: 0.811806	valid_1's focal_loss: 0.0494616
# [26]	training's binary_logloss: 0.790325	training's focal_loss: 0.0484378	valid_1's binary_logloss: 0.788687	valid_1's focal_loss: 0.048437
# [27]	training's binary_logloss: 0.767782	training's focal_loss: 0.0474386	valid_1's binary_logloss: 0.766752	valid_1's focal_loss: 0.0474379
# [28]	training's binary_logloss: 0.746717	training's focal_loss: 0.0464642	valid_1's binary_logloss: 0.746283	valid_1's focal_loss: 0.0464638
# [29]	training's binary_logloss: 0.725838	training's focal_loss: 0.0455144	valid_1's binary_logloss: 0.725013	valid_1's focal_loss: 0.0455144
# [30]	training's binary_logloss: 0.706118	training's focal_loss: 0.0445895	valid_1's binary_logloss: 0.70559	valid_1's focal_loss: 0.0445896
# [31]	training's binary_logloss: 0.687417	training's focal_loss: 0.0436888	valid_1's binary_logloss: 0.687106	valid_1's focal_loss: 0.043689
# [32]	training's binary_logloss: 0.668841	training's focal_loss: 0.0428117	valid_1's binary_logloss: 0.668107	valid_1's focal_loss: 0.0428118
# [33]	training's binary_logloss: 0.65052	training's focal_loss: 0.0419566	valid_1's binary_logloss: 0.650429	valid_1's focal_loss: 0.0419565
# [34]	training's binary_logloss: 0.633379	training's focal_loss: 0.0411232	valid_1's binary_logloss: 0.632976	valid_1's focal_loss: 0.0411228
# [35]	training's binary_logloss: 0.616131	training's focal_loss: 0.0403075	valid_1's binary_logloss: 0.616326	valid_1's focal_loss: 0.0403071
# [36]	training's binary_logloss: 0.598809	training's focal_loss: 0.0395128	valid_1's binary_logloss: 0.598657	valid_1's focal_loss: 0.0395125
# [37]	training's binary_logloss: 0.582909	training's focal_loss: 0.0387393	valid_1's binary_logloss: 0.581808	valid_1's focal_loss: 0.0387388
# [38]	training's binary_logloss: 0.567413	training's focal_loss: 0.0379855	valid_1's binary_logloss: 0.566535	valid_1's focal_loss: 0.0379849
# [39]	training's binary_logloss: 0.552546	training's focal_loss: 0.0372508	valid_1's binary_logloss: 0.55241	valid_1's focal_loss: 0.03725
# [40]	training's binary_logloss: 0.536928	training's focal_loss: 0.0365329	valid_1's binary_logloss: 0.537374	valid_1's focal_loss: 0.0365323
# [41]	training's binary_logloss: 0.521634	training's focal_loss: 0.0358313	valid_1's binary_logloss: 0.521643	valid_1's focal_loss: 0.0358308
# [42]	training's binary_logloss: 0.506936	training's focal_loss: 0.0351481	valid_1's binary_logloss: 0.507152	valid_1's focal_loss: 0.0351474
# [43]	training's binary_logloss: 0.49218	training's focal_loss: 0.0344811	valid_1's binary_logloss: 0.492299	valid_1's focal_loss: 0.0344796
# [44]	training's binary_logloss: 0.479219	training's focal_loss: 0.0338316	valid_1's binary_logloss: 0.479292	valid_1's focal_loss: 0.0338294
# [45]	training's binary_logloss: 0.465634	training's focal_loss: 0.0331973	valid_1's binary_logloss: 0.466521	valid_1's focal_loss: 0.0331952
# [46]	training's binary_logloss: 0.452091	training's focal_loss: 0.0325786	valid_1's binary_logloss: 0.452133	valid_1's focal_loss: 0.0325758
# [47]	training's binary_logloss: 0.439562	training's focal_loss: 0.0319739	valid_1's binary_logloss: 0.440529	valid_1's focal_loss: 0.0319706
# [48]	training's binary_logloss: 0.427012	training's focal_loss: 0.031386	valid_1's binary_logloss: 0.42789	valid_1's focal_loss: 0.0313828
# [49]	training's binary_logloss: 0.414209	training's focal_loss: 0.0308099	valid_1's binary_logloss: 0.41461	valid_1's focal_loss: 0.0308063
# [50]	training's binary_logloss: 0.401925	training's focal_loss: 0.0302484	valid_1's binary_logloss: 0.402357	valid_1's focal_loss: 0.0302448
# [51]	training's binary_logloss: 0.390185	training's focal_loss: 0.0296992	valid_1's binary_logloss: 0.391655	valid_1's focal_loss: 0.0296957
# [52]	training's binary_logloss: 0.377709	training's focal_loss: 0.029162	valid_1's binary_logloss: 0.37798	valid_1's focal_loss: 0.0291583
# [53]	training's binary_logloss: 0.366044	training's focal_loss: 0.0286402	valid_1's binary_logloss: 0.366365	valid_1's focal_loss: 0.0286366
# [54]	training's binary_logloss: 0.354364	training's focal_loss: 0.0281295	valid_1's binary_logloss: 0.354878	valid_1's focal_loss: 0.0281251
# [55]	training's binary_logloss: 0.342934	training's focal_loss: 0.0276309	valid_1's binary_logloss: 0.343399	valid_1's focal_loss: 0.0276257
# [56]	training's binary_logloss: 0.331432	training's focal_loss: 0.0271441	valid_1's binary_logloss: 0.333065	valid_1's focal_loss: 0.0271387
# [57]	training's binary_logloss: 0.320834	training's focal_loss: 0.026669	valid_1's binary_logloss: 0.323001	valid_1's focal_loss: 0.0266634
# [58]	training's binary_logloss: 0.310262	training's focal_loss: 0.026203	valid_1's binary_logloss: 0.312308	valid_1's focal_loss: 0.0261971
# [59]	training's binary_logloss: 0.299723	training's focal_loss: 0.0257482	valid_1's binary_logloss: 0.301293	valid_1's focal_loss: 0.0257419
# [60]	training's binary_logloss: 0.289203	training's focal_loss: 0.0253047	valid_1's binary_logloss: 0.291988	valid_1's focal_loss: 0.0252981
# [61]	training's binary_logloss: 0.279239	training's focal_loss: 0.0248704	valid_1's binary_logloss: 0.281496	valid_1's focal_loss: 0.0248636
# [62]	training's binary_logloss: 0.269159	training's focal_loss: 0.0244451	valid_1's binary_logloss: 0.27013	valid_1's focal_loss: 0.0244377
# [63]	training's binary_logloss: 0.259529	training's focal_loss: 0.024032	valid_1's binary_logloss: 0.262677	valid_1's focal_loss: 0.0240245
# [64]	training's binary_logloss: 0.249908	training's focal_loss: 0.0236282	valid_1's binary_logloss: 0.252932	valid_1's focal_loss: 0.0236201
# [65]	training's binary_logloss: 0.240391	training's focal_loss: 0.023232	valid_1's binary_logloss: 0.243264	valid_1's focal_loss: 0.0232235
# [66]	training's binary_logloss: 0.231336	training's focal_loss: 0.0228446	valid_1's binary_logloss: 0.23406	valid_1's focal_loss: 0.0228358
# [67]	training's binary_logloss: 0.22202	training's focal_loss: 0.0224686	valid_1's binary_logloss: 0.225274	valid_1's focal_loss: 0.0224595
# [68]	training's binary_logloss: 0.213384	training's focal_loss: 0.0221001	valid_1's binary_logloss: 0.216818	valid_1's focal_loss: 0.0220907
# [69]	training's binary_logloss: 0.204852	training's focal_loss: 0.0217401	valid_1's binary_logloss: 0.207243	valid_1's focal_loss: 0.0217305
# [70]	training's binary_logloss: 0.194997	training's focal_loss: 0.0213879	valid_1's binary_logloss: 0.197078	valid_1's focal_loss: 0.0213783
# [71]	training's binary_logloss: 0.187177	training's focal_loss: 0.0210442	valid_1's binary_logloss: 0.188043	valid_1's focal_loss: 0.0210346
# [72]	training's binary_logloss: 0.178597	training's focal_loss: 0.0207079	valid_1's binary_logloss: 0.179726	valid_1's focal_loss: 0.0206981
# [73]	training's binary_logloss: 0.170037	training's focal_loss: 0.0203779	valid_1's binary_logloss: 0.170935	valid_1's focal_loss: 0.0203676
# [74]	training's binary_logloss: 0.16161	training's focal_loss: 0.0200575	valid_1's binary_logloss: 0.162705	valid_1's focal_loss: 0.0200472
# [75]	training's binary_logloss: 0.152911	training's focal_loss: 0.0197432	valid_1's binary_logloss: 0.153775	valid_1's focal_loss: 0.0197328
# [76]	training's binary_logloss: 0.14502	training's focal_loss: 0.0194369	valid_1's binary_logloss: 0.14533	valid_1's focal_loss: 0.0194262
# [77]	training's binary_logloss: 0.137324	training's focal_loss: 0.0191365	valid_1's binary_logloss: 0.137839	valid_1's focal_loss: 0.0191254
# [78]	training's binary_logloss: 0.129501	training's focal_loss: 0.0188425	valid_1's binary_logloss: 0.129279	valid_1's focal_loss: 0.0188312
# [79]	training's binary_logloss: 0.121488	training's focal_loss: 0.018555	valid_1's binary_logloss: 0.122171	valid_1's focal_loss: 0.0185432
# [80]	training's binary_logloss: 0.113946	training's focal_loss: 0.0182733	valid_1's binary_logloss: 0.114214	valid_1's focal_loss: 0.0182614
# [81]	training's binary_logloss: 0.106345	training's focal_loss: 0.0179984	valid_1's binary_logloss: 0.106729	valid_1's focal_loss: 0.017986
# [82]	training's binary_logloss: 0.0981177	training's focal_loss: 0.0177287	valid_1's binary_logloss: 0.0990458	valid_1's focal_loss: 0.0177162
# [83]	training's binary_logloss: 0.090077	training's focal_loss: 0.0174664	valid_1's binary_logloss: 0.0913801	valid_1's focal_loss: 0.0174536
# [84]	training's binary_logloss: 0.0825486	training's focal_loss: 0.0172098	valid_1's binary_logloss: 0.0835694	valid_1's focal_loss: 0.0171961
# [85]	training's binary_logloss: 0.0752068	training's focal_loss: 0.0169587	valid_1's binary_logloss: 0.0757997	valid_1's focal_loss: 0.0169446
# [86]	training's binary_logloss: 0.0685652	training's focal_loss: 0.0167125	valid_1's binary_logloss: 0.0683191	valid_1's focal_loss: 0.0166981
# [87]	training's binary_logloss: 0.062017	training's focal_loss: 0.016471	valid_1's binary_logloss: 0.06255	valid_1's focal_loss: 0.0164562
# [88]	training's binary_logloss: 0.0549888	training's focal_loss: 0.0162359	valid_1's binary_logloss: 0.0554102	valid_1's focal_loss: 0.0162203
# [89]	training's binary_logloss: 0.0480761	training's focal_loss: 0.016007	valid_1's binary_logloss: 0.0477093	valid_1's focal_loss: 0.0159905
# [90]	training's binary_logloss: 0.0413339	training's focal_loss: 0.0157817	valid_1's binary_logloss: 0.0416806	valid_1's focal_loss: 0.0157643
# [91]	training's binary_logloss: 0.0349415	training's focal_loss: 0.0155621	valid_1's binary_logloss: 0.0352752	valid_1's focal_loss: 0.015544
# [92]	training's binary_logloss: 0.0280624	training's focal_loss: 0.0153471	valid_1's binary_logloss: 0.0280456	valid_1's focal_loss: 0.0153285
# [93]	training's binary_logloss: 0.0215623	training's focal_loss: 0.015137	valid_1's binary_logloss: 0.0212088	valid_1's focal_loss: 0.0151185
# [94]	training's binary_logloss: 0.0151178	training's focal_loss: 0.0149306	valid_1's binary_logloss: 0.0149449	valid_1's focal_loss: 0.014912
# [95]	training's binary_logloss: 0.00911739	training's focal_loss: 0.0147285	valid_1's binary_logloss: 0.00897181	valid_1's focal_loss: 0.0147095
# [96]	training's binary_logloss: 0.00269654	training's focal_loss: 0.0145303	valid_1's binary_logloss: 0.00159334	valid_1's focal_loss: 0.0145105
# [97]	training's binary_logloss: -0.00414138	training's focal_loss: 0.0143354	valid_1's binary_logloss: -0.00537065	valid_1's focal_loss: 0.0143157
# [98]	training's binary_logloss: -0.00993417	training's focal_loss: 0.0141461	valid_1's binary_logloss: -0.0114913	valid_1's focal_loss: 0.014126
# [99]	training's binary_logloss: -0.0155906	training's focal_loss: 0.0139616	valid_1's binary_logloss: -0.0178575	valid_1's focal_loss: 0.0139408
# [100]	training's binary_logloss: -0.0214947	training's focal_loss: 0.0137797	valid_1's binary_logloss: -0.0233388	valid_1's focal_loss: 0.0137585
# [101]	training's binary_logloss: -0.0275325	training's focal_loss: 0.0136028	valid_1's binary_logloss: -0.028738	valid_1's focal_loss: 0.0135814
# [102]	training's binary_logloss: -0.0335139	training's focal_loss: 0.0134297	valid_1's binary_logloss: -0.0356196	valid_1's focal_loss: 0.0134078
# [103]	training's binary_logloss: -0.0396436	training's focal_loss: 0.0132594	valid_1's binary_logloss: -0.0413122	valid_1's focal_loss: 0.0132375
# [104]	training's binary_logloss: -0.0455056	training's focal_loss: 0.0130934	valid_1's binary_logloss: -0.0468882	valid_1's focal_loss: 0.013071
# [105]	training's binary_logloss: -0.0510024	training's focal_loss: 0.0129303	valid_1's binary_logloss: -0.0519642	valid_1's focal_loss: 0.0129077
# [106]	training's binary_logloss: -0.0567771	training's focal_loss: 0.0127702	valid_1's binary_logloss: -0.0579293	valid_1's focal_loss: 0.0127476
# [107]	training's binary_logloss: -0.0627202	training's focal_loss: 0.012614	valid_1's binary_logloss: -0.0635166	valid_1's focal_loss: 0.0125913
# [108]	training's binary_logloss: -0.0684866	training's focal_loss: 0.0124606	valid_1's binary_logloss: -0.0690624	valid_1's focal_loss: 0.0124376
# [109]	training's binary_logloss: -0.0742163	training's focal_loss: 0.0123096	valid_1's binary_logloss: -0.0751773	valid_1's focal_loss: 0.0122865
# [110]	training's binary_logloss: -0.0797027	training's focal_loss: 0.0121609	valid_1's binary_logloss: -0.0801376	valid_1's focal_loss: 0.0121379
# [111]	training's binary_logloss: -0.0852253	training's focal_loss: 0.0120154	valid_1's binary_logloss: -0.08557	valid_1's focal_loss: 0.0119916
# [112]	training's binary_logloss: -0.0908409	training's focal_loss: 0.0118744	valid_1's binary_logloss: -0.0908825	valid_1's focal_loss: 0.0118509
# [113]	training's binary_logloss: -0.0954706	training's focal_loss: 0.011735	valid_1's binary_logloss: -0.0956208	valid_1's focal_loss: 0.0117114
# [114]	training's binary_logloss: -0.100231	training's focal_loss: 0.0115994	valid_1's binary_logloss: -0.10075	valid_1's focal_loss: 0.0115758
# [115]	training's binary_logloss: -0.105323	training's focal_loss: 0.0114659	valid_1's binary_logloss: -0.10594	valid_1's focal_loss: 0.0114423
# [116]	training's binary_logloss: -0.110221	training's focal_loss: 0.0113357	valid_1's binary_logloss: -0.111313	valid_1's focal_loss: 0.0113118
# [117]	training's binary_logloss: -0.114846	training's focal_loss: 0.0112066	valid_1's binary_logloss: -0.115603	valid_1's focal_loss: 0.0111828
# [118]	training's binary_logloss: -0.119832	training's focal_loss: 0.0110811	valid_1's binary_logloss: -0.121332	valid_1's focal_loss: 0.0110569
# [119]	training's binary_logloss: -0.125013	training's focal_loss: 0.0109584	valid_1's binary_logloss: -0.125968	valid_1's focal_loss: 0.0109343
# [120]	training's binary_logloss: -0.13005	training's focal_loss: 0.0108374	valid_1's binary_logloss: -0.131398	valid_1's focal_loss: 0.010813
# [121]	training's binary_logloss: -0.135015	training's focal_loss: 0.0107202	valid_1's binary_logloss: -0.136767	valid_1's focal_loss: 0.0106954
# [122]	training's binary_logloss: -0.139703	training's focal_loss: 0.0106062	valid_1's binary_logloss: -0.140873	valid_1's focal_loss: 0.0105814
# [123]	training's binary_logloss: -0.144277	training's focal_loss: 0.0104938	valid_1's binary_logloss: -0.145197	valid_1's focal_loss: 0.0104692
# [124]	training's binary_logloss: -0.149106	training's focal_loss: 0.0103824	valid_1's binary_logloss: -0.149748	valid_1's focal_loss: 0.0103576
# [125]	training's binary_logloss: -0.154045	training's focal_loss: 0.0102742	valid_1's binary_logloss: -0.154585	valid_1's focal_loss: 0.0102496
# [126]	training's binary_logloss: -0.158761	training's focal_loss: 0.0101669	valid_1's binary_logloss: -0.15929	valid_1's focal_loss: 0.0101422
# [127]	training's binary_logloss: -0.163389	training's focal_loss: 0.010062	valid_1's binary_logloss: -0.163848	valid_1's focal_loss: 0.0100372
# [128]	training's binary_logloss: -0.168061	training's focal_loss: 0.00995978	valid_1's binary_logloss: -0.168917	valid_1's focal_loss: 0.00993516
# [129]	training's binary_logloss: -0.172623	training's focal_loss: 0.00985868	valid_1's binary_logloss: -0.172614	valid_1's focal_loss: 0.00983409
# [130]	training's binary_logloss: -0.177242	training's focal_loss: 0.00976024	valid_1's binary_logloss: -0.178131	valid_1's focal_loss: 0.00973584
# [131]	training's binary_logloss: -0.18165	training's focal_loss: 0.00966444	valid_1's binary_logloss: -0.181337	valid_1's focal_loss: 0.00964025
# [132]	training's binary_logloss: -0.185963	training's focal_loss: 0.00956917	valid_1's binary_logloss: -0.1859	valid_1's focal_loss: 0.0095453
# [133]	training's binary_logloss: -0.190825	training's focal_loss: 0.00947618	valid_1's binary_logloss: -0.190812	valid_1's focal_loss: 0.00945216
# [134]	training's binary_logloss: -0.195342	training's focal_loss: 0.00938553	valid_1's binary_logloss: -0.195455	valid_1's focal_loss: 0.00936144
# [135]	training's binary_logloss: -0.199903	training's focal_loss: 0.009295	valid_1's binary_logloss: -0.20024	valid_1's focal_loss: 0.00927143
# [136]	training's binary_logloss: -0.204563	training's focal_loss: 0.00920843	valid_1's binary_logloss: -0.204815	valid_1's focal_loss: 0.0091849
# [137]	training's binary_logloss: -0.208768	training's focal_loss: 0.00912284	valid_1's binary_logloss: -0.208878	valid_1's focal_loss: 0.00909905
# [138]	training's binary_logloss: -0.213439	training's focal_loss: 0.00903908	valid_1's binary_logloss: -0.212939	valid_1's focal_loss: 0.00901553
# [139]	training's binary_logloss: -0.217672	training's focal_loss: 0.0089551	valid_1's binary_logloss: -0.217419	valid_1's focal_loss: 0.0089317
# [140]	training's binary_logloss: -0.222249	training's focal_loss: 0.00887331	valid_1's binary_logloss: -0.222337	valid_1's focal_loss: 0.00884998
# [141]	training's binary_logloss: -0.226506	training's focal_loss: 0.00879391	valid_1's binary_logloss: -0.226908	valid_1's focal_loss: 0.00877052
# [142]	training's binary_logloss: -0.230655	training's focal_loss: 0.00871533	valid_1's binary_logloss: -0.230996	valid_1's focal_loss: 0.00869218
# [143]	training's binary_logloss: -0.234664	training's focal_loss: 0.00863755	valid_1's binary_logloss: -0.234685	valid_1's focal_loss: 0.00861407
# [144]	training's binary_logloss: -0.238441	training's focal_loss: 0.00856077	valid_1's binary_logloss: -0.238916	valid_1's focal_loss: 0.00853717
# [145]	training's binary_logloss: -0.242732	training's focal_loss: 0.00848758	valid_1's binary_logloss: -0.243253	valid_1's focal_loss: 0.00846369
# [146]	training's binary_logloss: -0.246987	training's focal_loss: 0.00841533	valid_1's binary_logloss: -0.247741	valid_1's focal_loss: 0.00839152
# [147]	training's binary_logloss: -0.251148	training's focal_loss: 0.00834079	valid_1's binary_logloss: -0.251924	valid_1's focal_loss: 0.00831703
# [148]	training's binary_logloss: -0.255381	training's focal_loss: 0.00826968	valid_1's binary_logloss: -0.256424	valid_1's focal_loss: 0.00824549
# [149]	training's binary_logloss: -0.259529	training's focal_loss: 0.00820022	valid_1's binary_logloss: -0.261036	valid_1's focal_loss: 0.00817624
# [150]	training's binary_logloss: -0.263766	training's focal_loss: 0.0081312	valid_1's binary_logloss: -0.265105	valid_1's focal_loss: 0.00810706
# [151]	training's binary_logloss: -0.267939	training's focal_loss: 0.0080642	valid_1's binary_logloss: -0.269176	valid_1's focal_loss: 0.00803954
# [152]	training's binary_logloss: -0.271915	training's focal_loss: 0.00799893	valid_1's binary_logloss: -0.272643	valid_1's focal_loss: 0.0079741
# [153]	training's binary_logloss: -0.275518	training's focal_loss: 0.00793404	valid_1's binary_logloss: -0.276022	valid_1's focal_loss: 0.00790919
# [154]	training's binary_logloss: -0.27942	training's focal_loss: 0.00787032	valid_1's binary_logloss: -0.279818	valid_1's focal_loss: 0.00784546
# [155]	training's binary_logloss: -0.283424	training's focal_loss: 0.00780689	valid_1's binary_logloss: -0.283635	valid_1's focal_loss: 0.0077819
# [156]	training's binary_logloss: -0.287048	training's focal_loss: 0.00774649	valid_1's binary_logloss: -0.286998	valid_1's focal_loss: 0.0077215
# [157]	training's binary_logloss: -0.29107	training's focal_loss: 0.00768466	valid_1's binary_logloss: -0.291977	valid_1's focal_loss: 0.00765938
# [158]	training's binary_logloss: -0.294348	training's focal_loss: 0.00762447	valid_1's binary_logloss: -0.294713	valid_1's focal_loss: 0.0075991
# [159]	training's binary_logloss: -0.298117	training's focal_loss: 0.00756613	valid_1's binary_logloss: -0.298983	valid_1's focal_loss: 0.00754109
# [160]	training's binary_logloss: -0.301894	training's focal_loss: 0.00750765	valid_1's binary_logloss: -0.302798	valid_1's focal_loss: 0.00748246
# [161]	training's binary_logloss: -0.306069	training's focal_loss: 0.00745166	valid_1's binary_logloss: -0.306869	valid_1's focal_loss: 0.00742656
# [162]	training's binary_logloss: -0.30973	training's focal_loss: 0.00739561	valid_1's binary_logloss: -0.31035	valid_1's focal_loss: 0.00737101
# [163]	training's binary_logloss: -0.313124	training's focal_loss: 0.00734092	valid_1's binary_logloss: -0.313626	valid_1's focal_loss: 0.00731629
# [164]	training's binary_logloss: -0.317019	training's focal_loss: 0.00728759	valid_1's binary_logloss: -0.3176	valid_1's focal_loss: 0.00726325
# [165]	training's binary_logloss: -0.320594	training's focal_loss: 0.00723531	valid_1's binary_logloss: -0.320609	valid_1's focal_loss: 0.00721076
# [166]	training's binary_logloss: -0.324047	training's focal_loss: 0.00718421	valid_1's binary_logloss: -0.324745	valid_1's focal_loss: 0.00715948
# [167]	training's binary_logloss: -0.32801	training's focal_loss: 0.00713305	valid_1's binary_logloss: -0.328849	valid_1's focal_loss: 0.00710813
# [168]	training's binary_logloss: -0.331863	training's focal_loss: 0.00708358	valid_1's binary_logloss: -0.332226	valid_1's focal_loss: 0.0070583
# [169]	training's binary_logloss: -0.335331	training's focal_loss: 0.00703502	valid_1's binary_logloss: -0.336154	valid_1's focal_loss: 0.00700976
# [170]	training's binary_logloss: -0.338975	training's focal_loss: 0.00698636	valid_1's binary_logloss: -0.340078	valid_1's focal_loss: 0.00696085
# [171]	training's binary_logloss: -0.342491	training's focal_loss: 0.00693905	valid_1's binary_logloss: -0.344108	valid_1's focal_loss: 0.00691382
# [172]	training's binary_logloss: -0.345813	training's focal_loss: 0.00689289	valid_1's binary_logloss: -0.347044	valid_1's focal_loss: 0.00686736
# [173]	training's binary_logloss: -0.349303	training's focal_loss: 0.00684785	valid_1's binary_logloss: -0.351008	valid_1's focal_loss: 0.00682205
# [174]	training's binary_logloss: -0.352784	training's focal_loss: 0.00680304	valid_1's binary_logloss: -0.354494	valid_1's focal_loss: 0.00677723
# [175]	training's binary_logloss: -0.356217	training's focal_loss: 0.00675915	valid_1's binary_logloss: -0.358053	valid_1's focal_loss: 0.00673357
# [176]	training's binary_logloss: -0.359454	training's focal_loss: 0.00671652	valid_1's binary_logloss: -0.361344	valid_1's focal_loss: 0.0066909
# [177]	training's binary_logloss: -0.363307	training's focal_loss: 0.00667272	valid_1's binary_logloss: -0.365233	valid_1's focal_loss: 0.00664665
# [178]	training's binary_logloss: -0.366831	training's focal_loss: 0.00663022	valid_1's binary_logloss: -0.369518	valid_1's focal_loss: 0.0066041
# [179]	training's binary_logloss: -0.370496	training's focal_loss: 0.00658937	valid_1's binary_logloss: -0.373398	valid_1's focal_loss: 0.00656309
# [180]	training's binary_logloss: -0.374194	training's focal_loss: 0.00654761	valid_1's binary_logloss: -0.376933	valid_1's focal_loss: 0.00652191
# [181]	training's binary_logloss: -0.377589	training's focal_loss: 0.00650727	valid_1's binary_logloss: -0.380231	valid_1's focal_loss: 0.00648138
# [182]	training's binary_logloss: -0.38077	training's focal_loss: 0.00646657	valid_1's binary_logloss: -0.38332	valid_1's focal_loss: 0.00644064
# [183]	training's binary_logloss: -0.38411	training's focal_loss: 0.00642827	valid_1's binary_logloss: -0.386833	valid_1's focal_loss: 0.0064021
# [184]	training's binary_logloss: -0.387424	training's focal_loss: 0.00639104	valid_1's binary_logloss: -0.390195	valid_1's focal_loss: 0.00636458
# [185]	training's binary_logloss: -0.390664	training's focal_loss: 0.00635292	valid_1's binary_logloss: -0.393464	valid_1's focal_loss: 0.00632632
# [186]	training's binary_logloss: -0.394252	training's focal_loss: 0.00631685	valid_1's binary_logloss: -0.396709	valid_1's focal_loss: 0.0062899
# [187]	training's binary_logloss: -0.397796	training's focal_loss: 0.00628121	valid_1's binary_logloss: -0.400373	valid_1's focal_loss: 0.00625416
# [188]	training's binary_logloss: -0.401067	training's focal_loss: 0.00624537	valid_1's binary_logloss: -0.403965	valid_1's focal_loss: 0.00621838
# [189]	training's binary_logloss: -0.40438	training's focal_loss: 0.00621013	valid_1's binary_logloss: -0.407154	valid_1's focal_loss: 0.00618304
# [190]	training's binary_logloss: -0.40776	training's focal_loss: 0.00617537	valid_1's binary_logloss: -0.410356	valid_1's focal_loss: 0.00614819
# [191]	training's binary_logloss: -0.411416	training's focal_loss: 0.0061413	valid_1's binary_logloss: -0.414044	valid_1's focal_loss: 0.00611423
# [192]	training's binary_logloss: -0.414358	training's focal_loss: 0.00610876	valid_1's binary_logloss: -0.416687	valid_1's focal_loss: 0.00608187
# [193]	training's binary_logloss: -0.417696	training's focal_loss: 0.00607563	valid_1's binary_logloss: -0.420064	valid_1's focal_loss: 0.00604847
# [194]	training's binary_logloss: -0.421056	training's focal_loss: 0.00604269	valid_1's binary_logloss: -0.423764	valid_1's focal_loss: 0.00601535
# [195]	training's binary_logloss: -0.424442	training's focal_loss: 0.00601012	valid_1's binary_logloss: -0.427739	valid_1's focal_loss: 0.00598261
# [196]	training's binary_logloss: -0.427879	training's focal_loss: 0.00597943	valid_1's binary_logloss: -0.430649	valid_1's focal_loss: 0.00595184
# [197]	training's binary_logloss: -0.430871	training's focal_loss: 0.00594837	valid_1's binary_logloss: -0.433687	valid_1's focal_loss: 0.00592008
# [198]	training's binary_logloss: -0.434256	training's focal_loss: 0.00591768	valid_1's binary_logloss: -0.437297	valid_1's focal_loss: 0.00588941
# [199]	training's binary_logloss: -0.437462	training's focal_loss: 0.0058867	valid_1's binary_logloss: -0.440623	valid_1's focal_loss: 0.00585789
# [200]	training's binary_logloss: -0.44087	training's focal_loss: 0.0058579	valid_1's binary_logloss: -0.444031	valid_1's focal_loss: 0.00582901
# [201]	training's binary_logloss: -0.44413	training's focal_loss: 0.0058287	valid_1's binary_logloss: -0.446879	valid_1's focal_loss: 0.00579965
# [202]	training's binary_logloss: -0.447207	training's focal_loss: 0.00580051	valid_1's binary_logloss: -0.450334	valid_1's focal_loss: 0.00577143
# [203]	training's binary_logloss: -0.450289	training's focal_loss: 0.00577185	valid_1's binary_logloss: -0.453368	valid_1's focal_loss: 0.00574273
# [204]	training's binary_logloss: -0.453817	training's focal_loss: 0.0057433	valid_1's binary_logloss: -0.456286	valid_1's focal_loss: 0.00571428
# [205]	training's binary_logloss: -0.456545	training's focal_loss: 0.00571689	valid_1's binary_logloss: -0.458826	valid_1's focal_loss: 0.00568782
# [206]	training's binary_logloss: -0.459703	training's focal_loss: 0.00569022	valid_1's binary_logloss: -0.462195	valid_1's focal_loss: 0.00566115
# [207]	training's binary_logloss: -0.462723	training's focal_loss: 0.00566355	valid_1's binary_logloss: -0.465126	valid_1's focal_loss: 0.00563425
# [208]	training's binary_logloss: -0.465531	training's focal_loss: 0.00563627	valid_1's binary_logloss: -0.467627	valid_1's focal_loss: 0.00560685
# [209]	training's binary_logloss: -0.468469	training's focal_loss: 0.00561046	valid_1's binary_logloss: -0.470319	valid_1's focal_loss: 0.00558077
# [210]	training's binary_logloss: -0.471581	training's focal_loss: 0.00558551	valid_1's binary_logloss: -0.473452	valid_1's focal_loss: 0.00555555
# [211]	training's binary_logloss: -0.474522	training's focal_loss: 0.00556009	valid_1's binary_logloss: -0.475897	valid_1's focal_loss: 0.00552993
# [212]	training's binary_logloss: -0.477399	training's focal_loss: 0.00553539	valid_1's binary_logloss: -0.478417	valid_1's focal_loss: 0.00550534
# [213]	training's binary_logloss: -0.480478	training's focal_loss: 0.00551052	valid_1's binary_logloss: -0.480897	valid_1's focal_loss: 0.00548023
# [214]	training's binary_logloss: -0.483225	training's focal_loss: 0.0054863	valid_1's binary_logloss: -0.483691	valid_1's focal_loss: 0.00545581
# [215]	training's binary_logloss: -0.486359	training's focal_loss: 0.00546111	valid_1's binary_logloss: -0.486792	valid_1's focal_loss: 0.00543029
# [216]	training's binary_logloss: -0.489447	training's focal_loss: 0.00543845	valid_1's binary_logloss: -0.490299	valid_1's focal_loss: 0.0054075
# [217]	training's binary_logloss: -0.492479	training's focal_loss: 0.00541505	valid_1's binary_logloss: -0.493079	valid_1's focal_loss: 0.0053837
# [218]	training's binary_logloss: -0.49554	training's focal_loss: 0.00539166	valid_1's binary_logloss: -0.496014	valid_1's focal_loss: 0.00536013
# [219]	training's binary_logloss: -0.498432	training's focal_loss: 0.0053699	valid_1's binary_logloss: -0.499251	valid_1's focal_loss: 0.00533806
# [220]	training's binary_logloss: -0.501587	training's focal_loss: 0.00534699	valid_1's binary_logloss: -0.502376	valid_1's focal_loss: 0.00531505
# [221]	training's binary_logloss: -0.504015	training's focal_loss: 0.00532548	valid_1's binary_logloss: -0.50497	valid_1's focal_loss: 0.00529341
# [222]	training's binary_logloss: -0.506994	training's focal_loss: 0.00530459	valid_1's binary_logloss: -0.507601	valid_1's focal_loss: 0.00527224
# [223]	training's binary_logloss: -0.510002	training's focal_loss: 0.00528414	valid_1's binary_logloss: -0.510488	valid_1's focal_loss: 0.0052517
# [224]	training's binary_logloss: -0.513033	training's focal_loss: 0.00526396	valid_1's binary_logloss: -0.513829	valid_1's focal_loss: 0.00523148
# [225]	training's binary_logloss: -0.515745	training's focal_loss: 0.00524391	valid_1's binary_logloss: -0.516499	valid_1's focal_loss: 0.00521142
# [226]	training's binary_logloss: -0.518797	training's focal_loss: 0.00522367	valid_1's binary_logloss: -0.519818	valid_1's focal_loss: 0.0051908
# [227]	training's binary_logloss: -0.52158	training's focal_loss: 0.00520336	valid_1's binary_logloss: -0.522524	valid_1's focal_loss: 0.00517024
# [228]	training's binary_logloss: -0.524482	training's focal_loss: 0.00518263	valid_1's binary_logloss: -0.525988	valid_1's focal_loss: 0.00514933
# [229]	training's binary_logloss: -0.527361	training's focal_loss: 0.00516288	valid_1's binary_logloss: -0.529033	valid_1's focal_loss: 0.00512938
# [230]	training's binary_logloss: -0.529894	training's focal_loss: 0.00514364	valid_1's binary_logloss: -0.531345	valid_1's focal_loss: 0.0051102
# [231]	training's binary_logloss: -0.532624	training's focal_loss: 0.00512507	valid_1's binary_logloss: -0.534457	valid_1's focal_loss: 0.00509131
# [232]	training's binary_logloss: -0.535386	training's focal_loss: 0.00510654	valid_1's binary_logloss: -0.537056	valid_1's focal_loss: 0.00507305
# [233]	training's binary_logloss: -0.538106	training's focal_loss: 0.00508896	valid_1's binary_logloss: -0.539874	valid_1's focal_loss: 0.0050553
# [234]	training's binary_logloss: -0.541114	training's focal_loss: 0.00506899	valid_1's binary_logloss: -0.542886	valid_1's focal_loss: 0.00503521
# [235]	training's binary_logloss: -0.543915	training's focal_loss: 0.00504999	valid_1's binary_logloss: -0.545702	valid_1's focal_loss: 0.0050163
# [236]	training's binary_logloss: -0.546962	training's focal_loss: 0.00503182	valid_1's binary_logloss: -0.548696	valid_1's focal_loss: 0.00499828
# [237]	training's binary_logloss: -0.549399	training's focal_loss: 0.00501242	valid_1's binary_logloss: -0.551626	valid_1's focal_loss: 0.00497887
# [238]	training's binary_logloss: -0.552222	training's focal_loss: 0.00499396	valid_1's binary_logloss: -0.554046	valid_1's focal_loss: 0.00496025
# [239]	training's binary_logloss: -0.554886	training's focal_loss: 0.00497749	valid_1's binary_logloss: -0.556804	valid_1's focal_loss: 0.00494416
# [240]	training's binary_logloss: -0.557404	training's focal_loss: 0.0049604	valid_1's binary_logloss: -0.559595	valid_1's focal_loss: 0.00492721
# [241]	training's binary_logloss: -0.559869	training's focal_loss: 0.00494361	valid_1's binary_logloss: -0.56241	valid_1's focal_loss: 0.00490999
# [242]	training's binary_logloss: -0.562182	training's focal_loss: 0.00492682	valid_1's binary_logloss: -0.564515	valid_1's focal_loss: 0.00489298
# [243]	training's binary_logloss: -0.565038	training's focal_loss: 0.00491085	valid_1's binary_logloss: -0.568427	valid_1's focal_loss: 0.00487679
# [244]	training's binary_logloss: -0.567638	training's focal_loss: 0.00489456	valid_1's binary_logloss: -0.5711	valid_1's focal_loss: 0.00486061
# [245]	training's binary_logloss: -0.570029	training's focal_loss: 0.00487829	valid_1's binary_logloss: -0.573245	valid_1's focal_loss: 0.00484402
# [246]	training's binary_logloss: -0.572643	training's focal_loss: 0.00486245	valid_1's binary_logloss: -0.576368	valid_1's focal_loss: 0.00482803
# [247]	training's binary_logloss: -0.57528	training's focal_loss: 0.00484655	valid_1's binary_logloss: -0.579345	valid_1's focal_loss: 0.00481205
# [248]	training's binary_logloss: -0.5781	training's focal_loss: 0.00483137	valid_1's binary_logloss: -0.581885	valid_1's focal_loss: 0.00479658
# [249]	training's binary_logloss: -0.580859	training's focal_loss: 0.00481489	valid_1's binary_logloss: -0.584643	valid_1's focal_loss: 0.00477984
# [250]	training's binary_logloss: -0.583653	training's focal_loss: 0.00479964	valid_1's binary_logloss: -0.587651	valid_1's focal_loss: 0.00476451
# [251]	training's binary_logloss: -0.586145	training's focal_loss: 0.00478488	valid_1's binary_logloss: -0.59006	valid_1's focal_loss: 0.00474976
# [252]	training's binary_logloss: -0.588788	training's focal_loss: 0.00477011	valid_1's binary_logloss: -0.593386	valid_1's focal_loss: 0.00473463
# [253]	training's binary_logloss: -0.591079	training's focal_loss: 0.00475533	valid_1's binary_logloss: -0.594967	valid_1's focal_loss: 0.0047201
# [254]	training's binary_logloss: -0.593593	training's focal_loss: 0.00474122	valid_1's binary_logloss: -0.597138	valid_1's focal_loss: 0.00470605
# [255]	training's binary_logloss: -0.596255	training's focal_loss: 0.00472588	valid_1's binary_logloss: -0.599264	valid_1's focal_loss: 0.00469049
# [256]	training's binary_logloss: -0.598921	training's focal_loss: 0.00471186	valid_1's binary_logloss: -0.602326	valid_1's focal_loss: 0.00467639
# [257]	training's binary_logloss: -0.601746	training's focal_loss: 0.00469784	valid_1's binary_logloss: -0.605049	valid_1's focal_loss: 0.00466251
# [258]	training's binary_logloss: -0.604092	training's focal_loss: 0.00468417	valid_1's binary_logloss: -0.607544	valid_1's focal_loss: 0.00464836
# [259]	training's binary_logloss: -0.606393	training's focal_loss: 0.00467082	valid_1's binary_logloss: -0.609454	valid_1's focal_loss: 0.00463527
# [260]	training's binary_logloss: -0.609302	training's focal_loss: 0.00465601	valid_1's binary_logloss: -0.612556	valid_1's focal_loss: 0.00462067
# [261]	training's binary_logloss: -0.611686	training's focal_loss: 0.00464273	valid_1's binary_logloss: -0.614858	valid_1's focal_loss: 0.0046075
# [262]	training's binary_logloss: -0.614334	training's focal_loss: 0.00462875	valid_1's binary_logloss: -0.617609	valid_1's focal_loss: 0.0045937
# [263]	training's binary_logloss: -0.616951	training's focal_loss: 0.00461563	valid_1's binary_logloss: -0.620235	valid_1's focal_loss: 0.00458037
# [264]	training's binary_logloss: -0.619206	training's focal_loss: 0.00460299	valid_1's binary_logloss: -0.621949	valid_1's focal_loss: 0.0045672
# [265]	training's binary_logloss: -0.621619	training's focal_loss: 0.00458932	valid_1's binary_logloss: -0.625004	valid_1's focal_loss: 0.00455363
# [266]	training's binary_logloss: -0.624065	training's focal_loss: 0.00457673	valid_1's binary_logloss: -0.627425	valid_1's focal_loss: 0.00454101
# [267]	training's binary_logloss: -0.626896	training's focal_loss: 0.00456329	valid_1's binary_logloss: -0.630083	valid_1's focal_loss: 0.00452769
# [268]	training's binary_logloss: -0.629225	training's focal_loss: 0.00454972	valid_1's binary_logloss: -0.633036	valid_1's focal_loss: 0.00451449
# [269]	training's binary_logloss: -0.631409	training's focal_loss: 0.00453714	valid_1's binary_logloss: -0.634796	valid_1's focal_loss: 0.004502
# [270]	training's binary_logloss: -0.633669	training's focal_loss: 0.00452528	valid_1's binary_logloss: -0.637822	valid_1's focal_loss: 0.00449019
# [271]	training's binary_logloss: -0.63634	training's focal_loss: 0.00451282	valid_1's binary_logloss: -0.639744	valid_1's focal_loss: 0.00447797
# [272]	training's binary_logloss: -0.638582	training's focal_loss: 0.00450098	valid_1's binary_logloss: -0.642512	valid_1's focal_loss: 0.00446611
# [273]	training's binary_logloss: -0.640882	training's focal_loss: 0.00448893	valid_1's binary_logloss: -0.644603	valid_1's focal_loss: 0.00445439
# [274]	training's binary_logloss: -0.642959	training's focal_loss: 0.00447742	valid_1's binary_logloss: -0.64681	valid_1's focal_loss: 0.00444312
# [275]	training's binary_logloss: -0.64512	training's focal_loss: 0.00446596	valid_1's binary_logloss: -0.649087	valid_1's focal_loss: 0.00443169
# [276]	training's binary_logloss: -0.647257	training's focal_loss: 0.00445432	valid_1's binary_logloss: -0.65117	valid_1's focal_loss: 0.00441984
# [277]	training's binary_logloss: -0.649543	training's focal_loss: 0.00444281	valid_1's binary_logloss: -0.653471	valid_1's focal_loss: 0.00440824
# [278]	training's binary_logloss: -0.651787	training's focal_loss: 0.00443161	valid_1's binary_logloss: -0.655825	valid_1's focal_loss: 0.00439699
# [279]	training's binary_logloss: -0.654031	training's focal_loss: 0.0044203	valid_1's binary_logloss: -0.658134	valid_1's focal_loss: 0.00438545
# [280]	training's binary_logloss: -0.656574	training's focal_loss: 0.0044092	valid_1's binary_logloss: -0.660139	valid_1's focal_loss: 0.00437412
# [281]	training's binary_logloss: -0.658706	training's focal_loss: 0.00439808	valid_1's binary_logloss: -0.662375	valid_1's focal_loss: 0.00436307
# [282]	training's binary_logloss: -0.660946	training's focal_loss: 0.00438712	valid_1's binary_logloss: -0.665253	valid_1's focal_loss: 0.0043526
# [283]	training's binary_logloss: -0.663433	training's focal_loss: 0.00437517	valid_1's binary_logloss: -0.667588	valid_1's focal_loss: 0.00434056
# [284]	training's binary_logloss: -0.665557	training's focal_loss: 0.00436368	valid_1's binary_logloss: -0.670102	valid_1's focal_loss: 0.00432908
# [285]	training's binary_logloss: -0.667674	training's focal_loss: 0.00435334	valid_1's binary_logloss: -0.672469	valid_1's focal_loss: 0.00431853
# [286]	training's binary_logloss: -0.669995	training's focal_loss: 0.00434313	valid_1's binary_logloss: -0.674515	valid_1's focal_loss: 0.00430852
# [287]	training's binary_logloss: -0.672193	training's focal_loss: 0.00433275	valid_1's binary_logloss: -0.676755	valid_1's focal_loss: 0.00429808
# [288]	training's binary_logloss: -0.674572	training's focal_loss: 0.00432151	valid_1's binary_logloss: -0.679223	valid_1's focal_loss: 0.00428694
# [289]	training's binary_logloss: -0.676914	training's focal_loss: 0.00431107	valid_1's binary_logloss: -0.682416	valid_1's focal_loss: 0.00427684
# [290]	training's binary_logloss: -0.679165	training's focal_loss: 0.00429973	valid_1's binary_logloss: -0.684349	valid_1's focal_loss: 0.00426549
# [291]	training's binary_logloss: -0.681636	training's focal_loss: 0.00428973	valid_1's binary_logloss: -0.686715	valid_1's focal_loss: 0.00425538
# [292]	training's binary_logloss: -0.683821	training's focal_loss: 0.00427882	valid_1's binary_logloss: -0.689126	valid_1's focal_loss: 0.00424424
# [293]	training's binary_logloss: -0.686048	training's focal_loss: 0.0042692	valid_1's binary_logloss: -0.691618	valid_1's focal_loss: 0.00423457
# [294]	training's binary_logloss: -0.688118	training's focal_loss: 0.00425896	valid_1's binary_logloss: -0.693802	valid_1's focal_loss: 0.00422426
# [295]	training's binary_logloss: -0.690303	training's focal_loss: 0.00424882	valid_1's binary_logloss: -0.695998	valid_1's focal_loss: 0.00421435
# [296]	training's binary_logloss: -0.69242	training's focal_loss: 0.00423938	valid_1's binary_logloss: -0.698118	valid_1's focal_loss: 0.00420512
# [297]	training's binary_logloss: -0.694524	training's focal_loss: 0.00422883	valid_1's binary_logloss: -0.700347	valid_1's focal_loss: 0.00419482
# [298]	training's binary_logloss: -0.696346	training's focal_loss: 0.00421934	valid_1's binary_logloss: -0.702375	valid_1's focal_loss: 0.00418537
# [299]	training's binary_logloss: -0.698399	training's focal_loss: 0.0042096	valid_1's binary_logloss: -0.70352	valid_1's focal_loss: 0.00417582
# [300]	training's binary_logloss: -0.700532	training's focal_loss: 0.00420032	valid_1's binary_logloss: -0.705577	valid_1's focal_loss: 0.00416658
# [301]	training's binary_logloss: -0.702652	training's focal_loss: 0.00419073	valid_1's binary_logloss: -0.70811	valid_1's focal_loss: 0.00415715
# [302]	training's binary_logloss: -0.704867	training's focal_loss: 0.00418091	valid_1's binary_logloss: -0.710353	valid_1's focal_loss: 0.00414769
# [303]	training's binary_logloss: -0.706846	training's focal_loss: 0.004172	valid_1's binary_logloss: -0.712433	valid_1's focal_loss: 0.00413878
# [304]	training's binary_logloss: -0.708924	training's focal_loss: 0.0041631	valid_1's binary_logloss: -0.71434	valid_1's focal_loss: 0.00412963
# [305]	training's binary_logloss: -0.711046	training's focal_loss: 0.0041542	valid_1's binary_logloss: -0.717118	valid_1's focal_loss: 0.00412101
# [306]	training's binary_logloss: -0.712936	training's focal_loss: 0.00414462	valid_1's binary_logloss: -0.718722	valid_1's focal_loss: 0.00411162
# [307]	training's binary_logloss: -0.715226	training's focal_loss: 0.00413535	valid_1's binary_logloss: -0.721146	valid_1's focal_loss: 0.00410256
# [308]	training's binary_logloss: -0.717135	training's focal_loss: 0.00412693	valid_1's binary_logloss: -0.722777	valid_1's focal_loss: 0.00409375
# [309]	training's binary_logloss: -0.719163	training's focal_loss: 0.00411837	valid_1's binary_logloss: -0.724649	valid_1's focal_loss: 0.00408548
# [310]	training's binary_logloss: -0.721203	training's focal_loss: 0.00410965	valid_1's binary_logloss: -0.727187	valid_1's focal_loss: 0.00407745
# [311]	training's binary_logloss: -0.723164	training's focal_loss: 0.00410126	valid_1's binary_logloss: -0.728639	valid_1's focal_loss: 0.00406905
# [312]	training's binary_logloss: -0.725305	training's focal_loss: 0.00409248	valid_1's binary_logloss: -0.730857	valid_1's focal_loss: 0.0040605
# [313]	training's binary_logloss: -0.727196	training's focal_loss: 0.00408378	valid_1's binary_logloss: -0.732991	valid_1's focal_loss: 0.00405186
# [314]	training's binary_logloss: -0.729463	training's focal_loss: 0.00407502	valid_1's binary_logloss: -0.735563	valid_1's focal_loss: 0.0040427
# [315]	training's binary_logloss: -0.731164	training's focal_loss: 0.00406691	valid_1's binary_logloss: -0.737535	valid_1's focal_loss: 0.00403469
# [316]	training's binary_logloss: -0.733171	training's focal_loss: 0.00405852	valid_1's binary_logloss: -0.739035	valid_1's focal_loss: 0.00402627
# [317]	training's binary_logloss: -0.735118	training's focal_loss: 0.00404945	valid_1's binary_logloss: -0.74127	valid_1's focal_loss: 0.00401729
# [318]	training's binary_logloss: -0.736816	training's focal_loss: 0.00404057	valid_1's binary_logloss: -0.742557	valid_1's focal_loss: 0.00400864
# [319]	training's binary_logloss: -0.738776	training's focal_loss: 0.00403185	valid_1's binary_logloss: -0.74475	valid_1's focal_loss: 0.00399971
# [320]	training's binary_logloss: -0.740582	training's focal_loss: 0.00402377	valid_1's binary_logloss: -0.746548	valid_1's focal_loss: 0.00399161
# [321]	training's binary_logloss: -0.742509	training's focal_loss: 0.00401603	valid_1's binary_logloss: -0.748416	valid_1's focal_loss: 0.00398382
# [322]	training's binary_logloss: -0.744805	training's focal_loss: 0.00400752	valid_1's binary_logloss: -0.750485	valid_1's focal_loss: 0.0039754
# [323]	training's binary_logloss: -0.746775	training's focal_loss: 0.00399954	valid_1's binary_logloss: -0.752504	valid_1's focal_loss: 0.00396766
# [324]	training's binary_logloss: -0.748813	training's focal_loss: 0.00399142	valid_1's binary_logloss: -0.754547	valid_1's focal_loss: 0.00395962
# [325]	training's binary_logloss: -0.7506	training's focal_loss: 0.00398377	valid_1's binary_logloss: -0.75642	valid_1's focal_loss: 0.00395187
# [326]	training's binary_logloss: -0.752977	training's focal_loss: 0.00397593	valid_1's binary_logloss: -0.759341	valid_1's focal_loss: 0.00394388
# [327]	training's binary_logloss: -0.754903	training's focal_loss: 0.00396718	valid_1's binary_logloss: -0.760991	valid_1's focal_loss: 0.00393517
# [328]	training's binary_logloss: -0.756858	training's focal_loss: 0.00395894	valid_1's binary_logloss: -0.762484	valid_1's focal_loss: 0.00392707
# ...
# [5352]	training's binary_logloss: -1.88243	training's focal_loss: 3.51684e-05	valid_1's binary_logloss: -1.88289	valid_1's focal_loss: 3.32731e-05
# [5353]	training's binary_logloss: -1.88247	training's focal_loss: 3.51506e-05	valid_1's binary_logloss: -1.88294	valid_1's focal_loss: 3.32447e-05
# [5354]	training's binary_logloss: -1.88253	training's focal_loss: 3.51339e-05	valid_1's binary_logloss: -1.88299	valid_1's focal_loss: 3.32358e-05
# [5355]	training's binary_logloss: -1.88256	training's focal_loss: 3.51161e-05	valid_1's binary_logloss: -1.88302	valid_1's focal_loss: 3.32099e-05
# [5356]	training's binary_logloss: -1.88261	training's focal_loss: 3.50989e-05	valid_1's binary_logloss: -1.88307	valid_1's focal_loss: 3.31869e-05
# [5357]	training's binary_logloss: -1.88265	training's focal_loss: 3.5081e-05	valid_1's binary_logloss: -1.88312	valid_1's focal_loss: 3.31729e-05
# [5358]	training's binary_logloss: -1.88271	training's focal_loss: 3.50616e-05	valid_1's binary_logloss: -1.88318	valid_1's focal_loss: 3.31568e-05
# [5359]	training's binary_logloss: -1.88276	training's focal_loss: 3.50444e-05	valid_1's binary_logloss: -1.88322	valid_1's focal_loss: 3.31392e-05
# [5360]	training's binary_logloss: -1.88281	training's focal_loss: 3.50249e-05	valid_1's binary_logloss: -1.88328	valid_1's focal_loss: 3.31184e-05
# [5361]	training's binary_logloss: -1.88285	training's focal_loss: 3.50077e-05	valid_1's binary_logloss: -1.88332	valid_1's focal_loss: 3.3103e-05
# [5362]	training's binary_logloss: -1.88292	training's focal_loss: 3.49889e-05	valid_1's binary_logloss: -1.88338	valid_1's focal_loss: 3.30764e-05
# [5363]	training's binary_logloss: -1.88301	training's focal_loss: 3.49701e-05	valid_1's binary_logloss: -1.88347	valid_1's focal_loss: 3.30507e-05
# [5364]	training's binary_logloss: -1.88308	training's focal_loss: 3.49523e-05	valid_1's binary_logloss: -1.88354	valid_1's focal_loss: 3.30305e-05
# [5365]	training's binary_logloss: -1.88312	training's focal_loss: 3.49345e-05	valid_1's binary_logloss: -1.88358	valid_1's focal_loss: 3.30108e-05
# [5366]	training's binary_logloss: -1.88321	training's focal_loss: 3.49159e-05	valid_1's binary_logloss: -1.88368	valid_1's focal_loss: 3.29886e-05
# [5367]	training's binary_logloss: -1.88328	training's focal_loss: 3.48982e-05	valid_1's binary_logloss: -1.88374	valid_1's focal_loss: 3.29727e-05
# [5368]	training's binary_logloss: -1.88336	training's focal_loss: 3.48829e-05	valid_1's binary_logloss: -1.88382	valid_1's focal_loss: 3.297e-05
# [5369]	training's binary_logloss: -1.88346	training's focal_loss: 3.48647e-05	valid_1's binary_logloss: -1.88392	valid_1's focal_loss: 3.29521e-05
# [5370]	training's binary_logloss: -1.88351	training's focal_loss: 3.48467e-05	valid_1's binary_logloss: -1.88398	valid_1's focal_loss: 3.29337e-05
# [5371]	training's binary_logloss: -1.88355	training's focal_loss: 3.48292e-05	valid_1's binary_logloss: -1.88401	valid_1's focal_loss: 3.29318e-05
# [5372]	training's binary_logloss: -1.8836	training's focal_loss: 3.48117e-05	valid_1's binary_logloss: -1.88407	valid_1's focal_loss: 3.29075e-05
# [5373]	training's binary_logloss: -1.8837	training's focal_loss: 3.47919e-05	valid_1's binary_logloss: -1.88416	valid_1's focal_loss: 3.28935e-05
# [5374]	training's binary_logloss: -1.88379	training's focal_loss: 3.47742e-05	valid_1's binary_logloss: -1.88425	valid_1's focal_loss: 3.28736e-05
# [5375]	training's binary_logloss: -1.88386	training's focal_loss: 3.47565e-05	valid_1's binary_logloss: -1.88432	valid_1's focal_loss: 3.28524e-05
# [5376]	training's binary_logloss: -1.88391	training's focal_loss: 3.47388e-05	valid_1's binary_logloss: -1.88437	valid_1's focal_loss: 3.28289e-05
# [5377]	training's binary_logloss: -1.88397	training's focal_loss: 3.47229e-05	valid_1's binary_logloss: -1.88443	valid_1's focal_loss: 3.28118e-05
# [5378]	training's binary_logloss: -1.88408	training's focal_loss: 3.47066e-05	valid_1's binary_logloss: -1.88455	valid_1's focal_loss: 3.27957e-05
# [5379]	training's binary_logloss: -1.88417	training's focal_loss: 3.46889e-05	valid_1's binary_logloss: -1.88463	valid_1's focal_loss: 3.27672e-05
# [5380]	training's binary_logloss: -1.88422	training's focal_loss: 3.46712e-05	valid_1's binary_logloss: -1.88468	valid_1's focal_loss: 3.27513e-05
# [5381]	training's binary_logloss: -1.88427	training's focal_loss: 3.46527e-05	valid_1's binary_logloss: -1.88474	valid_1's focal_loss: 3.27244e-05
# [5382]	training's binary_logloss: -1.88433	training's focal_loss: 3.46337e-05	valid_1's binary_logloss: -1.8848	valid_1's focal_loss: 3.26974e-05
# [5383]	training's binary_logloss: -1.88438	training's focal_loss: 3.46159e-05	valid_1's binary_logloss: -1.88485	valid_1's focal_loss: 3.26798e-05
# [5384]	training's binary_logloss: -1.88445	training's focal_loss: 3.45983e-05	valid_1's binary_logloss: -1.88492	valid_1's focal_loss: 3.26602e-05
# [5385]	training's binary_logloss: -1.88447	training's focal_loss: 3.45804e-05	valid_1's binary_logloss: -1.88494	valid_1's focal_loss: 3.26471e-05
# [5386]	training's binary_logloss: -1.88457	training's focal_loss: 3.45646e-05	valid_1's binary_logloss: -1.88504	valid_1's focal_loss: 3.26312e-05
# [5387]	training's binary_logloss: -1.88464	training's focal_loss: 3.45459e-05	valid_1's binary_logloss: -1.8851	valid_1's focal_loss: 3.26075e-05
# [5388]	training's binary_logloss: -1.88475	training's focal_loss: 3.45289e-05	valid_1's binary_logloss: -1.88522	valid_1's focal_loss: 3.25759e-05
# [5389]	training's binary_logloss: -1.88486	training's focal_loss: 3.45125e-05	valid_1's binary_logloss: -1.88533	valid_1's focal_loss: 3.25572e-05
# [5390]	training's binary_logloss: -1.88496	training's focal_loss: 3.4495e-05	valid_1's binary_logloss: -1.88543	valid_1's focal_loss: 3.25379e-05
# [5391]	training's binary_logloss: -1.88501	training's focal_loss: 3.44778e-05	valid_1's binary_logloss: -1.88547	valid_1's focal_loss: 3.25289e-05
# [5392]	training's binary_logloss: -1.8851	training's focal_loss: 3.44609e-05	valid_1's binary_logloss: -1.88556	valid_1's focal_loss: 3.25156e-05
# [5393]	training's binary_logloss: -1.88514	training's focal_loss: 3.4442e-05	valid_1's binary_logloss: -1.88561	valid_1's focal_loss: 3.25068e-05
# [5394]	training's binary_logloss: -1.88524	training's focal_loss: 3.44223e-05	valid_1's binary_logloss: -1.88571	valid_1's focal_loss: 3.248e-05
# [5395]	training's binary_logloss: -1.88533	training's focal_loss: 3.44048e-05	valid_1's binary_logloss: -1.8858	valid_1's focal_loss: 3.24693e-05
# [5396]	training's binary_logloss: -1.8854	training's focal_loss: 3.43878e-05	valid_1's binary_logloss: -1.88586	valid_1's focal_loss: 3.24563e-05
# [5397]	training's binary_logloss: -1.88548	training's focal_loss: 3.43714e-05	valid_1's binary_logloss: -1.88594	valid_1's focal_loss: 3.24339e-05
# [5398]	training's binary_logloss: -1.88554	training's focal_loss: 3.43543e-05	valid_1's binary_logloss: -1.886	valid_1's focal_loss: 3.24257e-05
# [5399]	training's binary_logloss: -1.8856	training's focal_loss: 3.43365e-05	valid_1's binary_logloss: -1.88607	valid_1's focal_loss: 3.24076e-05
# [5400]	training's binary_logloss: -1.88566	training's focal_loss: 3.43184e-05	valid_1's binary_logloss: -1.88612	valid_1's focal_loss: 3.23874e-05
# [5401]	training's binary_logloss: -1.88572	training's focal_loss: 3.43038e-05	valid_1's binary_logloss: -1.88619	valid_1's focal_loss: 3.23761e-05
# [5402]	training's binary_logloss: -1.88585	training's focal_loss: 3.42849e-05	valid_1's binary_logloss: -1.88631	valid_1's focal_loss: 3.23489e-05
# [5403]	training's binary_logloss: -1.88596	training's focal_loss: 3.42667e-05	valid_1's binary_logloss: -1.88642	valid_1's focal_loss: 3.23377e-05
# [5404]	training's binary_logloss: -1.88606	training's focal_loss: 3.42485e-05	valid_1's binary_logloss: -1.88652	valid_1's focal_loss: 3.23087e-05
# [5405]	training's binary_logloss: -1.88614	training's focal_loss: 3.42321e-05	valid_1's binary_logloss: -1.8866	valid_1's focal_loss: 3.22884e-05
# [5406]	training's binary_logloss: -1.8862	training's focal_loss: 3.42137e-05	valid_1's binary_logloss: -1.88667	valid_1's focal_loss: 3.22768e-05
# [5407]	training's binary_logloss: -1.88624	training's focal_loss: 3.41957e-05	valid_1's binary_logloss: -1.88671	valid_1's focal_loss: 3.22578e-05
# [5408]	training's binary_logloss: -1.88627	training's focal_loss: 3.41795e-05	valid_1's binary_logloss: -1.88674	valid_1's focal_loss: 3.22449e-05
# [5409]	training's binary_logloss: -1.8863	training's focal_loss: 3.41629e-05	valid_1's binary_logloss: -1.88677	valid_1's focal_loss: 3.22247e-05
# [5410]	training's binary_logloss: -1.88638	training's focal_loss: 3.41464e-05	valid_1's binary_logloss: -1.88685	valid_1's focal_loss: 3.22049e-05
# [5411]	training's binary_logloss: -1.88641	training's focal_loss: 3.413e-05	valid_1's binary_logloss: -1.88688	valid_1's focal_loss: 3.21836e-05
# [5412]	training's binary_logloss: -1.88649	training's focal_loss: 3.41115e-05	valid_1's binary_logloss: -1.88696	valid_1's focal_loss: 3.21585e-05
# [5413]	training's binary_logloss: -1.88656	training's focal_loss: 3.4094e-05	valid_1's binary_logloss: -1.88703	valid_1's focal_loss: 3.2152e-05
# [5414]	training's binary_logloss: -1.88663	training's focal_loss: 3.40754e-05	valid_1's binary_logloss: -1.8871	valid_1's focal_loss: 3.21318e-05
# [5415]	training's binary_logloss: -1.8867	training's focal_loss: 3.40599e-05	valid_1's binary_logloss: -1.88717	valid_1's focal_loss: 3.2118e-05
# [5416]	training's binary_logloss: -1.88673	training's focal_loss: 3.40419e-05	valid_1's binary_logloss: -1.8872	valid_1's focal_loss: 3.21005e-05
# [5417]	training's binary_logloss: -1.88677	training's focal_loss: 3.40247e-05	valid_1's binary_logloss: -1.88724	valid_1's focal_loss: 3.20895e-05
# [5418]	training's binary_logloss: -1.88682	training's focal_loss: 3.40078e-05	valid_1's binary_logloss: -1.88729	valid_1's focal_loss: 3.20681e-05
# [5419]	training's binary_logloss: -1.88687	training's focal_loss: 3.39916e-05	valid_1's binary_logloss: -1.88734	valid_1's focal_loss: 3.20561e-05
# [5420]	training's binary_logloss: -1.88694	training's focal_loss: 3.39739e-05	valid_1's binary_logloss: -1.88741	valid_1's focal_loss: 3.20389e-05
# [5421]	training's binary_logloss: -1.88702	training's focal_loss: 3.39571e-05	valid_1's binary_logloss: -1.88749	valid_1's focal_loss: 3.20225e-05
# [5422]	training's binary_logloss: -1.88709	training's focal_loss: 3.39404e-05	valid_1's binary_logloss: -1.88756	valid_1's focal_loss: 3.20122e-05
# [5423]	training's binary_logloss: -1.88713	training's focal_loss: 3.39234e-05	valid_1's binary_logloss: -1.8876	valid_1's focal_loss: 3.19923e-05
# [5424]	training's binary_logloss: -1.8872	training's focal_loss: 3.39062e-05	valid_1's binary_logloss: -1.88767	valid_1's focal_loss: 3.19813e-05
# [5425]	training's binary_logloss: -1.88723	training's focal_loss: 3.38886e-05	valid_1's binary_logloss: -1.8877	valid_1's focal_loss: 3.19602e-05
# [5426]	training's binary_logloss: -1.88726	training's focal_loss: 3.38722e-05	valid_1's binary_logloss: -1.88773	valid_1's focal_loss: 3.19445e-05
# [5427]	training's binary_logloss: -1.88736	training's focal_loss: 3.38547e-05	valid_1's binary_logloss: -1.88782	valid_1's focal_loss: 3.19323e-05
# [5428]	training's binary_logloss: -1.88742	training's focal_loss: 3.38388e-05	valid_1's binary_logloss: -1.88789	valid_1's focal_loss: 3.19172e-05
# [5429]	training's binary_logloss: -1.88747	training's focal_loss: 3.38206e-05	valid_1's binary_logloss: -1.88794	valid_1's focal_loss: 3.18982e-05
# [5430]	training's binary_logloss: -1.88754	training's focal_loss: 3.38025e-05	valid_1's binary_logloss: -1.88801	valid_1's focal_loss: 3.18667e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-f2783962a4e3> in <module>
# ----> 1 gbm.fit(X, y,eval_set=[(X,y),(X_test,y_test)],
#       2         eval_metric=lambda y_true, y_pred: [focal_loss_lgb_eval_error_sk(y_true, y_pred, alpha=0.4, gamma = 2)],
#       3         early_stopping_rounds=100)
#
# ~\myconda\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     888                     valid_sets[i] = (valid_x, self._le.transform(valid_y))
#     889
# --> 890         super().fit(X, _y, sample_weight=sample_weight, init_score=init_score, eval_set=valid_sets,
#     891                     eval_names=eval_names, eval_sample_weight=eval_sample_weight,
#     892                     eval_class_weight=eval_class_weight, eval_init_score=eval_init_score,
#
# ~\myconda\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     681             init_model = init_model.booster_
#     682
# --> 683         self._Booster = train(params, train_set,
#     684                               self.n_estimators, valid_sets=valid_sets, valid_names=eval_names,
#     685                               early_stopping_rounds=early_stopping_rounds,
#
# ~\myconda\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     247                                     evaluation_result_list=None))
#     248
# --> 249         booster.update(fobj=fobj)
#     250
#     251         evaluation_result_list = []
#
# ~\myconda\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    2649             if not self.__set_objective_to_none:
#    2650                 self.reset_parameter({"objective": "none"}).__set_objective_to_none = True
# -> 2651             grad, hess = fobj(self.__inner_predict(0), self.train_set)
#    2652             return self.__boost(grad, hess)
#    2653
#
# ~\myconda\lib\site-packages\lightgbm\sklearn.py in __call__(self, preds, dataset)
#      73         argc = len(signature(self.func).parameters)
#      74         if argc == 2:
# ---> 75             grad, hess = self.func(labels, preds)
#      76         elif argc == 3:
#      77             grad, hess = self.func(labels, preds, dataset.get_group())
#
# <ipython-input-15-dc909070fa99> in <lambda>(x, y)
# ----> 1 focal_loss = lambda x,y: focal_loss_lgb_sk(x, y, alpha = 0.4, gamma = 2)
#
# <ipython-input-14-1452518ca53d> in focal_loss_lgb_sk(y_true, y_pred, alpha, gamma)
#       7         return -( a*t + (1-a)*(1-t) ) * (( 1 - ( t*p + (1-t)*(1-p)) )**g) * ( t*np.log(p)+(1-t)*np.log(1-p) )
#       8     partial_fl = lambda x: fl(x, y_true)
# ----> 9     grad = derivative(partial_fl, y_pred, n=1, dx=1e-6)
#      10     hess = derivative(partial_fl, y_pred, n=2, dx=1e-6)
#      11     return grad, hess
#
# ~\myconda\lib\site-packages\scipy\misc\common.py in derivative(func, x0, dx, n, args, order)
#     117     ho = order >> 1
#     118     for k in range(order):
# --> 119         val += weights[k]*func(x0+(k-ho)*dx,*args)
#     120     return val / prod((dx,)*n,axis=0)
#     121
#
# <ipython-input-14-1452518ca53d> in <lambda>(x)
#       6         p = 1/(1+np.exp(-x))
#       7         return -( a*t + (1-a)*(1-t) ) * (( 1 - ( t*p + (1-t)*(1-p)) )**g) * ( t*np.log(p)+(1-t)*np.log(1-p) )
# ----> 8     partial_fl = lambda x: fl(x, y_true)
#       9     grad = derivative(partial_fl, y_pred, n=1, dx=1e-6)
#      10     hess = derivative(partial_fl, y_pred, n=2, dx=1e-6)
#
# <ipython-input-14-1452518ca53d> in fl(x, t)
#       5     def fl(x,t):
#       6         p = 1/(1+np.exp(-x))
# ----> 7         return -( a*t + (1-a)*(1-t) ) * (( 1 - ( t*p + (1-t)*(1-p)) )**g) * ( t*np.log(p)+(1-t)*np.log(1-p) )
#       8     partial_fl = lambda x: fl(x, y_true)
#       9     grad = derivative(partial_fl, y_pred, n=1, dx=1e-6)
#
# KeyboardInterrupt:

# %%
train_pri=gbm.predict(train_data)
train_pri2 = sigmoid(train_pri)
train_pri2 = pd.DataFrame(train_pri2,columns=['flag'])
train_pri2.to_csv('C:/Users/Lenovo/Desktop/train/train_lgb_local.csv',index = False)

# %%
ind_pri=gbm.predict(test_data)
ind_pri2 = sigmoid(ind_pri)
ind_pri2 = pd.DataFrame(ind_pri2,columns=['flag'])
ind_pri2.to_csv('C:/Users/Lenovo/Desktop/train/prob_lgb+focal_loss.csv',index = False)

# %% [markdown]
# # lgb_3

# %%
parameters={ 'objective': 'binary',
             'metric': 'binary_error',
             'verbosity': -1,
             'boosting_type': 'gbdt',
             'lambda_l1': 8.14104577982587e-05, 
             'lambda_l2': 0.25985991684358545, 
             'num_leaves': 425, 
             'learning_rate': 0.029861155556805748, 
             'n_estimators': 3886,
             'feature_fraction': 0.6856367429495369,
             'bagging_fraction': 0.7331422541166238, 
             'bagging_freq': 2, 
             'min_child_samples': 45}

# %%
gbm = lgb.LGBMClassifier(**parameters)

# %%
gbm.fit(X, y,eval_set=[(X,y),(X_test,y_test)],early_stopping_rounds=100)
# Out:
# [1]	training's binary_error: 0.02668	valid_1's binary_error: 0.0265893
# Training until validation scores don't improve for 100 rounds
# [2]	training's binary_error: 0.0250136	valid_1's binary_error: 0.0249036
# [3]	training's binary_error: 0.0241307	valid_1's binary_error: 0.0242607
# [4]	training's binary_error: 0.0237793	valid_1's binary_error: 0.0235857
# [5]	training's binary_error: 0.0236779	valid_1's binary_error: 0.023475
# [6]	training's binary_error: 0.0232657	valid_1's binary_error: 0.0230857
# [7]	training's binary_error: 0.0229421	valid_1's binary_error: 0.0227821
# [8]	training's binary_error: 0.0228486	valid_1's binary_error: 0.0226286
# [9]	training's binary_error: 0.0228064	valid_1's binary_error: 0.0225571
# [10]	training's binary_error: 0.0227414	valid_1's binary_error: 0.0224893
# [11]	training's binary_error: 0.0226607	valid_1's binary_error: 0.0222607
# [12]	training's binary_error: 0.0225957	valid_1's binary_error: 0.0222321
# [13]	training's binary_error: 0.0225229	valid_1's binary_error: 0.0220571
# [14]	training's binary_error: 0.0224486	valid_1's binary_error: 0.022
# [15]	training's binary_error: 0.0223186	valid_1's binary_error: 0.0219679
# [16]	training's binary_error: 0.02223	valid_1's binary_error: 0.0219036
# [17]	training's binary_error: 0.0221293	valid_1's binary_error: 0.0217071
# [18]	training's binary_error: 0.0221064	valid_1's binary_error: 0.0217821
# [19]	training's binary_error: 0.0220464	valid_1's binary_error: 0.02165
# [20]	training's binary_error: 0.0219957	valid_1's binary_error: 0.0216679
# [21]	training's binary_error: 0.021895	valid_1's binary_error: 0.0216286
# [22]	training's binary_error: 0.0218964	valid_1's binary_error: 0.021575
# [23]	training's binary_error: 0.0217557	valid_1's binary_error: 0.0214786
# [24]	training's binary_error: 0.0216707	valid_1's binary_error: 0.0214
# [25]	training's binary_error: 0.0215836	valid_1's binary_error: 0.0213464
# [26]	training's binary_error: 0.0214957	valid_1's binary_error: 0.0212321
# [27]	training's binary_error: 0.0214179	valid_1's binary_error: 0.0211607
# [28]	training's binary_error: 0.0213671	valid_1's binary_error: 0.0210429
# [29]	training's binary_error: 0.0212771	valid_1's binary_error: 0.0210107
# [30]	training's binary_error: 0.0212257	valid_1's binary_error: 0.021
# [31]	training's binary_error: 0.0211664	valid_1's binary_error: 0.0209893
# [32]	training's binary_error: 0.0211536	valid_1's binary_error: 0.0209821
# [33]	training's binary_error: 0.02104	valid_1's binary_error: 0.020875
# [34]	training's binary_error: 0.0209871	valid_1's binary_error: 0.0207893
# [35]	training's binary_error: 0.0209193	valid_1's binary_error: 0.020725
# [36]	training's binary_error: 0.0208621	valid_1's binary_error: 0.02065
# [37]	training's binary_error: 0.02078	valid_1's binary_error: 0.0205571
# [38]	training's binary_error: 0.0207614	valid_1's binary_error: 0.0205
# [39]	training's binary_error: 0.0206979	valid_1's binary_error: 0.020425
# [40]	training's binary_error: 0.0206279	valid_1's binary_error: 0.0203071
# [41]	training's binary_error: 0.02058	valid_1's binary_error: 0.0202786
# [42]	training's binary_error: 0.020525	valid_1's binary_error: 0.0202214
# [43]	training's binary_error: 0.0204479	valid_1's binary_error: 0.0201857
# [44]	training's binary_error: 0.0204421	valid_1's binary_error: 0.0201857
# [45]	training's binary_error: 0.0203614	valid_1's binary_error: 0.0200714
# [46]	training's binary_error: 0.0203014	valid_1's binary_error: 0.02005
# [47]	training's binary_error: 0.0202114	valid_1's binary_error: 0.0199857
# [48]	training's binary_error: 0.0201621	valid_1's binary_error: 0.0198929
# [49]	training's binary_error: 0.0201	valid_1's binary_error: 0.0198679
# [50]	training's binary_error: 0.020075	valid_1's binary_error: 0.0198286
# [51]	training's binary_error: 0.0200136	valid_1's binary_error: 0.0197357
# [52]	training's binary_error: 0.0199757	valid_1's binary_error: 0.0196821
# [53]	training's binary_error: 0.0199014	valid_1's binary_error: 0.0196036
# [54]	training's binary_error: 0.019845	valid_1's binary_error: 0.0195464
# [55]	training's binary_error: 0.0197514	valid_1's binary_error: 0.0193929
# [56]	training's binary_error: 0.0196957	valid_1's binary_error: 0.0193357
# [57]	training's binary_error: 0.0196471	valid_1's binary_error: 0.0193357
# [58]	training's binary_error: 0.0195979	valid_1's binary_error: 0.0193143
# [59]	training's binary_error: 0.0195357	valid_1's binary_error: 0.0192429
# [60]	training's binary_error: 0.0194786	valid_1's binary_error: 0.0192071
# [61]	training's binary_error: 0.019445	valid_1's binary_error: 0.0192143
# [62]	training's binary_error: 0.0194086	valid_1's binary_error: 0.019175
# [63]	training's binary_error: 0.0193607	valid_1's binary_error: 0.0191107
# [64]	training's binary_error: 0.0192707	valid_1's binary_error: 0.019025
# [65]	training's binary_error: 0.0192007	valid_1's binary_error: 0.0189536
# [66]	training's binary_error: 0.01914	valid_1's binary_error: 0.0188929
# [67]	training's binary_error: 0.019095	valid_1's binary_error: 0.0188464
# [68]	training's binary_error: 0.01904	valid_1's binary_error: 0.0187893
# [69]	training's binary_error: 0.0189793	valid_1's binary_error: 0.0187214
# [70]	training's binary_error: 0.0189464	valid_1's binary_error: 0.018675
# [71]	training's binary_error: 0.0188871	valid_1's binary_error: 0.0186321
# [72]	training's binary_error: 0.0188207	valid_1's binary_error: 0.0185964
# [73]	training's binary_error: 0.0187957	valid_1's binary_error: 0.0185679
# [74]	training's binary_error: 0.0187486	valid_1's binary_error: 0.0185
# [75]	training's binary_error: 0.0187114	valid_1's binary_error: 0.0184429
# [76]	training's binary_error: 0.0186793	valid_1's binary_error: 0.0184536
# [77]	training's binary_error: 0.0186257	valid_1's binary_error: 0.018375
# [78]	training's binary_error: 0.0185886	valid_1's binary_error: 0.0183393
# [79]	training's binary_error: 0.0185207	valid_1's binary_error: 0.0182571
# [80]	training's binary_error: 0.0184579	valid_1's binary_error: 0.0182107
# [81]	training's binary_error: 0.0184207	valid_1's binary_error: 0.0181893
# [82]	training's binary_error: 0.0183471	valid_1's binary_error: 0.0181321
# [83]	training's binary_error: 0.0182786	valid_1's binary_error: 0.0180357
# [84]	training's binary_error: 0.0182314	valid_1's binary_error: 0.0180107
# [85]	training's binary_error: 0.0181657	valid_1's binary_error: 0.0179679
# [86]	training's binary_error: 0.0181136	valid_1's binary_error: 0.0178821
# [87]	training's binary_error: 0.0180493	valid_1's binary_error: 0.01785
# [88]	training's binary_error: 0.0180136	valid_1's binary_error: 0.0178536
# [89]	training's binary_error: 0.01794	valid_1's binary_error: 0.0177893
# [90]	training's binary_error: 0.0179	valid_1's binary_error: 0.01775
# [91]	training's binary_error: 0.017835	valid_1's binary_error: 0.0176571
# [92]	training's binary_error: 0.0177929	valid_1's binary_error: 0.0176607
# [93]	training's binary_error: 0.0177379	valid_1's binary_error: 0.0175643
# [94]	training's binary_error: 0.01768	valid_1's binary_error: 0.0175143
# [95]	training's binary_error: 0.0176214	valid_1's binary_error: 0.0174536
# [96]	training's binary_error: 0.0175771	valid_1's binary_error: 0.0174071
# [97]	training's binary_error: 0.0175393	valid_1's binary_error: 0.0173929
# [98]	training's binary_error: 0.0174914	valid_1's binary_error: 0.0173571
# [99]	training's binary_error: 0.0174464	valid_1's binary_error: 0.0173071
# [100]	training's binary_error: 0.0174014	valid_1's binary_error: 0.0172286
# [101]	training's binary_error: 0.0173493	valid_1's binary_error: 0.0171607
# [102]	training's binary_error: 0.0173086	valid_1's binary_error: 0.0171464
# [103]	training's binary_error: 0.0172643	valid_1's binary_error: 0.0170857
# [104]	training's binary_error: 0.0172021	valid_1's binary_error: 0.017025
# [105]	training's binary_error: 0.017155	valid_1's binary_error: 0.0169714
# [106]	training's binary_error: 0.0171093	valid_1's binary_error: 0.016925
# [107]	training's binary_error: 0.0170443	valid_1's binary_error: 0.0168321
# [108]	training's binary_error: 0.0169857	valid_1's binary_error: 0.0167929
# [109]	training's binary_error: 0.0169221	valid_1's binary_error: 0.016725
# [110]	training's binary_error: 0.0168507	valid_1's binary_error: 0.0166536
# [111]	training's binary_error: 0.0168193	valid_1's binary_error: 0.016625
# [112]	training's binary_error: 0.0167879	valid_1's binary_error: 0.0166143
# [113]	training's binary_error: 0.0167236	valid_1's binary_error: 0.0165393
# [114]	training's binary_error: 0.0166693	valid_1's binary_error: 0.0164536
# [115]	training's binary_error: 0.0166086	valid_1's binary_error: 0.0163786
# [116]	training's binary_error: 0.0165736	valid_1's binary_error: 0.01635
# [117]	training's binary_error: 0.0165371	valid_1's binary_error: 0.0162857
# [118]	training's binary_error: 0.0164993	valid_1's binary_error: 0.0162714
# [119]	training's binary_error: 0.0164493	valid_1's binary_error: 0.0162321
# [120]	training's binary_error: 0.0163879	valid_1's binary_error: 0.01615
# [121]	training's binary_error: 0.0163379	valid_1's binary_error: 0.0161357
# [122]	training's binary_error: 0.0163164	valid_1's binary_error: 0.0161107
# [123]	training's binary_error: 0.0162593	valid_1's binary_error: 0.0160571
# [124]	training's binary_error: 0.01623	valid_1's binary_error: 0.016025
# [125]	training's binary_error: 0.0161657	valid_1's binary_error: 0.0159607
# [126]	training's binary_error: 0.0161193	valid_1's binary_error: 0.0158893
# [127]	training's binary_error: 0.0160629	valid_1's binary_error: 0.0158536
# [128]	training's binary_error: 0.016005	valid_1's binary_error: 0.0157714
# [129]	training's binary_error: 0.0159643	valid_1's binary_error: 0.0157357
# [130]	training's binary_error: 0.0159157	valid_1's binary_error: 0.0156714
# [131]	training's binary_error: 0.0158736	valid_1's binary_error: 0.0156571
# [132]	training's binary_error: 0.0158221	valid_1's binary_error: 0.0155714
# [133]	training's binary_error: 0.0157879	valid_1's binary_error: 0.0155429
# [134]	training's binary_error: 0.0157443	valid_1's binary_error: 0.0155214
# [135]	training's binary_error: 0.0156979	valid_1's binary_error: 0.0154607
# [136]	training's binary_error: 0.0156393	valid_1's binary_error: 0.0154
# [137]	training's binary_error: 0.0155907	valid_1's binary_error: 0.0153321
# [138]	training's binary_error: 0.0155514	valid_1's binary_error: 0.0153286
# [139]	training's binary_error: 0.0155071	valid_1's binary_error: 0.0152964
# [140]	training's binary_error: 0.0154543	valid_1's binary_error: 0.0152536
# [141]	training's binary_error: 0.0154221	valid_1's binary_error: 0.0151964
# [142]	training's binary_error: 0.0153793	valid_1's binary_error: 0.0151643
# [143]	training's binary_error: 0.0153364	valid_1's binary_error: 0.01515
# [144]	training's binary_error: 0.0153071	valid_1's binary_error: 0.0150679
# [145]	training's binary_error: 0.0152414	valid_1's binary_error: 0.0150393
# [146]	training's binary_error: 0.0152029	valid_1's binary_error: 0.0150107
# [147]	training's binary_error: 0.0151614	valid_1's binary_error: 0.01495
# [148]	training's binary_error: 0.0151136	valid_1's binary_error: 0.0148786
# [149]	training's binary_error: 0.0151	valid_1's binary_error: 0.0148643
# [150]	training's binary_error: 0.015065	valid_1's binary_error: 0.0147929
# [151]	training's binary_error: 0.0150364	valid_1's binary_error: 0.0147929
# [152]	training's binary_error: 0.0150064	valid_1's binary_error: 0.0147679
# [153]	training's binary_error: 0.0149543	valid_1's binary_error: 0.0147143
# [154]	training's binary_error: 0.0149107	valid_1's binary_error: 0.0146679
# [155]	training's binary_error: 0.01485	valid_1's binary_error: 0.0145857
# [156]	training's binary_error: 0.0148336	valid_1's binary_error: 0.0145679
# [157]	training's binary_error: 0.0147836	valid_1's binary_error: 0.0145107
# [158]	training's binary_error: 0.0147436	valid_1's binary_error: 0.0144571
# [159]	training's binary_error: 0.0147	valid_1's binary_error: 0.0144
# [160]	training's binary_error: 0.01466	valid_1's binary_error: 0.0143536
# [161]	training's binary_error: 0.0146129	valid_1's binary_error: 0.0142857
# [162]	training's binary_error: 0.0145879	valid_1's binary_error: 0.0142821
# [163]	training's binary_error: 0.0145593	valid_1's binary_error: 0.0142679
# [164]	training's binary_error: 0.0145271	valid_1's binary_error: 0.0142464
# [165]	training's binary_error: 0.0144729	valid_1's binary_error: 0.0141607
# [166]	training's binary_error: 0.0144279	valid_1's binary_error: 0.0141357
# [167]	training's binary_error: 0.0143914	valid_1's binary_error: 0.0141036
# [168]	training's binary_error: 0.0143464	valid_1's binary_error: 0.0140357
# [169]	training's binary_error: 0.01431	valid_1's binary_error: 0.0139929
# [170]	training's binary_error: 0.0142914	valid_1's binary_error: 0.0140286
# [171]	training's binary_error: 0.0142629	valid_1's binary_error: 0.013975
# [172]	training's binary_error: 0.01421	valid_1's binary_error: 0.0139536
# [173]	training's binary_error: 0.0141629	valid_1's binary_error: 0.0138893
# [174]	training's binary_error: 0.0141271	valid_1's binary_error: 0.0138536
# [175]	training's binary_error: 0.014105	valid_1's binary_error: 0.0138679
# [176]	training's binary_error: 0.0140564	valid_1's binary_error: 0.0138
# [177]	training's binary_error: 0.014015	valid_1's binary_error: 0.013775
# [178]	training's binary_error: 0.0139743	valid_1's binary_error: 0.0137
# [179]	training's binary_error: 0.0139536	valid_1's binary_error: 0.01365
# [180]	training's binary_error: 0.0139143	valid_1's binary_error: 0.0136286
# [181]	training's binary_error: 0.0138693	valid_1's binary_error: 0.0136036
# [182]	training's binary_error: 0.0138336	valid_1's binary_error: 0.0135607
# [183]	training's binary_error: 0.0137943	valid_1's binary_error: 0.0134929
# [184]	training's binary_error: 0.0137407	valid_1's binary_error: 0.0134571
# [185]	training's binary_error: 0.013705	valid_1's binary_error: 0.0134107
# [186]	training's binary_error: 0.013655	valid_1's binary_error: 0.0133429
# [187]	training's binary_error: 0.0136371	valid_1's binary_error: 0.0133571
# [188]	training's binary_error: 0.0136107	valid_1's binary_error: 0.0132893
# [189]	training's binary_error: 0.0135571	valid_1's binary_error: 0.0132286
# [190]	training's binary_error: 0.013515	valid_1's binary_error: 0.0132179
# [191]	training's binary_error: 0.0134786	valid_1's binary_error: 0.0131607
# [192]	training's binary_error: 0.0134429	valid_1's binary_error: 0.01315
# [193]	training's binary_error: 0.0134057	valid_1's binary_error: 0.0131321
# [194]	training's binary_error: 0.013365	valid_1's binary_error: 0.0131036
# [195]	training's binary_error: 0.013335	valid_1's binary_error: 0.0130893
# [196]	training's binary_error: 0.0133021	valid_1's binary_error: 0.013025
# [197]	training's binary_error: 0.0132571	valid_1's binary_error: 0.012975
# [198]	training's binary_error: 0.0132393	valid_1's binary_error: 0.0129464
# [199]	training's binary_error: 0.0132043	valid_1's binary_error: 0.0129321
# [200]	training's binary_error: 0.0131621	valid_1's binary_error: 0.012875
# [201]	training's binary_error: 0.01314	valid_1's binary_error: 0.0128571
# [202]	training's binary_error: 0.0131107	valid_1's binary_error: 0.012825
# [203]	training's binary_error: 0.0130586	valid_1's binary_error: 0.0127607
# [204]	training's binary_error: 0.0130221	valid_1's binary_error: 0.0126964
# [205]	training's binary_error: 0.012995	valid_1's binary_error: 0.0126857
# [206]	training's binary_error: 0.0129686	valid_1's binary_error: 0.0126821
# [207]	training's binary_error: 0.0129357	valid_1's binary_error: 0.012625
# [208]	training's binary_error: 0.0129014	valid_1's binary_error: 0.0125929
# [209]	training's binary_error: 0.0128736	valid_1's binary_error: 0.0125679
# [210]	training's binary_error: 0.0128364	valid_1's binary_error: 0.0125714
# [211]	training's binary_error: 0.01281	valid_1's binary_error: 0.0125357
# [212]	training's binary_error: 0.0127629	valid_1's binary_error: 0.0124929
# [213]	training's binary_error: 0.0127407	valid_1's binary_error: 0.0124571
# [214]	training's binary_error: 0.0127071	valid_1's binary_error: 0.012425
# [215]	training's binary_error: 0.012675	valid_1's binary_error: 0.0123929
# [216]	training's binary_error: 0.0126236	valid_1's binary_error: 0.0123607
# [217]	training's binary_error: 0.01259	valid_1's binary_error: 0.012325
# [218]	training's binary_error: 0.0125629	valid_1's binary_error: 0.0123286
# [219]	training's binary_error: 0.0125314	valid_1's binary_error: 0.0123036
# [220]	training's binary_error: 0.0124979	valid_1's binary_error: 0.0122857
# [221]	training's binary_error: 0.0124671	valid_1's binary_error: 0.01225
# [222]	training's binary_error: 0.0124507	valid_1's binary_error: 0.012225
# [223]	training's binary_error: 0.0124071	valid_1's binary_error: 0.0121571
# [224]	training's binary_error: 0.01238	valid_1's binary_error: 0.0121571
# [225]	training's binary_error: 0.0123479	valid_1's binary_error: 0.0121143
# [226]	training's binary_error: 0.0123293	valid_1's binary_error: 0.0121036
# [227]	training's binary_error: 0.0123043	valid_1's binary_error: 0.0120821
# [228]	training's binary_error: 0.012275	valid_1's binary_error: 0.01205
# [229]	training's binary_error: 0.0122393	valid_1's binary_error: 0.0120143
# [230]	training's binary_error: 0.0122079	valid_1's binary_error: 0.0119643
# [231]	training's binary_error: 0.0121671	valid_1's binary_error: 0.011925
# [232]	training's binary_error: 0.0121307	valid_1's binary_error: 0.0118821
# [233]	training's binary_error: 0.0121021	valid_1's binary_error: 0.0118607
# [234]	training's binary_error: 0.0120836	valid_1's binary_error: 0.01185
# [235]	training's binary_error: 0.0120493	valid_1's binary_error: 0.0118321
# [236]	training's binary_error: 0.0120071	valid_1's binary_error: 0.0117893
# [237]	training's binary_error: 0.011975	valid_1's binary_error: 0.0117429
# [238]	training's binary_error: 0.0119421	valid_1's binary_error: 0.0117179
# [239]	training's binary_error: 0.0119043	valid_1's binary_error: 0.0116679
# [240]	training's binary_error: 0.01188	valid_1's binary_error: 0.0116714
# [241]	training's binary_error: 0.0118514	valid_1's binary_error: 0.0116321
# [242]	training's binary_error: 0.0118257	valid_1's binary_error: 0.0116286
# [243]	training's binary_error: 0.0117864	valid_1's binary_error: 0.0116143
# [244]	training's binary_error: 0.0117493	valid_1's binary_error: 0.0115893
# [245]	training's binary_error: 0.0117293	valid_1's binary_error: 0.0115429
# [246]	training's binary_error: 0.0117029	valid_1's binary_error: 0.0115036
# [247]	training's binary_error: 0.0116807	valid_1's binary_error: 0.0114964
# [248]	training's binary_error: 0.0116436	valid_1's binary_error: 0.01145
# [249]	training's binary_error: 0.0115929	valid_1's binary_error: 0.0114
# [250]	training's binary_error: 0.0115593	valid_1's binary_error: 0.0113536
# [251]	training's binary_error: 0.0115193	valid_1's binary_error: 0.0113321
# [252]	training's binary_error: 0.0114771	valid_1's binary_error: 0.0113179
# [253]	training's binary_error: 0.0114293	valid_1's binary_error: 0.0112643
# [254]	training's binary_error: 0.0114064	valid_1's binary_error: 0.0112429
# [255]	training's binary_error: 0.0113814	valid_1's binary_error: 0.0112286
# [256]	training's binary_error: 0.0113479	valid_1's binary_error: 0.011175
# [257]	training's binary_error: 0.0113057	valid_1's binary_error: 0.0111143
# [258]	training's binary_error: 0.0112757	valid_1's binary_error: 0.011075
# [259]	training's binary_error: 0.0112421	valid_1's binary_error: 0.01105
# [260]	training's binary_error: 0.0112086	valid_1's binary_error: 0.0110143
# [261]	training's binary_error: 0.0111757	valid_1's binary_error: 0.0110143
# [262]	training's binary_error: 0.0111407	valid_1's binary_error: 0.010975
# [263]	training's binary_error: 0.0111014	valid_1's binary_error: 0.0109071
# [264]	training's binary_error: 0.0110764	valid_1's binary_error: 0.0108821
# [265]	training's binary_error: 0.0110471	valid_1's binary_error: 0.0108429
# [266]	training's binary_error: 0.0110157	valid_1's binary_error: 0.0108143
# [267]	training's binary_error: 0.0109893	valid_1's binary_error: 0.0107857
# [268]	training's binary_error: 0.010955	valid_1's binary_error: 0.0107429
# [269]	training's binary_error: 0.01092	valid_1's binary_error: 0.0107357
# [270]	training's binary_error: 0.0108693	valid_1's binary_error: 0.0106786
# [271]	training's binary_error: 0.0108414	valid_1's binary_error: 0.0106607
# [272]	training's binary_error: 0.0108307	valid_1's binary_error: 0.0106464
# [273]	training's binary_error: 0.0107986	valid_1's binary_error: 0.0106179
# [274]	training's binary_error: 0.01078	valid_1's binary_error: 0.0106
# [275]	training's binary_error: 0.0107379	valid_1's binary_error: 0.0105857
# [276]	training's binary_error: 0.0107043	valid_1's binary_error: 0.0105393
# [277]	training's binary_error: 0.0106829	valid_1's binary_error: 0.010525
# [278]	training's binary_error: 0.0106379	valid_1's binary_error: 0.0104679
# [279]	training's binary_error: 0.0106164	valid_1's binary_error: 0.0104393
# [280]	training's binary_error: 0.0105857	valid_1's binary_error: 0.0104036
# [281]	training's binary_error: 0.01056	valid_1's binary_error: 0.0103643
# [282]	training's binary_error: 0.01052	valid_1's binary_error: 0.010325
# [283]	training's binary_error: 0.0104786	valid_1's binary_error: 0.0102929
# [284]	training's binary_error: 0.0104479	valid_1's binary_error: 0.0102643
# [285]	training's binary_error: 0.01042	valid_1's binary_error: 0.0102179
# [286]	training's binary_error: 0.0103829	valid_1's binary_error: 0.0101679
# [287]	training's binary_error: 0.010355	valid_1's binary_error: 0.0101679
# [288]	training's binary_error: 0.010315	valid_1's binary_error: 0.0101071
# [289]	training's binary_error: 0.0102964	valid_1's binary_error: 0.0101
# [290]	training's binary_error: 0.0102564	valid_1's binary_error: 0.0100821
# [291]	training's binary_error: 0.01024	valid_1's binary_error: 0.0100536
# [292]	training's binary_error: 0.0102114	valid_1's binary_error: 0.0100429
# [293]	training's binary_error: 0.0101821	valid_1's binary_error: 0.0100071
# [294]	training's binary_error: 0.0101643	valid_1's binary_error: 0.00998571
# [295]	training's binary_error: 0.01013	valid_1's binary_error: 0.00993929
# [296]	training's binary_error: 0.0100993	valid_1's binary_error: 0.00991429
# [297]	training's binary_error: 0.0100736	valid_1's binary_error: 0.00987143
# [298]	training's binary_error: 0.0100279	valid_1's binary_error: 0.00983214
# [299]	training's binary_error: 0.00998929	valid_1's binary_error: 0.00978571
# [300]	training's binary_error: 0.00996286	valid_1's binary_error: 0.00976429
# [301]	training's binary_error: 0.00993929	valid_1's binary_error: 0.00974286
# [302]	training's binary_error: 0.00990286	valid_1's binary_error: 0.00971429
# [303]	training's binary_error: 0.00986786	valid_1's binary_error: 0.00969286
# [304]	training's binary_error: 0.00984714	valid_1's binary_error: 0.00968929
# [305]	training's binary_error: 0.00981071	valid_1's binary_error: 0.00963929
# [306]	training's binary_error: 0.00978	valid_1's binary_error: 0.00959643
# [307]	training's binary_error: 0.00974857	valid_1's binary_error: 0.00958214
# [308]	training's binary_error: 0.00972571	valid_1's binary_error: 0.00952857
# [309]	training's binary_error: 0.00968571	valid_1's binary_error: 0.0095
# [310]	training's binary_error: 0.00965357	valid_1's binary_error: 0.00948929
# [311]	training's binary_error: 0.00963286	valid_1's binary_error: 0.00944643
# [312]	training's binary_error: 0.00960214	valid_1's binary_error: 0.00940357
# [313]	training's binary_error: 0.00957786	valid_1's binary_error: 0.0094
# [314]	training's binary_error: 0.00955786	valid_1's binary_error: 0.00937143
# [315]	training's binary_error: 0.00953	valid_1's binary_error: 0.00934643
# [316]	training's binary_error: 0.00950286	valid_1's binary_error: 0.00933929
# [317]	training's binary_error: 0.00947071	valid_1's binary_error: 0.0093
# [318]	training's binary_error: 0.009455	valid_1's binary_error: 0.009275
# [319]	training's binary_error: 0.00942357	valid_1's binary_error: 0.00925714
# [320]	training's binary_error: 0.00939143	valid_1's binary_error: 0.00920357
# [321]	training's binary_error: 0.00936	valid_1's binary_error: 0.00918929
# [322]	training's binary_error: 0.00932357	valid_1's binary_error: 0.00914286
# [323]	training's binary_error: 0.00929	valid_1's binary_error: 0.00911429
# [324]	training's binary_error: 0.00926429	valid_1's binary_error: 0.0091
# [325]	training's binary_error: 0.009245	valid_1's binary_error: 0.00908571
# [326]	training's binary_error: 0.009215	valid_1's binary_error: 0.009075
# [327]	training's binary_error: 0.00918786	valid_1's binary_error: 0.00903929
# [328]	training's binary_error: 0.00914571	valid_1's binary_error: 0.00900357
# [329]	training's binary_error: 0.00911786	valid_1's binary_error: 0.008975
# [330]	training's binary_error: 0.00909071	valid_1's binary_error: 0.00896429
# [331]	training's binary_error: 0.00907	valid_1's binary_error: 0.00895
# [332]	training's binary_error: 0.00904929	valid_1's binary_error: 0.00891786
# [333]	training's binary_error: 0.00902	valid_1's binary_error: 0.00887143
# [334]	training's binary_error: 0.00898857	valid_1's binary_error: 0.00884643
# [335]	training's binary_error: 0.00895286	valid_1's binary_error: 0.00881429
# [336]	training's binary_error: 0.008925	valid_1's binary_error: 0.00877857
# [337]	training's binary_error: 0.008895	valid_1's binary_error: 0.00875
# [338]	training's binary_error: 0.00886786	valid_1's binary_error: 0.00871429
# [339]	training's binary_error: 0.00884	valid_1's binary_error: 0.00869286
# [340]	training's binary_error: 0.00882143	valid_1's binary_error: 0.00867143
# [341]	training's binary_error: 0.00878143	valid_1's binary_error: 0.00863929
# [342]	training's binary_error: 0.00874786	valid_1's binary_error: 0.00860714
# [343]	training's binary_error: 0.008725	valid_1's binary_error: 0.00859643
# [344]	training's binary_error: 0.00868714	valid_1's binary_error: 0.00857143
# [345]	training's binary_error: 0.00866	valid_1's binary_error: 0.00854286
# [346]	training's binary_error: 0.00864214	valid_1's binary_error: 0.008525
# [347]	training's binary_error: 0.00860714	valid_1's binary_error: 0.008475
# [348]	training's binary_error: 0.00857786	valid_1's binary_error: 0.00847143
# [349]	training's binary_error: 0.00853857	valid_1's binary_error: 0.00844286
# [350]	training's binary_error: 0.00851714	valid_1's binary_error: 0.00842857
# [351]	training's binary_error: 0.00847786	valid_1's binary_error: 0.00839286
# [352]	training's binary_error: 0.00845357	valid_1's binary_error: 0.00833929
# [353]	training's binary_error: 0.00843429	valid_1's binary_error: 0.00833571
# [354]	training's binary_error: 0.00841357	valid_1's binary_error: 0.00831429
# [355]	training's binary_error: 0.00838357	valid_1's binary_error: 0.008275
# [356]	training's binary_error: 0.00834786	valid_1's binary_error: 0.00824286
# [357]	training's binary_error: 0.00832429	valid_1's binary_error: 0.00821429
# [358]	training's binary_error: 0.00829571	valid_1's binary_error: 0.008175
# [359]	training's binary_error: 0.00827071	valid_1's binary_error: 0.00814643
# [360]	training's binary_error: 0.00823143	valid_1's binary_error: 0.00810714
# [361]	training's binary_error: 0.00820143	valid_1's binary_error: 0.00808929
# [362]	training's binary_error: 0.00818143	valid_1's binary_error: 0.00805
# [363]	training's binary_error: 0.00815429	valid_1's binary_error: 0.00803214
# [364]	training's binary_error: 0.00813214	valid_1's binary_error: 0.00801429
# [365]	training's binary_error: 0.00810571	valid_1's binary_error: 0.00800357
# [366]	training's binary_error: 0.00808	valid_1's binary_error: 0.00798214
# [367]	training's binary_error: 0.00805214	valid_1's binary_error: 0.00796786
# [368]	training's binary_error: 0.00803857	valid_1's binary_error: 0.00795
# [369]	training's binary_error: 0.00801786	valid_1's binary_error: 0.00790714
# [370]	training's binary_error: 0.00798786	valid_1's binary_error: 0.00788929
# [371]	training's binary_error: 0.00795714	valid_1's binary_error: 0.00785
# [372]	training's binary_error: 0.00793786	valid_1's binary_error: 0.00784643
# [373]	training's binary_error: 0.00792	valid_1's binary_error: 0.00780357
# [374]	training's binary_error: 0.0079	valid_1's binary_error: 0.00775714
# [375]	training's binary_error: 0.00786429	valid_1's binary_error: 0.00773214
# [376]	training's binary_error: 0.00782571	valid_1's binary_error: 0.00768571
# [377]	training's binary_error: 0.0078	valid_1's binary_error: 0.00766071
# [378]	training's binary_error: 0.00777214	valid_1's binary_error: 0.00762857
# [379]	training's binary_error: 0.00775571	valid_1's binary_error: 0.00763571
# [380]	training's binary_error: 0.00773357	valid_1's binary_error: 0.00762143
# [381]	training's binary_error: 0.00771	valid_1's binary_error: 0.00758571
# [382]	training's binary_error: 0.00768714	valid_1's binary_error: 0.00756071
# [383]	training's binary_error: 0.00767143	valid_1's binary_error: 0.00753929
# [384]	training's binary_error: 0.00766214	valid_1's binary_error: 0.00752857
# [385]	training's binary_error: 0.00764357	valid_1's binary_error: 0.00748929
# [386]	training's binary_error: 0.00762429	valid_1's binary_error: 0.00748214
# [387]	training's binary_error: 0.00759857	valid_1's binary_error: 0.00746071
# [388]	training's binary_error: 0.00756714	valid_1's binary_error: 0.00746429
# [389]	training's binary_error: 0.00753	valid_1's binary_error: 0.00742857
# [390]	training's binary_error: 0.00751	valid_1's binary_error: 0.00741071
# [391]	training's binary_error: 0.00749214	valid_1's binary_error: 0.00738929
# [392]	training's binary_error: 0.00746929	valid_1's binary_error: 0.00737143
# [393]	training's binary_error: 0.00743143	valid_1's binary_error: 0.007325
# [394]	training's binary_error: 0.00740571	valid_1's binary_error: 0.00731429
# [395]	training's binary_error: 0.00737714	valid_1's binary_error: 0.00728929
# [396]	training's binary_error: 0.00734143	valid_1's binary_error: 0.00724286
# [397]	training's binary_error: 0.00732429	valid_1's binary_error: 0.00722143
# [398]	training's binary_error: 0.00730143	valid_1's binary_error: 0.00719286
# [399]	training's binary_error: 0.00727143	valid_1's binary_error: 0.00718214
# [400]	training's binary_error: 0.00725214	valid_1's binary_error: 0.00717857
# [401]	training's binary_error: 0.00722143	valid_1's binary_error: 0.00714643
# [402]	training's binary_error: 0.00719286	valid_1's binary_error: 0.00712857
# [403]	training's binary_error: 0.00715929	valid_1's binary_error: 0.00711429
# [404]	training's binary_error: 0.00712643	valid_1's binary_error: 0.00704286
# [405]	training's binary_error: 0.007115	valid_1's binary_error: 0.00702143
# [406]	training's binary_error: 0.00709143	valid_1's binary_error: 0.007025
# [407]	training's binary_error: 0.00706714	valid_1's binary_error: 0.00699286
# [408]	training's binary_error: 0.00704643	valid_1's binary_error: 0.00697143
# [409]	training's binary_error: 0.00702	valid_1's binary_error: 0.00693571
# [410]	training's binary_error: 0.00699571	valid_1's binary_error: 0.00690357
# [411]	training's binary_error: 0.00697929	valid_1's binary_error: 0.0069
# [412]	training's binary_error: 0.00693786	valid_1's binary_error: 0.00686429
# [413]	training's binary_error: 0.00690214	valid_1's binary_error: 0.00682143
# [414]	training's binary_error: 0.00686357	valid_1's binary_error: 0.00676071
# [415]	training's binary_error: 0.00684357	valid_1's binary_error: 0.00677143
# [416]	training's binary_error: 0.00681643	valid_1's binary_error: 0.00673214
# [417]	training's binary_error: 0.00679857	valid_1's binary_error: 0.00670357
# [418]	training's binary_error: 0.00677	valid_1's binary_error: 0.00666786
# [419]	training's binary_error: 0.00673429	valid_1's binary_error: 0.00662143
# [420]	training's binary_error: 0.00670714	valid_1's binary_error: 0.00658929
# [421]	training's binary_error: 0.00668857	valid_1's binary_error: 0.00655714
# [422]	training's binary_error: 0.00667	valid_1's binary_error: 0.00655714
# [423]	training's binary_error: 0.00665857	valid_1's binary_error: 0.00655357
# [424]	training's binary_error: 0.00664786	valid_1's binary_error: 0.00653571
# [425]	training's binary_error: 0.00661857	valid_1's binary_error: 0.00651786
# [426]	training's binary_error: 0.00659786	valid_1's binary_error: 0.00648929
# [427]	training's binary_error: 0.00656714	valid_1's binary_error: 0.00648571
# [428]	training's binary_error: 0.00654786	valid_1's binary_error: 0.00645714
# [429]	training's binary_error: 0.00651714	valid_1's binary_error: 0.00643571
# [430]	training's binary_error: 0.00650357	valid_1's binary_error: 0.00641786
# [431]	training's binary_error: 0.00647786	valid_1's binary_error: 0.00637857
# [432]	training's binary_error: 0.00644786	valid_1's binary_error: 0.00636071
# [433]	training's binary_error: 0.00642357	valid_1's binary_error: 0.00633571
# [434]	training's binary_error: 0.00639929	valid_1's binary_error: 0.00631429
# [435]	training's binary_error: 0.00638	valid_1's binary_error: 0.00628571
# [436]	training's binary_error: 0.00635071	valid_1's binary_error: 0.00626071
# [437]	training's binary_error: 0.006325	valid_1's binary_error: 0.00624643
# [438]	training's binary_error: 0.00630071	valid_1's binary_error: 0.00621429
# [439]	training's binary_error: 0.00627643	valid_1's binary_error: 0.00617857
# [440]	training's binary_error: 0.00625143	valid_1's binary_error: 0.00616071
# [441]	training's binary_error: 0.00623071	valid_1's binary_error: 0.00613571
# [442]	training's binary_error: 0.00620786	valid_1's binary_error: 0.0061
# [443]	training's binary_error: 0.00618429	valid_1's binary_error: 0.00608571
# [444]	training's binary_error: 0.00617	valid_1's binary_error: 0.00606786
# [445]	training's binary_error: 0.00614643	valid_1's binary_error: 0.00604643
# [446]	training's binary_error: 0.00612214	valid_1's binary_error: 0.006025
# [447]	training's binary_error: 0.00610071	valid_1's binary_error: 0.00601429
# [448]	training's binary_error: 0.00608643	valid_1's binary_error: 0.00600357
# [449]	training's binary_error: 0.00605929	valid_1's binary_error: 0.00596429
# [450]	training's binary_error: 0.00603643	valid_1's binary_error: 0.00595714
# [451]	training's binary_error: 0.00601929	valid_1's binary_error: 0.00593929
# [452]	training's binary_error: 0.00600143	valid_1's binary_error: 0.00592143
# [453]	training's binary_error: 0.00598786	valid_1's binary_error: 0.00588929
# [454]	training's binary_error: 0.00596714	valid_1's binary_error: 0.00587857
# [455]	training's binary_error: 0.00594857	valid_1's binary_error: 0.00587143
# [456]	training's binary_error: 0.00592857	valid_1's binary_error: 0.00583571
# [457]	training's binary_error: 0.00591571	valid_1's binary_error: 0.005825
# [458]	training's binary_error: 0.00591071	valid_1's binary_error: 0.00582143
# [459]	training's binary_error: 0.00589	valid_1's binary_error: 0.00581429
# [460]	training's binary_error: 0.00588	valid_1's binary_error: 0.00579286
# [461]	training's binary_error: 0.00585643	valid_1's binary_error: 0.00576429
# [462]	training's binary_error: 0.00584143	valid_1's binary_error: 0.00574286
# [463]	training's binary_error: 0.00581429	valid_1's binary_error: 0.00571429
# [464]	training's binary_error: 0.00579286	valid_1's binary_error: 0.0057
# [465]	training's binary_error: 0.00578	valid_1's binary_error: 0.0057
# [466]	training's binary_error: 0.00575357	valid_1's binary_error: 0.00566429
# [467]	training's binary_error: 0.00572929	valid_1's binary_error: 0.005625
# [468]	training's binary_error: 0.00570571	valid_1's binary_error: 0.00560714
# [469]	training's binary_error: 0.00568214	valid_1's binary_error: 0.00557143
# [470]	training's binary_error: 0.00566643	valid_1's binary_error: 0.00556429
# [471]	training's binary_error: 0.00565357	valid_1's binary_error: 0.00555357
# [472]	training's binary_error: 0.00564071	valid_1's binary_error: 0.00555
# [473]	training's binary_error: 0.00563143	valid_1's binary_error: 0.00554286
# [474]	training's binary_error: 0.00560714	valid_1's binary_error: 0.00550714
# [475]	training's binary_error: 0.00557429	valid_1's binary_error: 0.005475
# [476]	training's binary_error: 0.00554857	valid_1's binary_error: 0.00548214
# [477]	training's binary_error: 0.00552286	valid_1's binary_error: 0.00545357
# [478]	training's binary_error: 0.0055	valid_1's binary_error: 0.00541071
# [479]	training's binary_error: 0.00549	valid_1's binary_error: 0.00540714
# [480]	training's binary_error: 0.00545643	valid_1's binary_error: 0.00536071
# [481]	training's binary_error: 0.00543214	valid_1's binary_error: 0.00533929
# [482]	training's binary_error: 0.00539714	valid_1's binary_error: 0.00531429
# [483]	training's binary_error: 0.00537929	valid_1's binary_error: 0.00529286
# [484]	training's binary_error: 0.00536071	valid_1's binary_error: 0.00526429
# [485]	training's binary_error: 0.00533571	valid_1's binary_error: 0.00523929
# [486]	training's binary_error: 0.00532143	valid_1's binary_error: 0.005225
# [487]	training's binary_error: 0.00530429	valid_1's binary_error: 0.00521071
# [488]	training's binary_error: 0.00528071	valid_1's binary_error: 0.00520714
# [489]	training's binary_error: 0.00525857	valid_1's binary_error: 0.005175
# [490]	training's binary_error: 0.005235	valid_1's binary_error: 0.00516786
# [491]	training's binary_error: 0.00522	valid_1's binary_error: 0.00514643
# [492]	training's binary_error: 0.00521214	valid_1's binary_error: 0.00513214
# [493]	training's binary_error: 0.00518357	valid_1's binary_error: 0.00512143
# [494]	training's binary_error: 0.005165	valid_1's binary_error: 0.00508571
# [495]	training's binary_error: 0.00514857	valid_1's binary_error: 0.00506429
# [496]	training's binary_error: 0.00512571	valid_1's binary_error: 0.00504286
# [497]	training's binary_error: 0.00510714	valid_1's binary_error: 0.005025
# [498]	training's binary_error: 0.00509571	valid_1's binary_error: 0.00500714
# [499]	training's binary_error: 0.00508071	valid_1's binary_error: 0.00500714
# [500]	training's binary_error: 0.005075	valid_1's binary_error: 0.00498929
# [501]	training's binary_error: 0.00506071	valid_1's binary_error: 0.00497857
# [502]	training's binary_error: 0.00504071	valid_1's binary_error: 0.00497143
# [503]	training's binary_error: 0.00502214	valid_1's binary_error: 0.00494286
# [504]	training's binary_error: 0.00501357	valid_1's binary_error: 0.00493571
# [505]	training's binary_error: 0.00498714	valid_1's binary_error: 0.0049
# [506]	training's binary_error: 0.00497357	valid_1's binary_error: 0.00489286
# [507]	training's binary_error: 0.00495357	valid_1's binary_error: 0.004875
# [508]	training's binary_error: 0.00492643	valid_1's binary_error: 0.00485357
# [509]	training's binary_error: 0.00490286	valid_1's binary_error: 0.004825
# [510]	training's binary_error: 0.004885	valid_1's binary_error: 0.00481786
# [511]	training's binary_error: 0.004865	valid_1's binary_error: 0.00480357
# [512]	training's binary_error: 0.00484714	valid_1's binary_error: 0.00478929
# [513]	training's binary_error: 0.00483143	valid_1's binary_error: 0.00477143
# [514]	training's binary_error: 0.00480643	valid_1's binary_error: 0.00476071
# [515]	training's binary_error: 0.00478929	valid_1's binary_error: 0.004725
# [516]	training's binary_error: 0.00477214	valid_1's binary_error: 0.0047
# [517]	training's binary_error: 0.00475571	valid_1's binary_error: 0.00468214
# [518]	training's binary_error: 0.00473571	valid_1's binary_error: 0.00467143
# [519]	training's binary_error: 0.00471929	valid_1's binary_error: 0.00465
# [520]	training's binary_error: 0.00469714	valid_1's binary_error: 0.00462857
# [521]	training's binary_error: 0.00468714	valid_1's binary_error: 0.00461786
# [522]	training's binary_error: 0.00467357	valid_1's binary_error: 0.00461071
# [523]	training's binary_error: 0.00465929	valid_1's binary_error: 0.00459643
# [524]	training's binary_error: 0.004645	valid_1's binary_error: 0.004575
# [525]	training's binary_error: 0.004615	valid_1's binary_error: 0.00453214
# [526]	training's binary_error: 0.00460214	valid_1's binary_error: 0.0045
# [527]	training's binary_error: 0.00457929	valid_1's binary_error: 0.00447143
# [528]	training's binary_error: 0.00456214	valid_1's binary_error: 0.00446786
# [529]	training's binary_error: 0.00454214	valid_1's binary_error: 0.00443929
# [530]	training's binary_error: 0.00452357	valid_1's binary_error: 0.00441429
# [531]	training's binary_error: 0.00451571	valid_1's binary_error: 0.00440714
# [532]	training's binary_error: 0.00451	valid_1's binary_error: 0.00440357
# [533]	training's binary_error: 0.00448929	valid_1's binary_error: 0.00438929
# [534]	training's binary_error: 0.00447643	valid_1's binary_error: 0.00438571
# [535]	training's binary_error: 0.00445714	valid_1's binary_error: 0.00436429
# [536]	training's binary_error: 0.00443	valid_1's binary_error: 0.00434286
# [537]	training's binary_error: 0.00441786	valid_1's binary_error: 0.00434286
# [538]	training's binary_error: 0.00440929	valid_1's binary_error: 0.00434286
# [539]	training's binary_error: 0.00439714	valid_1's binary_error: 0.00433929
# [540]	training's binary_error: 0.00438714	valid_1's binary_error: 0.00431786
# [541]	training's binary_error: 0.00437286	valid_1's binary_error: 0.00431786
# [542]	training's binary_error: 0.00435571	valid_1's binary_error: 0.00430357
# [543]	training's binary_error: 0.00433929	valid_1's binary_error: 0.00427857
# [544]	training's binary_error: 0.00432071	valid_1's binary_error: 0.00426071
# [545]	training's binary_error: 0.00430214	valid_1's binary_error: 0.00423571
# [546]	training's binary_error: 0.00427857	valid_1's binary_error: 0.00422143
# [547]	training's binary_error: 0.00425357	valid_1's binary_error: 0.00421786
# [548]	training's binary_error: 0.004235	valid_1's binary_error: 0.00421429
# [549]	training's binary_error: 0.004225	valid_1's binary_error: 0.00419286
# [550]	training's binary_error: 0.00421857	valid_1's binary_error: 0.00419643
# [551]	training's binary_error: 0.00420214	valid_1's binary_error: 0.00418214
# [552]	training's binary_error: 0.00418357	valid_1's binary_error: 0.00416786
# [553]	training's binary_error: 0.00417071	valid_1's binary_error: 0.00416786
# [554]	training's binary_error: 0.00415929	valid_1's binary_error: 0.00415714
# [555]	training's binary_error: 0.00414214	valid_1's binary_error: 0.00412857
# [556]	training's binary_error: 0.00412143	valid_1's binary_error: 0.00410357
# [557]	training's binary_error: 0.00411429	valid_1's binary_error: 0.00411786
# [558]	training's binary_error: 0.00409143	valid_1's binary_error: 0.00408571
# [559]	training's binary_error: 0.00408214	valid_1's binary_error: 0.00408214
# [560]	training's binary_error: 0.00406643	valid_1's binary_error: 0.00408571
# [561]	training's binary_error: 0.00405429	valid_1's binary_error: 0.00407857
# [562]	training's binary_error: 0.00403714	valid_1's binary_error: 0.00406429
# [563]	training's binary_error: 0.00402286	valid_1's binary_error: 0.00404286
# [564]	training's binary_error: 0.00401643	valid_1's binary_error: 0.00403214
# [565]	training's binary_error: 0.004005	valid_1's binary_error: 0.004025
# [566]	training's binary_error: 0.00398429	valid_1's binary_error: 0.00400714
# [567]	training's binary_error: 0.00397571	valid_1's binary_error: 0.00400714
# [568]	training's binary_error: 0.00396786	valid_1's binary_error: 0.00398929
# [569]	training's binary_error: 0.00395	valid_1's binary_error: 0.003975
# [570]	training's binary_error: 0.00393929	valid_1's binary_error: 0.00395357
# [571]	training's binary_error: 0.00392714	valid_1's binary_error: 0.00393571
# [572]	training's binary_error: 0.00390857	valid_1's binary_error: 0.00391786
# [573]	training's binary_error: 0.00390214	valid_1's binary_error: 0.00389643
# [574]	training's binary_error: 0.00389429	valid_1's binary_error: 0.00388929
# [575]	training's binary_error: 0.00388143	valid_1's binary_error: 0.00388214
# [576]	training's binary_error: 0.00386214	valid_1's binary_error: 0.003875
# [577]	training's binary_error: 0.00385143	valid_1's binary_error: 0.00386786
# [578]	training's binary_error: 0.00384	valid_1's binary_error: 0.00386071
# [579]	training's binary_error: 0.00381929	valid_1's binary_error: 0.003825
# [580]	training's binary_error: 0.00379714	valid_1's binary_error: 0.00380714
# [581]	training's binary_error: 0.00377143	valid_1's binary_error: 0.00379286
# [582]	training's binary_error: 0.00375286	valid_1's binary_error: 0.00377143
# [583]	training's binary_error: 0.003735	valid_1's binary_error: 0.00374643
# [584]	training's binary_error: 0.00372	valid_1's binary_error: 0.00372143
# [585]	training's binary_error: 0.00369286	valid_1's binary_error: 0.00371071
# [586]	training's binary_error: 0.00367929	valid_1's binary_error: 0.00368571
# [587]	training's binary_error: 0.00366286	valid_1's binary_error: 0.00367143
# [588]	training's binary_error: 0.00364571	valid_1's binary_error: 0.00364643
# [589]	training's binary_error: 0.00362214	valid_1's binary_error: 0.00363929
# [590]	training's binary_error: 0.00360643	valid_1's binary_error: 0.00361071
# [591]	training's binary_error: 0.00359214	valid_1's binary_error: 0.00360357
# [592]	training's binary_error: 0.00358214	valid_1's binary_error: 0.00357857
# [593]	training's binary_error: 0.00357571	valid_1's binary_error: 0.00356429
# [594]	training's binary_error: 0.00355357	valid_1's binary_error: 0.00353929
# [595]	training's binary_error: 0.003545	valid_1's binary_error: 0.00353571
# [596]	training's binary_error: 0.00353	valid_1's binary_error: 0.003525
# [597]	training's binary_error: 0.00350929	valid_1's binary_error: 0.00348571
# [598]	training's binary_error: 0.00349214	valid_1's binary_error: 0.00346071
# [599]	training's binary_error: 0.003475	valid_1's binary_error: 0.00343929
# [600]	training's binary_error: 0.00345857	valid_1's binary_error: 0.00342857
# [601]	training's binary_error: 0.00344786	valid_1's binary_error: 0.00341429
# [602]	training's binary_error: 0.00343571	valid_1's binary_error: 0.0034
# [603]	training's binary_error: 0.00341643	valid_1's binary_error: 0.00338571
# [604]	training's binary_error: 0.00339786	valid_1's binary_error: 0.00336071
# [605]	training's binary_error: 0.00337	valid_1's binary_error: 0.00333929
# [606]	training's binary_error: 0.00335357	valid_1's binary_error: 0.003325
# [607]	training's binary_error: 0.00333571	valid_1's binary_error: 0.00330357
# [608]	training's binary_error: 0.00331786	valid_1's binary_error: 0.003275
# [609]	training's binary_error: 0.00330357	valid_1's binary_error: 0.003275
# [610]	training's binary_error: 0.00328786	valid_1's binary_error: 0.00325
# [611]	training's binary_error: 0.00327214	valid_1's binary_error: 0.00323929
# [612]	training's binary_error: 0.00326857	valid_1's binary_error: 0.00324286
# [613]	training's binary_error: 0.00325429	valid_1's binary_error: 0.003225
# [614]	training's binary_error: 0.00324357	valid_1's binary_error: 0.00321071
# [615]	training's binary_error: 0.00323571	valid_1's binary_error: 0.00321429
# [616]	training's binary_error: 0.00322143	valid_1's binary_error: 0.00319643
# [617]	training's binary_error: 0.00320071	valid_1's binary_error: 0.00317143
# [618]	training's binary_error: 0.003185	valid_1's binary_error: 0.00316071
# [619]	training's binary_error: 0.00317071	valid_1's binary_error: 0.00314643
# [620]	training's binary_error: 0.00316429	valid_1's binary_error: 0.00313929
# [621]	training's binary_error: 0.00315786	valid_1's binary_error: 0.00313214
# [622]	training's binary_error: 0.00313929	valid_1's binary_error: 0.00310357
# [623]	training's binary_error: 0.00312643	valid_1's binary_error: 0.00309286
# [624]	training's binary_error: 0.00311357	valid_1's binary_error: 0.003075
# [625]	training's binary_error: 0.00308857	valid_1's binary_error: 0.00305714
# [626]	training's binary_error: 0.00307786	valid_1's binary_error: 0.00305714
# [627]	training's binary_error: 0.00306214	valid_1's binary_error: 0.00302143
# [628]	training's binary_error: 0.00305071	valid_1's binary_error: 0.00300714
# [629]	training's binary_error: 0.00304	valid_1's binary_error: 0.00300357
# [630]	training's binary_error: 0.00303786	valid_1's binary_error: 0.00299643
# [631]	training's binary_error: 0.00302143	valid_1's binary_error: 0.00299643
# [632]	training's binary_error: 0.00300786	valid_1's binary_error: 0.00298571
# [633]	training's binary_error: 0.00299071	valid_1's binary_error: 0.00295
# [634]	training's binary_error: 0.00298571	valid_1's binary_error: 0.00294643
# [635]	training's binary_error: 0.00297929	valid_1's binary_error: 0.00295
# [636]	training's binary_error: 0.00296786	valid_1's binary_error: 0.00293929
# [637]	training's binary_error: 0.00296071	valid_1's binary_error: 0.00293929
# ...
# [2015]	training's binary_error: 4.85714e-05	valid_1's binary_error: 3.57143e-05
# [2016]	training's binary_error: 4.85714e-05	valid_1's binary_error: 3.57143e-05
# [2017]	training's binary_error: 4.78571e-05	valid_1's binary_error: 3.21429e-05
# [2018]	training's binary_error: 4.78571e-05	valid_1's binary_error: 3.21429e-05
# [2019]	training's binary_error: 4.78571e-05	valid_1's binary_error: 3.21429e-05
# [2020]	training's binary_error: 4.78571e-05	valid_1's binary_error: 3.21429e-05
# [2021]	training's binary_error: 4.78571e-05	valid_1's binary_error: 3.21429e-05
# [2022]	training's binary_error: 4.78571e-05	valid_1's binary_error: 3.21429e-05
# [2023]	training's binary_error: 4.78571e-05	valid_1's binary_error: 3.21429e-05
# [2024]	training's binary_error: 4.78571e-05	valid_1's binary_error: 3.21429e-05
# [2025]	training's binary_error: 4.78571e-05	valid_1's binary_error: 3.21429e-05
# [2026]	training's binary_error: 4.78571e-05	valid_1's binary_error: 3.21429e-05
# [2027]	training's binary_error: 4.78571e-05	valid_1's binary_error: 3.21429e-05
# [2028]	training's binary_error: 4.78571e-05	valid_1's binary_error: 3.21429e-05
# [2029]	training's binary_error: 4.71429e-05	valid_1's binary_error: 3.21429e-05
# [2030]	training's binary_error: 4.71429e-05	valid_1's binary_error: 3.21429e-05
# [2031]	training's binary_error: 4.78571e-05	valid_1's binary_error: 3.21429e-05
# [2032]	training's binary_error: 4.85714e-05	valid_1's binary_error: 3.21429e-05
# [2033]	training's binary_error: 4.85714e-05	valid_1's binary_error: 3.21429e-05
# [2034]	training's binary_error: 4.85714e-05	valid_1's binary_error: 3.21429e-05
# [2035]	training's binary_error: 4.85714e-05	valid_1's binary_error: 3.21429e-05
# [2036]	training's binary_error: 4.85714e-05	valid_1's binary_error: 3.21429e-05
# [2037]	training's binary_error: 4.85714e-05	valid_1's binary_error: 3.21429e-05
# [2038]	training's binary_error: 4.85714e-05	valid_1's binary_error: 3.21429e-05
# [2039]	training's binary_error: 4.85714e-05	valid_1's binary_error: 3.21429e-05
# [2040]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2041]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2042]	training's binary_error: 4.71429e-05	valid_1's binary_error: 2.85714e-05
# [2043]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2044]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2045]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2046]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2047]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2048]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2049]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2050]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2051]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2052]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2053]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2054]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2055]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2056]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2057]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2058]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2059]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2060]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2061]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2062]	training's binary_error: 4.78571e-05	valid_1's binary_error: 2.85714e-05
# [2063]	training's binary_error: 4.71429e-05	valid_1's binary_error: 2.85714e-05
# [2064]	training's binary_error: 4.71429e-05	valid_1's binary_error: 2.85714e-05
# [2065]	training's binary_error: 4.71429e-05	valid_1's binary_error: 2.85714e-05
# [2066]	training's binary_error: 4.71429e-05	valid_1's binary_error: 2.85714e-05
# [2067]	training's binary_error: 4.71429e-05	valid_1's binary_error: 2.85714e-05
# [2068]	training's binary_error: 4.71429e-05	valid_1's binary_error: 2.85714e-05
# [2069]	training's binary_error: 4.71429e-05	valid_1's binary_error: 2.85714e-05
# [2070]	training's binary_error: 4.71429e-05	valid_1's binary_error: 2.85714e-05
# [2071]	training's binary_error: 4.71429e-05	valid_1's binary_error: 2.85714e-05
# [2072]	training's binary_error: 4.64286e-05	valid_1's binary_error: 2.85714e-05
# [2073]	training's binary_error: 4.64286e-05	valid_1's binary_error: 2.85714e-05
# [2074]	training's binary_error: 4.64286e-05	valid_1's binary_error: 2.85714e-05
# [2075]	training's binary_error: 4.64286e-05	valid_1's binary_error: 2.85714e-05
# [2076]	training's binary_error: 4.57143e-05	valid_1's binary_error: 2.85714e-05
# [2077]	training's binary_error: 4.57143e-05	valid_1's binary_error: 2.85714e-05
# [2078]	training's binary_error: 4.57143e-05	valid_1's binary_error: 2.85714e-05
# [2079]	training's binary_error: 4.57143e-05	valid_1's binary_error: 2.85714e-05
# [2080]	training's binary_error: 4.57143e-05	valid_1's binary_error: 2.85714e-05
# [2081]	training's binary_error: 4.57143e-05	valid_1's binary_error: 2.85714e-05
# [2082]	training's binary_error: 4.57143e-05	valid_1's binary_error: 2.85714e-05
# [2083]	training's binary_error: 4.5e-05	valid_1's binary_error: 2.85714e-05
# [2084]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2085]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2086]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2087]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2088]	training's binary_error: 4.5e-05	valid_1's binary_error: 2.85714e-05
# [2089]	training's binary_error: 4.5e-05	valid_1's binary_error: 2.85714e-05
# [2090]	training's binary_error: 4.5e-05	valid_1's binary_error: 2.85714e-05
# [2091]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2092]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2093]	training's binary_error: 4.5e-05	valid_1's binary_error: 2.85714e-05
# [2094]	training's binary_error: 4.5e-05	valid_1's binary_error: 2.85714e-05
# [2095]	training's binary_error: 4.5e-05	valid_1's binary_error: 2.85714e-05
# [2096]	training's binary_error: 4.5e-05	valid_1's binary_error: 2.85714e-05
# [2097]	training's binary_error: 4.5e-05	valid_1's binary_error: 2.85714e-05
# [2098]	training's binary_error: 4.57143e-05	valid_1's binary_error: 2.85714e-05
# [2099]	training's binary_error: 4.57143e-05	valid_1's binary_error: 2.85714e-05
# [2100]	training's binary_error: 4.57143e-05	valid_1's binary_error: 2.85714e-05
# [2101]	training's binary_error: 4.57143e-05	valid_1's binary_error: 2.85714e-05
# [2102]	training's binary_error: 4.57143e-05	valid_1's binary_error: 2.85714e-05
# [2103]	training's binary_error: 4.57143e-05	valid_1's binary_error: 2.85714e-05
# [2104]	training's binary_error: 4.57143e-05	valid_1's binary_error: 2.85714e-05
# [2105]	training's binary_error: 4.57143e-05	valid_1's binary_error: 2.85714e-05
# [2106]	training's binary_error: 4.57143e-05	valid_1's binary_error: 2.85714e-05
# [2107]	training's binary_error: 4.57143e-05	valid_1's binary_error: 2.85714e-05
# [2108]	training's binary_error: 4.28571e-05	valid_1's binary_error: 2.5e-05
# [2109]	training's binary_error: 4.35714e-05	valid_1's binary_error: 2.85714e-05
# [2110]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2111]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2112]	training's binary_error: 4.35714e-05	valid_1's binary_error: 2.85714e-05
# [2113]	training's binary_error: 4.35714e-05	valid_1's binary_error: 2.85714e-05
# [2114]	training's binary_error: 4.35714e-05	valid_1's binary_error: 2.85714e-05
# [2115]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2116]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2117]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2118]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2119]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2120]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2121]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2122]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2123]	training's binary_error: 4.5e-05	valid_1's binary_error: 2.85714e-05
# [2124]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2125]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2126]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2127]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2128]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2129]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2130]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2131]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2132]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2133]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2134]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2135]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2136]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2137]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2138]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2139]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2140]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2141]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2142]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2143]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2144]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2145]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2146]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2147]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2148]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2149]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2150]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2151]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2152]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2153]	training's binary_error: 4.35714e-05	valid_1's binary_error: 2.85714e-05
# [2154]	training's binary_error: 4.35714e-05	valid_1's binary_error: 2.85714e-05
# [2155]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2156]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2157]	training's binary_error: 4.35714e-05	valid_1's binary_error: 2.85714e-05
# [2158]	training's binary_error: 4.35714e-05	valid_1's binary_error: 2.85714e-05
# [2159]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2160]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2161]	training's binary_error: 4.35714e-05	valid_1's binary_error: 2.85714e-05
# [2162]	training's binary_error: 4.35714e-05	valid_1's binary_error: 2.85714e-05
# [2163]	training's binary_error: 4.35714e-05	valid_1's binary_error: 2.85714e-05
# [2164]	training's binary_error: 4.35714e-05	valid_1's binary_error: 2.85714e-05
# [2165]	training's binary_error: 4.35714e-05	valid_1's binary_error: 2.85714e-05
# [2166]	training's binary_error: 4.35714e-05	valid_1's binary_error: 2.85714e-05
# [2167]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2168]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2169]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2170]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2171]	training's binary_error: 4.35714e-05	valid_1's binary_error: 2.85714e-05
# [2172]	training's binary_error: 4.42857e-05	valid_1's binary_error: 2.85714e-05
# [2173]	training's binary_error: 4.35714e-05	valid_1's binary_error: 2.85714e-05
# [2174]	training's binary_error: 4.21429e-05	valid_1's binary_error: 2.85714e-05
# [2175]	training's binary_error: 4.21429e-05	valid_1's binary_error: 2.85714e-05
# [2176]	training's binary_error: 4.21429e-05	valid_1's binary_error: 2.85714e-05
# [2177]	training's binary_error: 4.21429e-05	valid_1's binary_error: 2.85714e-05
# [2178]	training's binary_error: 4.28571e-05	valid_1's binary_error: 2.85714e-05
# [2179]	training's binary_error: 4.28571e-05	valid_1's binary_error: 2.85714e-05
# [2180]	training's binary_error: 4.28571e-05	valid_1's binary_error: 2.85714e-05
# [2181]	training's binary_error: 4.28571e-05	valid_1's binary_error: 2.85714e-05
# [2182]	training's binary_error: 4.21429e-05	valid_1's binary_error: 2.85714e-05
# [2183]	training's binary_error: 4.14286e-05	valid_1's binary_error: 2.85714e-05
# [2184]	training's binary_error: 4.21429e-05	valid_1's binary_error: 2.85714e-05
# [2185]	training's binary_error: 4.21429e-05	valid_1's binary_error: 2.85714e-05
# [2186]	training's binary_error: 4.21429e-05	valid_1's binary_error: 2.85714e-05
# [2187]	training's binary_error: 4.21429e-05	valid_1's binary_error: 2.85714e-05
# [2188]	training's binary_error: 4.14286e-05	valid_1's binary_error: 2.85714e-05
# [2189]	training's binary_error: 4.14286e-05	valid_1's binary_error: 2.85714e-05
# [2190]	training's binary_error: 4.14286e-05	valid_1's binary_error: 2.85714e-05
# [2191]	training's binary_error: 4.14286e-05	valid_1's binary_error: 2.85714e-05
# [2192]	training's binary_error: 4.14286e-05	valid_1's binary_error: 2.85714e-05
# [2193]	training's binary_error: 4.14286e-05	valid_1's binary_error: 2.85714e-05
# [2194]	training's binary_error: 4.07143e-05	valid_1's binary_error: 2.85714e-05
# [2195]	training's binary_error: 4.07143e-05	valid_1's binary_error: 2.85714e-05
# [2196]	training's binary_error: 4.07143e-05	valid_1's binary_error: 2.85714e-05
# [2197]	training's binary_error: 4e-05	valid_1's binary_error: 2.85714e-05
# [2198]	training's binary_error: 4e-05	valid_1's binary_error: 2.85714e-05
# [2199]	training's binary_error: 3.92857e-05	valid_1's binary_error: 2.85714e-05
# [2200]	training's binary_error: 3.92857e-05	valid_1's binary_error: 2.5e-05
# [2201]	training's binary_error: 3.92857e-05	valid_1's binary_error: 2.5e-05
# [2202]	training's binary_error: 3.92857e-05	valid_1's binary_error: 2.5e-05
# [2203]	training's binary_error: 3.92857e-05	valid_1's binary_error: 2.5e-05
# [2204]	training's binary_error: 3.92857e-05	valid_1's binary_error: 2.5e-05
# [2205]	training's binary_error: 3.92857e-05	valid_1's binary_error: 2.5e-05
# [2206]	training's binary_error: 3.92857e-05	valid_1's binary_error: 2.5e-05
# [2207]	training's binary_error: 3.85714e-05	valid_1's binary_error: 2.5e-05
# [2208]	training's binary_error: 3.85714e-05	valid_1's binary_error: 2.5e-05
# Early stopping, best iteration is:
# [2108]	training's binary_error: 4.28571e-05	valid_1's binary_error: 2.5e-05
# LGBMClassifier(bagging_fraction=0.7331422541166238, bagging_freq=2,
#                feature_fraction=0.6856367429495369,
#                lambda_l1=8.14104577982587e-05, lambda_l2=0.25985991684358545,
#                learning_rate=0.029861155556805748, metric='binary_error',
#                min_child_samples=45, n_estimators=3886, num_leaves=425,
#                objective='binary', verbosity=-1)

# %%
train_pri1 = gbm.predict_proba(train_data)[:,-1]
train_pri1 = pd.DataFrame(train_pri1,columns=['flag'])
train_pri1.to_csv('C:/Users/Lenovo/Desktop/train/train_lgb_3.csv',index = False)

# %%
ind_pri3 = gbm.predict_proba(test_data)[:,-1]

# %%
ind_pri3 = pd.DataFrame(ind_pri3,columns=['flag'])
ind_pri3.to_csv('C:/Users/Lenovo/Desktop/train/prob_lgb_2.csv',index = False)
